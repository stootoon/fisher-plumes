# %% [markdown]
# # Correlation models

# %% [markdown]
# In this notebook we will be testing the corr_models.

# %% [markdown]
# # Code

# %%
# %pylab inline
from importlib import reload
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import corr_models as corrm

# %% [markdown]
# # Exponential model

# %%
reload(corrm)
y, labs = corrm.Exponential.gen_data(1001, corrm.Exponential.Params(2,1))
corrm.plot_data(y, labs)

# %%
reload(corrm)
mdl = corrm.Exponential()
mdl.fit(y)
corrm.plot_cdfs(y, [mdl])
# Out:
#              corr_models 2023/09/13 09:35:22     INFO: Fitting exponential model Model.
#              corr_models 2023/09/13 09:35:22     INFO: Initializing from fit.
#              corr_models 2023/09/13 09:35:22     INFO: Found 673 positive, 328 negative values.
#              corr_models 2023/09/13 09:35:22     INFO: Fit exponential distribution to positive values, λ=2.03.
#              corr_models 2023/09/13 09:35:22     INFO: Fit exponential distribution to negative values, μ=0.993.
#              corr_models 2023/09/13 09:35:22     INFO: Parameters initialized to λ=2, μ=0.99.
#              corr_models 2023/09/13 09:35:22    DEBUG: Iter    0: n+= 673, n-= 328 λ=2, μ=0.99
#              corr_models 2023/09/13 09:35:22    DEBUG: Iter    1: n+= 673, n-= 328 λ=2, μ=0.99
#              corr_models 2023/09/13 09:35:22     INFO: Converged.
#              corr_models 2023/09/13 09:35:22     INFO: Plotting cdf for model: Model, Exponential(λ=2, μ=0.99)

# %% [markdown]
# # Intermittent Exponential model

# %%
reload(corrm)
true_params = corrm.IntermittentExponential.Params(2,1,0.1,0.2)
y, labs = corrm.IntermittentExponential.gen_data(2001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentExponential(init_params = true_params, name = "True Model")
mdl = corrm.IntermittentExponential(#corrm.IntermittentExponential.Params(λ=2,μ=1,σ=0.001,γ=0.2),
    name = "Fit",
                                    σ_penalty = 0, γ_pr_mean = 0.2, γ_pr_strength = 1)
mdl.fit(y)
corrm.plot_cdfs(y, [true_mdl, mdl])
print(mdl)
# Out:
#              corr_models 2023/09/13 09:35:26     INFO:
#              corr_models 2023/09/13 09:35:26     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:35:26     INFO: Initializing model IntermittentExponential named 'True Model' id(self)=140284583823344.
#              corr_models 2023/09/13 09:35:26     INFO: Casting IntermittentExponential to IntermittentExponential.
#              corr_models 2023/09/13 09:35:26     INFO: Cast params: λ=2, μ=1, σ=0.1, γ=0.2 -> λ=2, μ=1, σ=0.1, γ=0.2
#              corr_models 2023/09/13 09:35:26     INFO: Initialized self.init_params = λ=2, μ=1, σ=0.1, γ=0.2
#              corr_models 2023/09/13 09:35:26     INFO: Initialized self.params      = λ=2, μ=1, σ=0.1, γ=0.2
#              corr_models 2023/09/13 09:35:26     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.5, γ_pr_strength=0
#              corr_models 2023/09/13 09:35:26     INFO:
#              corr_models 2023/09/13 09:35:26     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:35:26     INFO: Initializing model IntermittentExponential named 'Fit' id(self)=140284583473056.
#              corr_models 2023/09/13 09:35:26     INFO: Initialized self.init_params = None
#              corr_models 2023/09/13 09:35:26     INFO: Initialized self.params      = None
#              corr_models 2023/09/13 09:35:26     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.2, γ_pr_strength=1
#              corr_models 2023/09/13 09:35:26     INFO: Fitting IntermittentExponential model Fit.
#              corr_models 2023/09/13 09:35:26     INFO: Initializing from fit using γ=0.2.
#              corr_models 2023/09/13 09:35:26     INFO: Found 1601 intermittent points, 239 positive, 161 negative values.
#              corr_models 2023/09/13 09:35:26     INFO: Fit exponential distribution to positive values, λ=1.75.
#              corr_models 2023/09/13 09:35:26     INFO: Fit exponential distribution to negative values, μ=0.922.
#              corr_models 2023/09/13 09:35:26     INFO: Parameters initialized to λ=1.8, μ=0.92, σ=0.093, γ=0.2.
#              corr_models 2023/09/13 09:35:26    DEBUG: Iter    0: n+= 239, n-= 161 n0=1601 λ=1.7, μ=0.99, σ=0.093, γ=0.2
#              corr_models 2023/09/13 09:35:26    DEBUG: Iter    1: n+= 209, n-= 122 n0=1670 λ=2, μ=1.1, σ=0.1, γ=0.18
#              corr_models 2023/09/13 09:35:26    DEBUG: Iter    2: n+= 195, n-= 116 n0=1690 λ=2.1, μ=1.2, σ=0.11, γ=0.18
#              corr_models 2023/09/13 09:35:26    DEBUG: Iter    3: n+= 192, n-= 114 n0=1695 λ=2.1, μ=1.2, σ=0.11, γ=0.18
#              corr_models 2023/09/13 09:35:26    DEBUG: Iter    4: n+= 192, n-= 111 n0=1698 λ=2.1, μ=1.2, σ=0.11, γ=0.18
#              corr_models 2023/09/13 09:35:26    DEBUG: Iter    5: n+= 192, n-= 110 n0=1699 λ=2.1, μ=1.2, σ=0.11, γ=0.18
#              corr_models 2023/09/13 09:35:26    DEBUG: Iter    6: n+= 192, n-= 110 n0=1699 λ=2.1, μ=1.2, σ=0.11, γ=0.18
#              corr_models 2023/09/13 09:35:26     INFO: Converged.
#              corr_models 2023/09/13 09:35:26     INFO: Plotting cdf for model: True Model, IntermittentExponential(λ=2, μ=1, σ=0.1, γ=0.2)
#              corr_models 2023/09/13 09:35:26     INFO: Plotting cdf for model: Fit, IntermittentExponential(λ=2.1, μ=1.2, σ=0.11, γ=0.18)
# Fit, IntermittentExponential(λ=2.1, μ=1.2, σ=0.11, γ=0.18)

# %% [markdown]
# # Intermittent Gamma model

# %%
reload(corrm)
true_params = corrm.IntermittentGamma.Params(2,1,0.01,0.8, 0.2,0.3)
y, labs = corrm.IntermittentGamma.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentGamma(init_params = true_params, name="True Model")
mdl = corrm.IntermittentGamma(#corrm.IntermittentGamma.Params(λ=2,μ=1,σ=0.001,γ=0.2,k=1,m=1),
    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1, name="Gamma")
mdl.fit(y, method="Nelder-Mead")
figure(figsize=(8,4))
corrm.plot_cdfs(y, [true_mdl, mdl], diffs=False)
# Out:
#              corr_models 2023/09/13 09:35:30     INFO:
#              corr_models 2023/09/13 09:35:30     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:35:30     INFO: Initializing model IntermittentGamma named 'True Model' id(self)=140284582880160.
#              corr_models 2023/09/13 09:35:30     INFO: Casting IntermittentGamma to IntermittentGamma.
#              corr_models 2023/09/13 09:35:30     INFO: Cast params: λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3 -> λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3
#              corr_models 2023/09/13 09:35:30     INFO: Initialized self.init_params = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3
#              corr_models 2023/09/13 09:35:30     INFO: Initialized self.params      = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3
#              corr_models 2023/09/13 09:35:30     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.5, γ_pr_strength=0
#              corr_models 2023/09/13 09:35:30     INFO:
#              corr_models 2023/09/13 09:35:30     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:35:30     INFO: Initializing model IntermittentGamma named 'Gamma' id(self)=140284619302896.
#              corr_models 2023/09/13 09:35:30     INFO: Initialized self.init_params = None
#              corr_models 2023/09/13 09:35:30     INFO: Initialized self.params      = None
#              corr_models 2023/09/13 09:35:30     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.8, γ_pr_strength=1
#              corr_models 2023/09/13 09:35:30     INFO: Fitting IntermittentGamma model Gamma.
#              corr_models 2023/09/13 09:35:30     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/13 09:35:30     INFO: Found 201 intermittent points, 460 positive, 340 negative values.
#              corr_models 2023/09/13 09:35:30     INFO: Fit gamma distribution to positive values, k=0.366, λ=1.03.
#              corr_models 2023/09/13 09:35:30     INFO: Fit gamma distribution to negative values, m=0.369, μ=0.782.
#              corr_models 2023/09/13 09:35:30     INFO: Parameters initialized to λ=1, μ=0.78, σ=0.00052, γ=0.8, k=0.37, m=0.37.
#              corr_models 2023/09/13 09:35:30    DEBUG: Iter    0: n+= 530, n-= 360 n0= 111 λ=1.4, μ=0.91, σ=0.00046, γ=0.84, k=0.23, m=0.3
#              corr_models 2023/09/13 09:35:30    DEBUG: Iter    1: n+= 564, n-= 365 n0=  72 λ=1.4, μ=0.92, σ=0.00045, γ=0.86, k=0.21, m=0.29
#              corr_models 2023/09/13 09:35:30    DEBUG: Iter    2: n+= 568, n-= 367 n0=  66 λ=1.4, μ=0.91, σ=0.00044, γ=0.87, k=0.21, m=0.29
#              corr_models 2023/09/13 09:35:30    DEBUG: Iter    3: n+= 568, n-= 367 n0=  66 λ=1.4, μ=0.91, σ=0.00044, γ=0.87, k=0.21, m=0.29
#              corr_models 2023/09/13 09:35:30    DEBUG: Iter    4: n+= 568, n-= 367 n0=  66 λ=1.4, μ=0.91, σ=0.00044, γ=0.87, k=0.21, m=0.29
#              corr_models 2023/09/13 09:35:30     INFO: Converged.
#              corr_models 2023/09/13 09:35:30     INFO: Plotting cdf for model: True Model, IntermittentGamma(λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3)
#              corr_models 2023/09/13 09:35:30    DEBUG: agamma_cdf: Z0 = 2.991568987687591, Z1 = 5.273494620021508
#              corr_models 2023/09/13 09:35:30    DEBUG: agamma_cdf: Z0 = 2.991568987687591, Z1 = 5.273494620021508
#              corr_models 2023/09/13 09:35:30     INFO: Plotting cdf for model: Gamma, IntermittentGamma(λ=1.4, μ=0.91, σ=0.00044, γ=0.87, k=0.21, m=0.29)
#              corr_models 2023/09/13 09:35:30    DEBUG: agamma_cdf: Z0 = 2.9940569480340975, Z1 = 4.638668286808016
#              corr_models 2023/09/13 09:35:30    DEBUG: agamma_cdf: Z0 = 2.9940569480340975, Z1 = 4.638668286808016

# %% [markdown]
# # Intermittent Generalized Inverse Gausssian model

# %%
reload(corrm)
Model = corrm.IntermittentGeneralizedInverseGaussian

# %%
true_params = Model.Params(λ=2,μ=1,σ=0.01,γ=0.8, k=0.2,m=0.1,α=0.1, β=0.1)
y, labs = Model.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
corrm.logger.setLevel(logging.INFO)
Model    = corrm.IntermittentGeneralizedInverseGaussian
true_mdl = Model(init_params=true_params, name="True Model")
mdl      = Model(#Model.Params(λ=1,μ=0.1, k=1,m=1,α=0.5, β=0.5, γ = 0.8, σ = 0.01),
    name = "Fit",
            σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1e-3)
mdl.fit(y, method="Nelder-Mead", damping=0.0)
figure(figsize=(10,5))
corrm.plot_cdfs(y, [true_mdl, mdl])
# Out:
#              corr_models 2023/09/13 09:35:37     INFO:
#              corr_models 2023/09/13 09:35:37     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:35:37     INFO: Initializing model IntermittentGeneralizedInverseGaussian named 'True Model' id(self)=140284581663696.
#              corr_models 2023/09/13 09:35:37     INFO: Casting IntermittentGeneralizedInversGaussian to IntermittentGeneralizedInversGaussian.
#              corr_models 2023/09/13 09:35:37     INFO: Cast params: λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1 -> λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1
#              corr_models 2023/09/13 09:35:37     INFO: Initialized self.init_params = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1
#              corr_models 2023/09/13 09:35:37     INFO: Initialized self.params      = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1
#              corr_models 2023/09/13 09:35:37     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.5, γ_pr_strength=0
#              corr_models 2023/09/13 09:35:37     INFO:
#              corr_models 2023/09/13 09:35:37     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:35:37     INFO: Initializing model IntermittentGeneralizedInverseGaussian named 'Fit' id(self)=140284581663744.
#              corr_models 2023/09/13 09:35:37     INFO: Initialized self.init_params = None
#              corr_models 2023/09/13 09:35:37     INFO: Initialized self.params      = None
#              corr_models 2023/09/13 09:35:37     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.8, γ_pr_strength=0.001
#              corr_models 2023/09/13 09:35:37     INFO: Fitting IntermittentGeneralizedInverseGaussian model Fit.
#              corr_models 2023/09/13 09:35:37     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/13 09:35:37     INFO: Found 201 intermittent points, 534 positive, 266 negative values.
#              corr_models 2023/09/13 09:35:37     INFO: Fit geninvgauss distribution to positive values, λ=1.64, k=0.221, α=0.0857.
#              corr_models 2023/09/13 09:35:37     INFO: Fit geninvgauss distribution to negative values, m=0.135, μ=0.871, β=0.0807.
#              corr_models 2023/09/13 09:35:37     INFO: Parameters initialized to λ=1.6, μ=0.87, σ=0.009, γ=0.8, k=0.22, m=0.14, α=0.086, β=0.081.
#              corr_models 2023/09/13 09:35:37     INFO: Converged.
#              corr_models 2023/09/13 09:35:37     INFO: Plotting cdf for model: True Model, IntermittentGeneralizedInverseGaussian(λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1)
#              corr_models 2023/09/13 09:35:38     INFO: Plotting cdf for model: Fit, IntermittentGeneralizedInverseGaussian(λ=2.1, μ=1.1, σ=0.0099, γ=0.79, k=0.16, m=0.11, α=0.1, β=0.097)

# %% [markdown]
# # CorrModel - Testing the wrapper class.

# %%
reload(corrm)
Params     = corrm.IntermittentGeneralizedInverseGaussian.Params
TrueModel  = corrm.IntermittentGamma
true_model = TrueModel(name="True Model", init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.4, m = 0.1, α = 0.1, β = 0.1),
                       σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
data, labs = true_model.gen_data(1001, params = true_model.params)
corrm.plot_data(data, labs)
# Out:
#              corr_models 2023/09/13 09:37:39     INFO:
#              corr_models 2023/09/13 09:37:39     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:37:39     INFO: Initializing model IntermittentGamma named 'True Model' id(self)=140284579864384.
#              corr_models 2023/09/13 09:37:39     INFO: Casting IntermittentGenInvGauss to IntermittentGamma.
#              corr_models 2023/09/13 09:37:39     INFO: Finding nearest Gamma distribution to GIG(η=2, p=0.4, θ=0.1).
#              corr_models 2023/09/13 09:37:39    DEBUG: C0=18.693982264514133, C1=1.9252473405978052
#              corr_models 2023/09/13 09:37:39    DEBUG: Initializing at [40.   0.4].
#              corr_models 2023/09/13 09:37:39    DEBUG: Solving using scipy.optimize.minimize.
#              corr_models 2023/09/13 09:37:39    DEBUG: Initial value of neg_ElogQ = 3.894727560318895.
#              corr_models 2023/09/13 09:37:39    DEBUG: Minimization terminated with Converged (|f_n-f_(n-1)| ~= 0).
#              corr_models 2023/09/13 09:37:39    DEBUG: Final value of neg_ElogQ = 3.831563333778006.
#              corr_models 2023/09/13 09:37:39     INFO: Mapped to θ=30.474104930903444, k=0.6137319618921069.
#              corr_models 2023/09/13 09:37:39     INFO: Finding nearest Gamma distribution to GIG(η=0.5, p=0.1, θ=0.1).
#              corr_models 2023/09/13 09:37:39    DEBUG: C0=2.572962201893338, C1=-0.3670131832767346
#              corr_models 2023/09/13 09:37:39    DEBUG: Initializing at [10.   0.1].
#              corr_models 2023/09/13 09:37:39    DEBUG: Solving using scipy.optimize.minimize.
#              corr_models 2023/09/13 09:37:39    DEBUG: Initial value of neg_ElogQ = 2.4099555162738833.
#              corr_models 2023/09/13 09:37:39    DEBUG: Minimization terminated with Converged (|f_n-f_(n-1)| ~= 0).
#              corr_models 2023/09/13 09:37:39    DEBUG: Final value of neg_ElogQ = 1.7076704866575092.
#              corr_models 2023/09/13 09:37:39     INFO: Mapped to θ=5.291817230108876, k=0.48621578379438546.
#              corr_models 2023/09/13 09:37:39     INFO: Cast params: λ=2, μ=0.5, σ=0.01, γ=0.8, k=0.4, m=0.1, α=0.1, β=0.1 -> λ=30, μ=5.3, σ=0.01, γ=0.8, k=0.61, m=0.49
#              corr_models 2023/09/13 09:37:39     INFO: Initialized self.init_params = λ=30, μ=5.3, σ=0.01, γ=0.8, k=0.61, m=0.49
#              corr_models 2023/09/13 09:37:39     INFO: Initialized self.params      = λ=30, μ=5.3, σ=0.01, γ=0.8, k=0.61, m=0.49
#              corr_models 2023/09/13 09:37:39     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.8, γ_pr_strength=1

# %%
reload(corrm)
Exp = corrm.CorrModel(model = "exp", name = "Exp", intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.2, m = 0.1, α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gam = corrm.CorrModel(model = "gamma", name = "Gam", intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 1., α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gig = corrm.CorrModel(model = "gig", name="Gig",intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 0.2, α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1, gammaness_thresh = 1e5)

# %%
corrm.logger.setLevel(logging.INFO)
Exp.fit(data);
Gam.fit(data, method = "Nelder-Mead");
Gig.fit(data, method = "Nelder-Mead");
Gam2 = corrm.IntermittentGamma(init_params = corrm.IntermittentGamma.params_from_gig(Gig.params), name="GamFromGig")
figure(figsize=(12,8))
corrm.plot_cdfs(data, [true_model, Gam, Gig, Gam2])#, Gig1])#, labs=["true", "Gam", "Gig", "Gig (γ)"])
# Out:
#              corr_models 2023/09/13 09:37:45     INFO:
#              corr_models 2023/09/13 09:37:45     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:37:45     INFO: Initializing model IntermittentExponential named 'Exp' id(self)=140284578076896.
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.init_params = None
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.params      = None
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.8, γ_pr_strength=1
#              corr_models 2023/09/13 09:37:45     INFO: Fitting IntermittentExponential model Exp.
#              corr_models 2023/09/13 09:37:45     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/13 09:37:45     INFO: Found 201 intermittent points, 614 positive, 186 negative values.
#              corr_models 2023/09/13 09:37:45     INFO: Fit exponential distribution to positive values, λ=20.8.
#              corr_models 2023/09/13 09:37:45     INFO: Fit exponential distribution to negative values, μ=2.97.
#              corr_models 2023/09/13 09:37:45     INFO: Parameters initialized to λ=21, μ=3, σ=0.01, γ=0.8.
#              corr_models 2023/09/13 09:37:45     INFO: Converged.
#              corr_models 2023/09/13 09:37:45     INFO:
#              corr_models 2023/09/13 09:37:45     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:37:45     INFO: Initializing model IntermittentGamma named 'Gam' id(self)=140284578507696.
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.init_params = None
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.params      = None
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.8, γ_pr_strength=1
#              corr_models 2023/09/13 09:37:45     INFO: Fitting IntermittentGamma model Gam.
#              corr_models 2023/09/13 09:37:45     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/13 09:37:45     INFO: Found 201 intermittent points, 614 positive, 186 negative values.
#              corr_models 2023/09/13 09:37:45     INFO: Fit gamma distribution to positive values, k=0.663, λ=31.4.
#              corr_models 2023/09/13 09:37:45     INFO: Fit gamma distribution to negative values, m=0.591, μ=5.03.
#              corr_models 2023/09/13 09:37:45     INFO: Parameters initialized to λ=31, μ=5, σ=0.01, γ=0.8, k=0.66, m=0.59.
# /nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py:618: OptimizeWarning: Initial guess is not within the specified bounds
#   sol = minimize(self.neg_ll, [λ_old, μ_old, k_old, m_old],
#              corr_models 2023/09/13 09:37:45     INFO: Converged.
#              corr_models 2023/09/13 09:37:45     INFO:
#              corr_models 2023/09/13 09:37:45     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:37:45     INFO: Initializing model IntermittentGeneralizedInverseGaussian named 'Gig' id(self)=140284578429488.
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.init_params = None
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.params      = None
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.8, γ_pr_strength=1
#              corr_models 2023/09/13 09:37:45     INFO: Fitting IntermittentGeneralizedInverseGaussian model Gig.
#              corr_models 2023/09/13 09:37:45     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/13 09:37:45     INFO: Found 201 intermittent points, 614 positive, 186 negative values.
#              corr_models 2023/09/13 09:37:45     INFO: Fit geninvgauss distribution to positive values, λ=0.847, k=0.588, α=0.0492.
#              corr_models 2023/09/13 09:37:45     INFO: Fit geninvgauss distribution to negative values, m=0.246, μ=0.531, β=0.134.
#              corr_models 2023/09/13 09:37:45     INFO: Parameters initialized to λ=0.85, μ=0.53, σ=0.01, γ=0.8, k=0.59, m=0.25, α=0.049, β=0.13.
#              corr_models 2023/09/13 09:37:45     INFO: Converged.
#              corr_models 2023/09/13 09:37:45     INFO:
#              corr_models 2023/09/13 09:37:45     INFO: ********************************************************************************
#              corr_models 2023/09/13 09:37:45     INFO: Initializing model IntermittentGamma named 'GamFromGig' id(self)=140284578535552.
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.init_params = λ=34, μ=10, σ=0.011, γ=0.8, k=0.58, m=0.13
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.params      = λ=34, μ=10, σ=0.011, γ=0.8, k=0.58, m=0.13
#              corr_models 2023/09/13 09:37:45     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.5, γ_pr_strength=0
#              corr_models 2023/09/13 09:37:45     INFO: Plotting cdf for model: True Model, IntermittentGamma(λ=30, μ=5.3, σ=0.01, γ=0.8, k=0.61, m=0.49)
#              corr_models 2023/09/13 09:37:45     INFO: Plotting cdf for model: Gam, IntermittentGamma(λ=10, μ=6.1, σ=0.011, γ=0.8, k=1.3, m=0.54)
#              corr_models 2023/09/13 09:37:45     INFO: Plotting cdf for model: Gig, IntermittentGeneralizedInverseGaussian(λ=0.95, μ=0.83, σ=0.011, γ=0.8, k=0.58, m=0.13, α=0.056, β=0.16)
#              corr_models 2023/09/13 09:37:46     INFO: Plotting cdf for model: GamFromGig, IntermittentGamma(λ=34, μ=10, σ=0.011, γ=0.8, k=0.58, m=0.13)

# %% [markdown]
# # Real data

# %%
import os, sys
os.environ["FISHER_PLUMES"] = os.path.join(os.environ["GIT"],"fisher-plumes")
os.chdir(os.environ["FISHER_PLUMES"])
import units; reload(units); UNITS = units.UNITS;

# %%
import boulder;   reload(boulder)
import crick;     reload(crick)
import surrogate; reload(surrogate)
import fisher_plumes_tools as fpt;      reload(fpt)
import fisher_plumes_figs  as fpf;      reload(fpf);
import fisher_plumes_fig_tools as fpft; reload(fpft)
import fisher_plumes as fp;             reload(fp)
import utils; reload(utils); from utils import dict_update, dict_update_from_field
import proc; reload(proc);
FisherPlumes = fp.FisherPlumes
crick.logger.setLevel(logging.DEBUG)
fp.logger.setLevel(logging.INFO)
# Out:
# INFO:boulder:Boulder simulation data available for:
# INFO:boulder:Re100_0_5mm_50Hz_16source_manuscript.h5         : ['Odor Data/c1a', 'Odor Data/c1b', 'Odor Data/c2a', 'Odor Data/c2b', 'Odor Data/c3a', 'Odor Data/c3b', 'Odor Data/c4a', 'Odor Data/c4b', 'Odor Data/c5a', 'Odor Data/c5b', 'Odor Data/c6a', 'Odor Data/c6b', 'Odor Data/c7a', 'Odor Data/c7b', 'Odor Data/c8a', 'Odor Data/c8b'] (16 datasets)
# INFO:boulder:Boulder simulation data available for:
# INFO:boulder:Re100_0_5mm_50Hz_16source_manuscript.h5         : ['Odor Data/c1a', 'Odor Data/c1b', 'Odor Data/c2a', 'Odor Data/c2b', 'Odor Data/c3a', 'Odor Data/c3b', 'Odor Data/c4a', 'Odor Data/c4b', 'Odor Data/c5a', 'Odor Data/c5b', 'Odor Data/c6a', 'Odor Data/c6b', 'Odor Data/c7a', 'Odor Data/c7b', 'Odor Data/c8a', 'Odor Data/c8b'] (16 datasets)
# INFO:crick:Simulation data available for:
# INFO:crick:crimgrid_w1                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w2                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w3                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w4                                     : y0 - y9 (16 datasets)
# INFO:crick:n12T                                            : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n12Tslow                                        : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n12dishT                                        : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n16T                                            : Y0.440 - Y0.560 (16 datasets)
# INFO:crick:n16Tslow                                        : Y0.440 - Y0.560 (16 datasets)
# INFO:crick:Simulation data available for:
# INFO:crick:crimgrid_w1                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w2                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w3                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w4                                     : y0 - y9 (16 datasets)
# INFO:crick:n12T                                            : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n12Tslow                                        : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n12dishT                                        : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n16T                                            : Y0.440 - Y0.560 (16 datasets)
# INFO:crick:n16Tslow                                        : Y0.440 - Y0.560 (16 datasets)
# INFO:surrogate:Surrogate simulation data available for: ['no_info', 'one_info', 'two_info', 'high', 'spike_and_slab', 'blue', 'red', 'all_equal']
# INFO:surrogate:Surrogate simulation data available for: ['no_info', 'one_info', 'two_info', 'high', 'spike_and_slab', 'blue', 'red', 'all_equal']

# %%
window_length = 1 * UNITS.second
windows       = ['boxcar', 'hann', ('kaiser',9), ('kaiser', 16)]
window_shape  = windows[0]
fit_k         = False
fit_b         = True

# %%
to_use = {"16Ts":{"sim_name":"n16Tslow"},
          "bw":  {"sim_name":"boulder16"},
          "s=w": {"sim_name":"surr_all_equal", "surrogate_k": 0},
          "s=p": {"sim_name":"surr_all_equal", "surrogate_k": 4},
          "shw": {"sim_name":"surr_high",      "surrogate_k": 0},          
          "shp": {"sim_name":"surr_high",      "surrogate_k": 4},
          "s=w_q0":{"sim_name":"surr_quad",      "surrogate_k": 0, "phi":0},
          "s=w_q1":{"sim_name":"surr_quad",      "surrogate_k": 0, "phi":pi/3},
}

# %%
type(loaded["16Ts"])
# Out:
# dict

# %%
safe_load = lambda d: d[0] if d is not None else d
[f.logger.setLevel(logging.WARN) for f in [crick, boulder,fp]];
loaded = {k:safe_load(proc.load_data(init_filter = v,
                                       compute_filter = {
                                           "window_shape":window_shape,
                                           "window_length":window_length,
                                           "fit_k":fit_k,
                                           "fit_b":fit_b,
                                       }))
          for k,v in to_use.items()}

data =  {k:FisherPlumes(d) for k,d in loaded.items() if d is not None}

for k, l in loaded.items():
    if l is None:
        print(f"WARNING: No data for {k=}")

[f.logger.setLevel(logging.INFO) for f in [crick, boulder,fp]];
# Out:
#                     proc 2023/09/13 13:47:09     INFO: Loading init_filter={'sim_name': 'n16Tslow'} compute_filter={'window_shape': 'boxcar', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/n16Ts.1/8ce1f67f387e66d4.p
#                     proc 2023/09/13 13:47:14     INFO: Returning 1 results.
#                     proc 2023/09/13 13:47:14     INFO: Loading init_filter={'sim_name': 'boulder16'} compute_filter={'window_shape': 'boxcar', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/bw.1/68a5c7b1f718189b.p
#                     proc 2023/09/13 13:47:15     INFO: Returning 1 results.
#                     proc 2023/09/13 13:47:15     INFO: Loading init_filter={'sim_name': 'surr_all_equal', 'surrogate_k': 0} compute_filter={'window_shape': 'boxcar', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/s=w.1/70fcf788dfbe988d.p
#                     proc 2023/09/13 13:47:16     INFO: Returning 1 results.
#                     proc 2023/09/13 13:47:16     INFO: Loading init_filter={'sim_name': 'surr_all_equal', 'surrogate_k': 4} compute_filter={'window_shape': 'boxcar', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/s=p.1/51df97cff474b45b.p
#                     proc 2023/09/13 13:47:18     INFO: Returning 1 results.
#                     proc 2023/09/13 13:47:18     INFO: Loading init_filter={'sim_name': 'surr_high', 'surrogate_k': 0} compute_filter={'window_shape': 'boxcar', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/shw.1/0fd8aafa793ef13c.p
#                     proc 2023/09/13 13:47:19     INFO: Returning 1 results.
#                     proc 2023/09/13 13:47:19     INFO: Loading init_filter={'sim_name': 'surr_high', 'surrogate_k': 4} compute_filter={'window_shape': 'boxcar', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/shp.1/9ef1f2cd82d249a0.p
#                     proc 2023/09/13 13:47:20     INFO: Returning 1 results.
#                     proc 2023/09/13 13:47:20     INFO: Loading init_filter={'sim_name': 'surr_quad', 'surrogate_k': 0, 'phi': 0} compute_filter={'window_shape': 'boxcar', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/s=w_q.1/d33385af950cea0d.p
#                     proc 2023/09/13 13:47:21     INFO: Returning 1 results.
#                     proc 2023/09/13 13:47:21     INFO: Loading init_filter={'sim_name': 'surr_quad', 'surrogate_k': 0, 'phi': 1.0471975511965976} compute_filter={'window_shape': 'boxcar', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/s=w_q.2/2278089abc434303.p
#                     proc 2023/09/13 13:47:22     INFO: Returning 1 results.
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -56250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S0'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-59.10548154],
#        [ 35.2562945 ],
#        [-38.69660792],
#        ...,
#        [ 34.57781868],
#        [ -3.27081684],
#        [-59.10548154]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -56250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S0'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-59.10548154],
#        [ 35.2562945 ],
#        [-38.69660792],
#        ...,
#        [ 34.57781868],
#        [ -3.27081684],
#        [-59.10548154]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -48750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S1'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-34.8066426 ],
#        [ 43.82380139],
#        [-18.10450163],
#        ...,
#        [ 40.19624256],
#        [-15.65682817],
#        [-34.8066426 ]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -41250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S2'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-28.97564641],
#        [ 37.15857913],
#        [-41.8924706 ],
#        ...,
#        [ 29.51571216],
#        [-33.07679923],
#        [-28.97564641]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -33750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S3'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[  0.09667675],
#        [ 17.15605786],
#        [-22.76591961],
#        ...,
#        [ 14.80597364],
#        [-32.5007697 ],
#        [  0.09667675]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -26250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S4'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-54.5278579 ],
#        [ 31.51239671],
#        [-47.64004882],
#        ...,
#        [  8.26059954],
#        [-20.55958392],
#        [-54.5278579 ]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -18750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S5'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-48.35916503],
#        [ 45.96442053],
#        [-25.01993076],
#        ...,
#        [ -7.29143947],
#        [-23.64727656],
#        [-48.35916503]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -11250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S6'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-50.55704307],
#        [ 41.24139666],
#        [ -7.55622495],
#        ...,
#        [ -4.75087879],
#        [ -2.98271267],
#        [-50.55704307]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([    0. -3750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S7'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-14.44633995],
#        [ 56.33865616],
#        [ -6.5564151 ],
#        ...,
#        [ 21.55376075],
#        [ 20.56034844],
#        [-14.44633995]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([   0. 3750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S8'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-19.18887802],
#        [ 68.03417363],
#        [ -5.47800054],
#        ...,
#        [-45.58270935],
#        [ 22.17898333],
#        [-19.18887802]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
# ...
#         -71.37121462,  23.62859485]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[ 1.00000000e+00,  2.50000000e-01,  1.25000000e-01, ...,
#         -1.05715992e-04, -5.28579958e-05, -2.64289979e-05],
#        [ 2.50000000e-01,  1.00000000e+00,  2.50000000e-01, ...,
#         -2.11431983e-04, -1.05715992e-04, -5.28579958e-05],
#        [ 1.25000000e-01,  2.50000000e-01,  1.00000000e+00, ...,
#         -4.22863967e-04, -2.11431983e-04, -1.05715992e-04],
#        ...,
#        [-1.05715992e-04, -2.11431983e-04, -4.22863967e-04, ...,
#          1.00000000e+00,  2.50000000e-01,  1.25000000e-01],
#        [-5.28579958e-05, -1.05715992e-04, -2.11431983e-04, ...,
#          2.50000000e-01,  1.00000000e+00,  2.50000000e-01],
#        [-2.64289979e-05, -5.28579958e-05, -1.05715992e-04, ...,
#          1.25000000e-01,  2.50000000e-01,  1.00000000e+00]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'quad', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_quad_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_quad_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_quad_pitch')>, 'y': <Quantity([[0]], 'surr_quad_pitch')>}, 'x': <Quantity([10], 'surr_quad_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_quad_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_quad_pitch')>, <Quantity(10, 'surr_quad_pitch')>], 'y_lim': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'source': <Quantity([    0. 41250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'fields': ['S13'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'quad', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'phi': 1.0471975511965976, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[ -6.92404524],
#        [-40.39761547],
#        [  2.50464286],
#        ...,
#        [ 50.39836973],
#        [-12.13207052],
#        [ -6.92404524]]), 'nt': 3001, 'c': array([[ 1.76405235,  0.82846364,  1.2564624 , ...,  0.47276232,
#          0.63362831,  0.52423855],
#        [-0.88778575, -2.13984437, -0.8945978 , ..., -0.46941495,
#         -1.3314329 ,  0.40952886],
#        [ 0.17742614, -0.34466618, -1.64351493, ..., -0.82458199,
#         -0.56341031, -0.14681787],
#        ...,
#        [-0.14331315,  0.03073311,  0.57065177, ..., -0.773345  ,
#         -0.80698412, -0.22809732],
#        [ 0.925733  ,  2.33588161,  1.18617844, ...,  0.87031558,
#          0.76618868,  2.06066851],
#        [-0.62405388, -0.4350677 , -0.2639882 , ..., -0.69299892,
#         -0.30490032,  0.09155918]]), 's': array([[ 1.70545815,  0.17742492,  1.52406063, ...,  0.22239455,
#          0.26449227,  0.89487101],
#        [-2.33901382, -0.3385047 ,  0.10022246, ..., -0.84969923,
#         -0.39612789, -1.00917376],
#        [-1.3989365 , -0.39719692,  0.03087951, ...,  1.19497523,
#          0.9667504 ,  1.4963462 ],
#        ...,
#        [ 0.21547655,  0.53908094, -0.54803681, ..., -0.74585253,
#          1.57666895,  1.04639066],
#        [ 0.17462559,  0.64189124, -2.09751742, ...,  0.89710145,
#          0.39956768, -0.74096399],
#        [-0.97838942, -0.82640367,  0.8039547 , ..., -1.46635496,
#         -0.19610938, -0.78272994]]), 'X': array([[-59.10548154,  39.85129852, -38.88205781, ...,  34.76326856,
#          -7.86582086, -59.10548154],
#        [ 11.72520906,  49.40969037,  12.8582053 , ...,  31.7210257 ,
#         -39.09943121,  11.72520906],
#        [ -3.04537335,  13.40222049, -51.98474926, ...,   5.2071827 ,
#         -43.12579257,  -3.04537335],
#        ...,
#        [ -6.92404524, -40.39761547,   2.50464286, ...,  50.39836973,
#         -12.13207052,  -6.92404524],
#        [-17.90394882,  32.83156048, -22.00845732, ...,  81.28075257,
#         -19.18707923, -17.90394882],
#        [ 23.62859485, -10.37340181, -45.43897195, ...,  55.05468827,
#         -71.37121462,  23.62859485]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[ 1.00000000e+00,  2.50000000e-01,  1.25000000e-01, ...,
#         -1.05715992e-04, -5.28579958e-05, -2.64289979e-05],
#        [ 2.50000000e-01,  1.00000000e+00,  2.50000000e-01, ...,
#         -2.11431983e-04, -1.05715992e-04, -5.28579958e-05],
#        [ 1.25000000e-01,  2.50000000e-01,  1.00000000e+00, ...,
#         -4.22863967e-04, -2.11431983e-04, -1.05715992e-04],
#        ...,
#        [-1.05715992e-04, -2.11431983e-04, -4.22863967e-04, ...,
#          1.00000000e+00,  2.50000000e-01,  1.25000000e-01],
#        [-5.28579958e-05, -1.05715992e-04, -2.11431983e-04, ...,
#          2.50000000e-01,  1.00000000e+00,  2.50000000e-01],
#        [-2.64289979e-05, -5.28579958e-05, -1.05715992e-04, ...,
#          1.25000000e-01,  2.50000000e-01,  1.00000000e+00]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'quad', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_quad_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_quad_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_quad_pitch')>, 'y': <Quantity([[0]], 'surr_quad_pitch')>}, 'x': <Quantity([10], 'surr_quad_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_quad_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_quad_pitch')>, <Quantity(10, 'surr_quad_pitch')>], 'y_lim': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'source': <Quantity([    0. 48750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'fields': ['S14'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'quad', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'phi': 1.0471975511965976, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-17.90394882],
#        [ 32.83156048],
#        [-22.00845732],
#        ...,
#        [ 81.28075257],
#        [-19.18707923],
#        [-17.90394882]]), 'nt': 3001, 'c': array([[ 1.76405235,  0.82846364,  1.2564624 , ...,  0.47276232,
#          0.63362831,  0.52423855],
#        [-0.88778575, -2.13984437, -0.8945978 , ..., -0.46941495,
#         -1.3314329 ,  0.40952886],
#        [ 0.17742614, -0.34466618, -1.64351493, ..., -0.82458199,
#         -0.56341031, -0.14681787],
#        ...,
#        [-0.14331315,  0.03073311,  0.57065177, ..., -0.773345  ,
#         -0.80698412, -0.22809732],
#        [ 0.925733  ,  2.33588161,  1.18617844, ...,  0.87031558,
#          0.76618868,  2.06066851],
#        [-0.62405388, -0.4350677 , -0.2639882 , ..., -0.69299892,
#         -0.30490032,  0.09155918]]), 's': array([[ 1.70545815,  0.17742492,  1.52406063, ...,  0.22239455,
#          0.26449227,  0.89487101],
#        [-2.33901382, -0.3385047 ,  0.10022246, ..., -0.84969923,
#         -0.39612789, -1.00917376],
#        [-1.3989365 , -0.39719692,  0.03087951, ...,  1.19497523,
#          0.9667504 ,  1.4963462 ],
#        ...,
#        [ 0.21547655,  0.53908094, -0.54803681, ..., -0.74585253,
#          1.57666895,  1.04639066],
#        [ 0.17462559,  0.64189124, -2.09751742, ...,  0.89710145,
#          0.39956768, -0.74096399],
#        [-0.97838942, -0.82640367,  0.8039547 , ..., -1.46635496,
#         -0.19610938, -0.78272994]]), 'X': array([[-59.10548154,  39.85129852, -38.88205781, ...,  34.76326856,
#          -7.86582086, -59.10548154],
#        [ 11.72520906,  49.40969037,  12.8582053 , ...,  31.7210257 ,
#         -39.09943121,  11.72520906],
#        [ -3.04537335,  13.40222049, -51.98474926, ...,   5.2071827 ,
#         -43.12579257,  -3.04537335],
#        ...,
#        [ -6.92404524, -40.39761547,   2.50464286, ...,  50.39836973,
#         -12.13207052,  -6.92404524],
#        [-17.90394882,  32.83156048, -22.00845732, ...,  81.28075257,
#         -19.18707923, -17.90394882],
#        [ 23.62859485, -10.37340181, -45.43897195, ...,  55.05468827,
#         -71.37121462,  23.62859485]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[ 1.00000000e+00,  2.50000000e-01,  1.25000000e-01, ...,
#         -1.05715992e-04, -5.28579958e-05, -2.64289979e-05],
#        [ 2.50000000e-01,  1.00000000e+00,  2.50000000e-01, ...,
#         -2.11431983e-04, -1.05715992e-04, -5.28579958e-05],
#        [ 1.25000000e-01,  2.50000000e-01,  1.00000000e+00, ...,
#         -4.22863967e-04, -2.11431983e-04, -1.05715992e-04],
#        ...,
#        [-1.05715992e-04, -2.11431983e-04, -4.22863967e-04, ...,
#          1.00000000e+00,  2.50000000e-01,  1.25000000e-01],
#        [-5.28579958e-05, -1.05715992e-04, -2.11431983e-04, ...,
#          2.50000000e-01,  1.00000000e+00,  2.50000000e-01],
#        [-2.64289979e-05, -5.28579958e-05, -1.05715992e-04, ...,
#          1.25000000e-01,  2.50000000e-01,  1.00000000e+00]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'quad', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_quad_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_quad_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_quad_pitch')>, 'y': <Quantity([[0]], 'surr_quad_pitch')>}, 'x': <Quantity([10], 'surr_quad_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_quad_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_quad_pitch')>, <Quantity(10, 'surr_quad_pitch')>], 'y_lim': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'source': <Quantity([    0. 56250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'fields': ['S15'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'quad', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'phi': 1.0471975511965976, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[ 23.62859485],
#        [-10.37340181],
#        [-45.43897195],
#        ...,
#        [ 55.05468827],
#        [-71.37121462],
#        [ 23.62859485]]), 'nt': 3001, 'c': array([[ 1.76405235,  0.82846364,  1.2564624 , ...,  0.47276232,
#          0.63362831,  0.52423855],
#        [-0.88778575, -2.13984437, -0.8945978 , ..., -0.46941495,
#         -1.3314329 ,  0.40952886],
#        [ 0.17742614, -0.34466618, -1.64351493, ..., -0.82458199,
#         -0.56341031, -0.14681787],
#        ...,
#        [-0.14331315,  0.03073311,  0.57065177, ..., -0.773345  ,
#         -0.80698412, -0.22809732],
#        [ 0.925733  ,  2.33588161,  1.18617844, ...,  0.87031558,
#          0.76618868,  2.06066851],
#        [-0.62405388, -0.4350677 , -0.2639882 , ..., -0.69299892,
#         -0.30490032,  0.09155918]]), 's': array([[ 1.70545815,  0.17742492,  1.52406063, ...,  0.22239455,
#          0.26449227,  0.89487101],
#        [-2.33901382, -0.3385047 ,  0.10022246, ..., -0.84969923,
#         -0.39612789, -1.00917376],
#        [-1.3989365 , -0.39719692,  0.03087951, ...,  1.19497523,
#          0.9667504 ,  1.4963462 ],
#        ...,
#        [ 0.21547655,  0.53908094, -0.54803681, ..., -0.74585253,
#          1.57666895,  1.04639066],
#        [ 0.17462559,  0.64189124, -2.09751742, ...,  0.89710145,
#          0.39956768, -0.74096399],
#        [-0.97838942, -0.82640367,  0.8039547 , ..., -1.46635496,
#         -0.19610938, -0.78272994]]), 'X': array([[-59.10548154,  39.85129852, -38.88205781, ...,  34.76326856,
#          -7.86582086, -59.10548154],
#        [ 11.72520906,  49.40969037,  12.8582053 , ...,  31.7210257 ,
#         -39.09943121,  11.72520906],
#        [ -3.04537335,  13.40222049, -51.98474926, ...,   5.2071827 ,
#         -43.12579257,  -3.04537335],
#        ...,
#        [ -6.92404524, -40.39761547,   2.50464286, ...,  50.39836973,
#         -12.13207052,  -6.92404524],
#        [-17.90394882,  32.83156048, -22.00845732, ...,  81.28075257,
#         -19.18707923, -17.90394882],
#        [ 23.62859485, -10.37340181, -45.43897195, ...,  55.05468827,
#         -71.37121462,  23.62859485]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[ 1.00000000e+00,  2.50000000e-01,  1.25000000e-01, ...,
#         -1.05715992e-04, -5.28579958e-05, -2.64289979e-05],
#        [ 2.50000000e-01,  1.00000000e+00,  2.50000000e-01, ...,
#         -2.11431983e-04, -1.05715992e-04, -5.28579958e-05],
#        [ 1.25000000e-01,  2.50000000e-01,  1.00000000e+00, ...,
#         -4.22863967e-04, -2.11431983e-04, -1.05715992e-04],
#        ...,
#        [-1.05715992e-04, -2.11431983e-04, -4.22863967e-04, ...,
#          1.00000000e+00,  2.50000000e-01,  1.25000000e-01],
#        [-5.28579958e-05, -1.05715992e-04, -2.11431983e-04, ...,
#          2.50000000e-01,  1.00000000e+00,  2.50000000e-01],
#        [-2.64289979e-05, -5.28579958e-05, -1.05715992e-04, ...,
#          1.25000000e-01,  2.50000000e-01,  1.00000000e+00]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)

# %%
def get_data(ds, idist, ifreq, iprb=0):
    F = data[ds]
    dd= array(list(F.pairs_um.keys()))
    dd= dd[dd>=0]
    d = dd[idist]
    f = ifreq
    print(f"Returning data for ds={ds}, d={d}, freq={F.freqs[f]:.1f}")
    y  = F.rho[iprb][d][0][f]
    la = F.la[iprb][d][0,f,0]
    mu = F.mu[iprb][d][0,f,0]
    print(f"la={la:.2g}, mu={mu:.2g}, {std(y)=:.2g}")
    la_ = la/std(y)
    mu_ = mu/std(y)
    y_  =  y/std(y)
    print(f"la_={la_:.2g}, mu_={mu_:.2g}, {std(y_)=:.2g}")
    return y_

# %%
data["16Ts"].rho[0][0].shape
# Out:
# (51, 51, 4448)

# %%
y_ = get_data("16Ts", 0, 0)
plot(y_)
# Out:
# Returning data for ds=16Ts, d=0, freq=0.0 hertz
# la=3.2e-31, mu=1.9e-64, std(y)=2.8e-30
# la_=0.12, mu_=6.8e-35, std(y_)=1

# %%
reload(fpt)
reload(corrm)
Exp0 = corrm.CorrModel(model = "exp", name = "Exp0", intermittent = False, σ_penalty = 0, γ_pr_mean = 0.95, γ_pr_strength = 1)
Exp0.fit(y_)
Exp = corrm.CorrModel(model = "exp", name = "Exp", intermittent = True, σ_penalty = 0, γ_pr_mean = 0.95, γ_pr_strength = 1)
Exp.fit(y_)
Gam = corrm.CorrModel(model = "gamma", name = "Gam", intermittent = True, init_params = Exp.models[-1].params)
Gam.fit(y_, method = "TNC")
Gig = corrm.CorrModel(model = "gig", name="Gig",intermittent = True, init_params = Gam.models[-1].params)
Gig.fit(y_, method = "TNC")
Gig0 = corrm.CorrModel(model = "gig", name="Gig0",intermittent = False, init_params = Gig.models[-1].params)
Gig0.fit(y_, method = "TNC")
Gam0 = corrm.CorrModel(model = "gamma", name="Gam0",intermittent = False, init_params = Gam.models[-1].params)
Gam0.fit(y_, method = "TNC")

#Gam2 = corrm.IntermittentGamma(init_params = Gig0.model.params, name="GamFromGig")
figure(figsize=(12,5))
corrm.plot_cdfs(y_, [Exp0, Exp, Gam, Gig], legend_args={"labelspacing":0, "fontsize":6, "loc":"lower right"})
# Out:
#              corr_models 2023/09/13 14:51:05     INFO: ********************************************************************************
#              corr_models 2023/09/13 14:51:05     INFO: Initializing model IntermittentExponential named 'Model' id(self)=140281644064576.
#              corr_models 2023/09/13 14:51:05     INFO: Initialized self.init_params = None
#              corr_models 2023/09/13 14:51:05     INFO: Initialized self.params      = None
#              corr_models 2023/09/13 14:51:05     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=1, γ_pr_strength=inf
#              corr_models 2023/09/13 14:51:05     INFO: Fitting IntermittentExponential model Model.
#              corr_models 2023/09/13 14:51:05     INFO: Initializing from fit using γ=1.
#              corr_models 2023/09/13 14:51:05     INFO: Found 0 intermittent points, 4423 positive, 0 negative values.
#              corr_models 2023/09/13 14:51:05     INFO: Fit exponential distribution to positive values, λ=0.0588.
#              corr_models 2023/09/13 14:51:05     INFO: No negative values, setting μ=1e-06.
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#              corr_models 2023/09/13 14:51:05     INFO: Parameters initialized to λ=0.059, μ=1e-06, σ=nan, γ=1.
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    0: n+=4448, n-=   0 n0=   0 λ=0.058, μ=1e-06, σ=0, γ=1
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    1: n+=4448, n-=   0 n0=   0 λ=0.058, μ=1e-06, σ=0, γ=1
#              corr_models 2023/09/13 14:51:05     INFO: Converged in    1 iterations to n+=4448, n-=   0 n0=   0 λ=0.058, μ=1e-06, σ=0, γ=1
#              corr_models 2023/09/13 14:51:05     INFO: ********************************************************************************
#              corr_models 2023/09/13 14:51:05     INFO: Initializing model IntermittentExponential named 'Model' id(self)=140281871270960.
#              corr_models 2023/09/13 14:51:05     INFO: Initialized self.init_params = None
#              corr_models 2023/09/13 14:51:05     INFO: Initialized self.params      = None
#              corr_models 2023/09/13 14:51:05     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.95, γ_pr_strength=1
#              corr_models 2023/09/13 14:51:05     INFO: Fitting IntermittentExponential model Model.
#              corr_models 2023/09/13 14:51:05     INFO: Initializing from fit using γ=0.95.
#              corr_models 2023/09/13 14:51:05     INFO: Found 223 intermittent points, 4225 positive, 0 negative values.
#              corr_models 2023/09/13 14:51:05     INFO: Fit exponential distribution to positive values, λ=0.0615.
#              corr_models 2023/09/13 14:51:05     INFO: No negative values, setting μ=1e-06.
#              corr_models 2023/09/13 14:51:05     INFO: Parameters initialized to λ=0.062, μ=1e-06, σ=4.1e-06, γ=0.95.
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    0: n+=4225, n-=   0 n0= 223 λ=0.062, μ=1e-06, σ=6.1e-06, γ=0.95
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    1: n+=4187, n-=   0 n0= 261 λ=0.062, μ=1e-06, σ=8.4e-06, γ=0.95
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    2: n+=4159, n-=   0 n0= 289 λ=0.063, μ=1e-06, σ=1.1e-05, γ=0.94
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    3: n+=4110, n-=   0 n0= 338 λ=0.063, μ=1e-06, σ=1.5e-05, γ=0.94
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    4: n+=4068, n-=   0 n0= 380 λ=0.064, μ=1e-06, σ=2e-05, γ=0.93
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    5: n+=4017, n-=   0 n0= 431 λ=0.065, μ=1e-06, σ=2.7e-05, γ=0.93
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    6: n+=3972, n-=   0 n0= 476 λ=0.065, μ=1e-06, σ=3.3e-05, γ=0.92
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    7: n+=3929, n-=   0 n0= 519 λ=0.066, μ=1e-06, σ=4.1e-05, γ=0.92
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    8: n+=3880, n-=   0 n0= 568 λ=0.067, μ=1e-06, σ=5e-05, γ=0.91
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    9: n+=3810, n-=   0 n0= 638 λ=0.068, μ=1e-06, σ=6.3e-05, γ=0.9
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   10: n+=3728, n-=   0 n0= 720 λ=0.07, μ=1e-06, σ=8.1e-05, γ=0.89
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   11: n+=3676, n-=   0 n0= 772 λ=0.071, μ=1e-06, σ=9.4e-05, γ=0.89
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   12: n+=3618, n-=   0 n0= 830 λ=0.072, μ=1e-06, σ=0.00011, γ=0.88
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   13: n+=3554, n-=   0 n0= 894 λ=0.073, μ=1e-06, σ=0.00013, γ=0.87
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   14: n+=3495, n-=   0 n0= 953 λ=0.074, μ=1e-06, σ=0.00015, γ=0.87
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   15: n+=3441, n-=   0 n0=1007 λ=0.076, μ=1e-06, σ=0.00017, γ=0.86
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   16: n+=3379, n-=   0 n0=1069 λ=0.077, μ=1e-06, σ=0.00019, γ=0.85
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   17: n+=3346, n-=   0 n0=1102 λ=0.078, μ=1e-06, σ=0.0002, γ=0.85
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   18: n+=3296, n-=   0 n0=1152 λ=0.079, μ=1e-06, σ=0.00023, γ=0.85
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   19: n+=3255, n-=   0 n0=1193 λ=0.08, μ=1e-06, σ=0.00024, γ=0.84
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   20: n+=3209, n-=   0 n0=1239 λ=0.081, μ=1e-06, σ=0.00027, γ=0.84
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   21: n+=3163, n-=   0 n0=1285 λ=0.082, μ=1e-06, σ=0.00029, γ=0.83
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   22: n+=3130, n-=   0 n0=1318 λ=0.083, μ=1e-06, σ=0.00031, γ=0.83
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   23: n+=3105, n-=   0 n0=1343 λ=0.084, μ=1e-06, σ=0.00032, γ=0.82
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   24: n+=3089, n-=   0 n0=1359 λ=0.084, μ=1e-06, σ=0.00033, γ=0.82
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   25: n+=3061, n-=   0 n0=1387 λ=0.085, μ=1e-06, σ=0.00034, γ=0.82
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   26: n+=3042, n-=   0 n0=1406 λ=0.085, μ=1e-06, σ=0.00036, γ=0.82
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   27: n+=3016, n-=   0 n0=1432 λ=0.086, μ=1e-06, σ=0.00037, γ=0.81
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   28: n+=2960, n-=   0 n0=1488 λ=0.088, μ=1e-06, σ=0.0004, γ=0.81
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   29: n+=2923, n-=   0 n0=1525 λ=0.089, μ=1e-06, σ=0.00043, γ=0.8
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   30: n+=2894, n-=   0 n0=1554 λ=0.09, μ=1e-06, σ=0.00044, γ=0.8
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   31: n+=2881, n-=   0 n0=1567 λ=0.09, μ=1e-06, σ=0.00045, γ=0.8
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   32: n+=2858, n-=   0 n0=1590 λ=0.091, μ=1e-06, σ=0.00047, γ=0.8
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   33: n+=2842, n-=   0 n0=1606 λ=0.091, μ=1e-06, σ=0.00048, γ=0.79
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   34: n+=2816, n-=   0 n0=1632 λ=0.092, μ=1e-06, σ=0.0005, γ=0.79
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   35: n+=2801, n-=   0 n0=1647 λ=0.093, μ=1e-06, σ=0.00051, γ=0.79
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   36: n+=2770, n-=   0 n0=1678 λ=0.094, μ=1e-06, σ=0.00053, γ=0.79
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   37: n+=2728, n-=   0 n0=1720 λ=0.095, μ=1e-06, σ=0.00056, γ=0.78
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   38: n+=2694, n-=   0 n0=1754 λ=0.096, μ=1e-06, σ=0.00059, γ=0.78
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   39: n+=2678, n-=   0 n0=1770 λ=0.097, μ=1e-06, σ=0.0006, γ=0.78
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   40: n+=2651, n-=   0 n0=1797 λ=0.098, μ=1e-06, σ=0.00062, γ=0.77
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   41: n+=2638, n-=   0 n0=1810 λ=0.098, μ=1e-06, σ=0.00063, γ=0.77
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   42: n+=2621, n-=   0 n0=1827 λ=0.099, μ=1e-06, σ=0.00064, γ=0.77
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   43: n+=2610, n-=   0 n0=1838 λ=0.099, μ=1e-06, σ=0.00065, γ=0.77
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   44: n+=2608, n-=   0 n0=1840 λ=0.099, μ=1e-06, σ=0.00065, γ=0.77
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   45: n+=2580, n-=   0 n0=1868 λ=0.1, μ=1e-06, σ=0.00068, γ=0.77
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   46: n+=2569, n-=   0 n0=1879 λ=0.1, μ=1e-06, σ=0.00069, γ=0.76
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   47: n+=2549, n-=   0 n0=1899 λ=0.1, μ=1e-06, σ=0.0007, γ=0.76
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   48: n+=2537, n-=   0 n0=1911 λ=0.1, μ=1e-06, σ=0.00071, γ=0.76
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   49: n+=2536, n-=   0 n0=1912 λ=0.1, μ=1e-06, σ=0.00071, γ=0.76
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter   50: n+=2536, n-=   0 n0=1912 λ=0.1, μ=1e-06, σ=0.00071, γ=0.76
#              corr_models 2023/09/13 14:51:05     INFO: Converged in   50 iterations to n+=2536, n-=   0 n0=1912 λ=0.1, μ=1e-06, σ=0.00071, γ=0.76
#              corr_models 2023/09/13 14:51:05     INFO: ********************************************************************************
#              corr_models 2023/09/13 14:51:05     INFO: Initializing model IntermittentGamma named 'Model' id(self)=140281871273744.
#              corr_models 2023/09/13 14:51:05     INFO: Casting IntermittentExponential to IntermittentGamma.
#              corr_models 2023/09/13 14:51:05     INFO: Cast params: λ=0.1, μ=1e-06, σ=0.00071, γ=0.76 -> λ=0.1, μ=1e-06, σ=0.00071, γ=0.76, k=1, m=1
#              corr_models 2023/09/13 14:51:05     INFO: Initialized self.init_params = λ=0.1, μ=1e-06, σ=0.00071, γ=0.76, k=1, m=1
#              corr_models 2023/09/13 14:51:05     INFO: Initialized self.params      = λ=0.1, μ=1e-06, σ=0.00071, γ=0.76, k=1, m=1
#              corr_models 2023/09/13 14:51:05     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.5, γ_pr_strength=1
#              corr_models 2023/09/13 14:51:05     INFO: Fitting IntermittentGamma model Model.
# /nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py:566: RuntimeWarning: divide by zero encountered in log
#   lrho[y>=0] = -np.log(Z) + (k - 1)*np.log(y[y>=0]) - y[y>=0]/λ
# /nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py:566: RuntimeWarning: invalid value encountered in multiply
#   lrho[y>=0] = -np.log(Z) + (k - 1)*np.log(y[y>=0]) - y[y>=0]/λ
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    0: n+=2536, n-=   0 n0=1912 λ=0.34, μ=1e-06, σ=0.00071, γ=0.54, k=0.3, m=1
# /nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py:598: RuntimeWarning: divide by zero encountered in log
#   lypm = np.mean(np.log(y[ip])) if n_p else 0
# /camp/home/tootoos/working/tootoos/conda-envs/py38/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    1: n+=2961, n-=   0 n0=1487 λ=0.34, μ=1e-06, σ=0.00076, γ=0.58, k=0.3, m=1
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    2: n+=3026, n-=   0 n0=1422 λ=0.34, μ=1e-06, σ=0.00078, γ=0.59, k=0.3, m=1
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    3: n+=3053, n-=   0 n0=1395 λ=0.34, μ=1e-06, σ=0.00079, γ=0.59, k=0.3, m=1
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    4: n+=3045, n-=   0 n0=1403 λ=0.34, μ=1e-06, σ=0.00079, γ=0.59, k=0.3, m=1
#              corr_models 2023/09/13 14:51:05    DEBUG: Iter    5: n+=3045, n-=   0 n0=1403 λ=0.34, μ=1e-06, σ=0.00079, γ=0.59, k=0.3, m=1
#              corr_models 2023/09/13 14:51:05    DEBUG: Converged in    5 iterations to n+=3045, n-=   0 n0=1403 λ=0.34, μ=1e-06, σ=0.00079, γ=0.59, k=0.3, m=1
#              corr_models 2023/09/13 14:51:05     INFO: ********************************************************************************
#              corr_models 2023/09/13 14:51:05     INFO: Initializing model IntermittentGeneralizedInverseGaussian named 'Model' id(self)=140283607262112.
#              corr_models 2023/09/13 14:51:06     INFO: Casting IntermittentGamma to IntermittentGeneralizedInversGaussian.
#              corr_models 2023/09/13 14:51:06     INFO: Cast params: λ=0.34, μ=1e-06, σ=0.00079, γ=0.59, k=0.3, m=1 -> λ=0.00029, μ=5e-07, σ=0.00079, γ=0.59, k=0.3, m=1, α=0.0017, β=1
#              corr_models 2023/09/13 14:51:06     INFO: Initialized self.init_params = λ=0.00029, μ=5e-07, σ=0.00079, γ=0.59, k=0.3, m=1, α=0.0017, β=1
#              corr_models 2023/09/13 14:51:06     INFO: Initialized self.params      = λ=0.00029, μ=5e-07, σ=0.00079, γ=0.59, k=0.3, m=1, α=0.0017, β=1
#              corr_models 2023/09/13 14:51:06     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.5, γ_pr_strength=1
#              corr_models 2023/09/13 14:51:06     INFO: Fitting IntermittentGeneralizedInverseGaussian model Model.
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000292, 1e-06, 0.3, 1.01, 0.00171, 1
#              corr_models 2023/09/13 14:51:06    DEBUG: Max. number of function evaluations reached after 18 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    0: n+=3033, n-=   0 n0=1415 λ=0.0004, μ=7.5e-07, σ=0.00079, γ=0.59, k=0.22, m=0.45, α=0.0019, β=1.4
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000403, 1e-06, 0.219, 0.453, 0.00186, 1.37
#              corr_models 2023/09/13 14:51:06    DEBUG: Max. number of function evaluations reached after 15 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    1: n+=3139, n-=   0 n0=1309 λ=0.0005, μ=8.8e-07, σ=0.00081, γ=0.6, k=0.17, m=0.22, α=0.0021, β=1.9
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000505, 1e-06, 0.17, 0.221, 0.00208, 1.91
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 10 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    2: n+=3268, n-=   0 n0=1180 λ=0.00058, μ=9.4e-07, σ=0.00081, γ=0.62, k=0.14, m=0.025, α=0.0023, β=2.6
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.00058, 1e-06, 0.14, 0.0253, 0.00227, 2.56
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 9 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    3: n+=3353, n-=   0 n0=1095 λ=0.00063, μ=9.7e-07, σ=0.00083, γ=0.63, k=0.12, m=0.06, α=0.0024, β=2.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000634, 1e-06, 0.122, 0.0599, 0.00242, 2.55
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 9 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    4: n+=3397, n-=   0 n0=1051 λ=0.00067, μ=9.8e-07, σ=0.00084, γ=0.63, k=0.11, m=0.06, α=0.0025, β=2.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000669, 1e-06, 0.11, 0.0603, 0.00252, 2.55
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 5 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    5: n+=3426, n-=   0 n0=1022 λ=0.00069, μ=9.9e-07, σ=0.00085, γ=0.64, k=0.1, m=0.06, α=0.0026, β=2.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000691, 1e-06, 0.104, 0.0603, 0.00258, 2.55
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 14 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    6: n+=3452, n-=   0 n0= 996 λ=0.00071, μ=1e-06, σ=0.00086, γ=0.64, k=0.099, m=0.047, α=0.0026, β=2.7
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000708, 1e-06, 0.0991, 0.0468, 0.00263, 2.75
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 7 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    7: n+=3468, n-=   0 n0= 980 λ=0.00072, μ=1e-06, σ=0.00087, γ=0.64, k=0.096, m=0.047, α=0.0027, β=2.7
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000719, 1e-06, 0.0964, 0.0468, 0.00267, 2.75
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 4 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    8: n+=3488, n-=   0 n0= 960 λ=0.00073, μ=1e-06, σ=0.00088, γ=0.64, k=0.094, m=0.047, α=0.0027, β=2.7
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000728, 1e-06, 0.0942, 0.0468, 0.0027, 2.75
#              corr_models 2023/09/13 14:51:06    DEBUG: Max. number of function evaluations reached after 14 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    9: n+=3478, n-=   0 n0= 970 λ=0.00073, μ=1e-06, σ=0.00089, γ=0.64, k=0.093, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000733, 1e-06, 0.0931, 0.046, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 7 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter   10: n+=3476, n-=   0 n0= 972 λ=0.00073, μ=1e-06, σ=0.00089, γ=0.64, k=0.093, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000734, 1e-06, 0.0926, 0.046, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 4 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter   11: n+=3476, n-=   0 n0= 972 λ=0.00073, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000735, 1e-06, 0.0924, 0.0459, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 3 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter   12: n+=3476, n-=   0 n0= 972 λ=0.00074, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000736, 1e-06, 0.0923, 0.0457, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 2 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter   13: n+=3476, n-=   0 n0= 972 λ=0.00074, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000736, 1e-06, 0.0922, 0.0457, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 2 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter   14: n+=3476, n-=   0 n0= 972 λ=0.00074, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000736, 1e-06, 0.0922, 0.0457, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 1 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter   15: n+=3476, n-=   0 n0= 972 λ=0.00074, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000736, 1e-06, 0.0921, 0.0457, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 1 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter   16: n+=3476, n-=   0 n0= 972 λ=0.00074, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000736, 1e-06, 0.0921, 0.0457, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 1 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter   17: n+=3476, n-=   0 n0= 972 λ=0.00074, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000736, 1e-06, 0.0921, 0.0457, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 1 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter   18: n+=3476, n-=   0 n0= 972 λ=0.00074, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000736, 1e-06, 0.0921, 0.0457, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 1 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter   19: n+=3476, n-=   0 n0= 972 λ=0.00074, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged in   19 iterations to n+=3476, n-=   0 n0= 972 λ=0.00074, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06     INFO: ********************************************************************************
#              corr_models 2023/09/13 14:51:06     INFO: Initializing model IntermittentGeneralizedInverseGaussian named 'Model' id(self)=140284388837360.
#              corr_models 2023/09/13 14:51:06     INFO: Initialized self.init_params = λ=0.00074, μ=1e-06, σ=0.00089, γ=1, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06     INFO: Initialized self.params      = λ=0.00074, μ=1e-06, σ=0.00089, γ=1, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=1, γ_pr_strength=inf
#              corr_models 2023/09/13 14:51:06     INFO: Fitting IntermittentGeneralizedInverseGaussian model Model.
# /nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py:944: RuntimeWarning: divide by zero encountered in log
#   lypm = np.mean(np.log(y[ip]))   if n_p else 0
# /nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py:946: RuntimeWarning: divide by zero encountered in divide
#   iypm = np.mean(1/y[ip])         if n_p else 0
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000736, 1e-06, 0.0921, 0.0457, 0.00271, 3.46
# /nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py:805: RuntimeWarning: invalid value encountered in scalar add
#   lpos = fp*((k-1)*np.log(λ) - (k-1)*lypm + α/(2*λ) * ypm + α * λ/2 * iypm)
#              corr_models 2023/09/13 14:51:06    DEBUG: Unable to progress after 33 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    0: n+=4448, n-=   0 n0=   0 λ=0.00074, μ=1e-06, σ=0, γ=1, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Starting optimization with x0 = 0.000736, 1e-06, 0.0921, 0.0457, 0.00271, 3.46
#              corr_models 2023/09/13 14:51:06    DEBUG: Unable to progress after 33 iterations.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    1: n+=4448, n-=   0 n0=   0 λ=0.00074, μ=1e-06, σ=0, γ=1, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged in    1 iterations to n+=4448, n-=   0 n0=   0 λ=0.00074, μ=1e-06, σ=0, γ=1, k=0.092, m=0.046, α=0.0027, β=3.5
#              corr_models 2023/09/13 14:51:06     INFO: ********************************************************************************
#              corr_models 2023/09/13 14:51:06     INFO: Initializing model IntermittentGamma named 'Model' id(self)=140281644483008.
#              corr_models 2023/09/13 14:51:06     INFO: Initialized self.init_params = λ=0.34, μ=1e-06, σ=0.00079, γ=1, k=0.3, m=1
#              corr_models 2023/09/13 14:51:06     INFO: Initialized self.params      = λ=0.34, μ=1e-06, σ=0.00079, γ=1, k=0.3, m=1
#              corr_models 2023/09/13 14:51:06     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=1, γ_pr_strength=inf
#              corr_models 2023/09/13 14:51:06     INFO: Fitting IntermittentGamma model Model.
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    0: n+=4448, n-=   0 n0=   0 λ=0.34, μ=1e-06, σ=0, γ=1, k=0.3, m=1
#              corr_models 2023/09/13 14:51:06    DEBUG: Iter    1: n+=4448, n-=   0 n0=   0 λ=0.34, μ=1e-06, σ=0, γ=1, k=0.3, m=1
#              corr_models 2023/09/13 14:51:06    DEBUG: Converged in    1 iterations to n+=4448, n-=   0 n0=   0 λ=0.34, μ=1e-06, σ=0, γ=1, k=0.3, m=1
#              corr_models 2023/09/13 14:51:06     INFO: Plotting cdf for model: Model, IntermittentExponential(λ=0.058, μ=1e-06, σ=0, γ=1)
#              corr_models 2023/09/13 14:51:06     INFO: Plotting cdf for model: Model, IntermittentExponential(λ=0.1, μ=1e-06, σ=0.00071, γ=0.76)
#              corr_models 2023/09/13 14:51:06     INFO: Plotting cdf for model: Model, IntermittentGamma(λ=0.34, μ=1e-06, σ=0.00079, γ=0.59, k=0.3, m=1)
#              corr_models 2023/09/13 14:51:06    DEBUG: agamma_cdf: n_neg = 0 so setting Z0 = 0
#              corr_models 2023/09/13 14:51:06    DEBUG: agamma_cdf: Z0 = 0, Z1 = 2.1641258356812165
#              corr_models 2023/09/13 14:51:06    DEBUG: agamma_cdf: n_neg = 0 so setting Z0 = 0
#              corr_models 2023/09/13 14:51:06    DEBUG: agamma_cdf: Z0 = 0, Z1 = 2.1641258356812165
#              corr_models 2023/09/13 14:51:06     INFO: Plotting cdf for model: Model, IntermittentGeneralizedInverseGaussian(λ=0.00074, μ=1e-06, σ=0.00089, γ=0.64, k=0.092, m=0.046, α=0.0027, β=3.5)
# /camp/home/tootoos/working/tootoos/conda-envs/py38/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:4199: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   return integrate.quad(llc, _a, x)[0]
#              corr_models 2023/09/13 14:51:06  WARNING: cdf out of range for 495 of 1001 values.
#              corr_models 2023/09/13 14:51:07  WARNING: cdf out of range for 495 of 1001 values.

# %% [markdown]
# # Model selection

# %%
from sklearn.model_selection import GridSearchCV, ShuffleSplit
import pandas as pd

# %%
param_grid= [{"model":["exp", "gamma", "gig"], "intermittent":[False]},
             {"model":["exp", "gamma", "gig"], "intermittent":[True], "γ_pr_mean":[0.2,0.4,0.6,0.8], "γ_pr_strength":[1]}]

# %%
reload(fpt)
reload(corrm)
corrm.logger.setLevel(logging.WARN)

# %%
search = GridSearchCV(estimator = corrm.CorrModel(name="Model", scoring = "tv", init_mode="ancestral"), param_grid=param_grid, cv=ShuffleSplit(n_splits=3, test_size=0.5, random_state=0),verbose=1, n_jobs=1)

# %%
y_ = get_data("16Ts", 1, 5)
plot(y_)
# Out:
# Returning data for ds=16Ts, d=8000, freq=5.0 hertz
# la=0.044, mu=0.0024, std(y)=0.026
# la_=1.7, mu_=0.093, std(y_)=1

# %%
search.fit(X=y_, y=None)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /camp/home/tootoos/working/tootoos/conda-envs/py38/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:4199: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   return integrate.quad(llc, _a, x)[0]
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#              corr_models 2023/09/13 18:50:35  WARNING: cdf out of range for 1 of 1001 values.
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# GridSearchCV(cv=ShuffleSplit(n_splits=3, random_state=0, test_size=0.5, train_size=None),
#              estimator=CorrModel(init_mode='ancestral', scoring='tv'), n_jobs=1,
#              param_grid=[{'intermittent': [False],
#                           'model': ['exp', 'gamma', 'gig']},
#                          {'intermittent': [True],
#                           'model': ['exp', 'gamma', 'gig'],
#                           'γ_pr_mean': [0.2, 0.4, 0.6, 0.8],
#                           'γ_pr_strength': [1]}],
#              verbose=1)

# %%
import pickle
file_name = 
with open("search.p", "wb") as f:
    pickle.dump(search.best_estimator_, f)

# %%
file_name = "proc/bw.1/fit_corrs/search.0/8350d3f143881758.5.p"
with open(file_name, "rb") as f:
    search1 = pickle.load(f)

# %%
search.best_estimator_
# Out:
# Model, IntermittentExponential(Params(λ=0.67, μ=0.23, σ=0.0041, γ=0.55))

# %%
search = search1["search"]
results_df = pd.DataFrame(search.cv_results_)
filtered_results = results_df[
    ['param_model', 'param_intermittent', 'param_γ_pr_mean', 'mean_test_score', 'std_test_score']
]
print(filtered_results.sort_values(by='mean_test_score', ascending=False).to_string(index=False))
# Out:
# param_model param_intermittent param_γ_pr_mean  mean_test_score  std_test_score
#         exp               True             0.5         0.925163        0.012285
#         gig               True             0.5         0.903439        0.006198
#       gamma               True             0.5         0.899972        0.004734

# %%
corrm.plot_cdfs(y_, [search.best_estimator_], gof_fun = fpt.compute_tv_value)
# Out:
# /camp/home/tootoos/working/tootoos/conda-envs/py38/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:4199: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   return integrate.quad(llc, _a, x)[0]

# %% [markdown]
# # Sandbox

# %%
import yaml

# %%
config = yaml.load(open('search.1.yaml'), Loader=yaml.FullLoader)

# %%
config
# Out:
# {'verbose': 1,
#  'n_jobs': 1,
#  'corr_model': {'scoring': 'tv', 'init_mode': 'ancestral'},
#  'cv': {'n_splits': 3, 'test_size': 0.5, 'random_state': 0},
#  'param_grid': [{'model': ['exp', 'gamma', 'gig'], 'intermittent': [False]},
#   {'model': ['exp', 'gamma', 'gig'],
#    'intermittent': [True],
#    'γ_pr_mean': [0.2, 0.4, 0.6, 0.8],
#    'γ_pr_strength': [1]}]}

# %%
any([2, None])
# Out:
# 2

# %%
# ?any

# %%
loaded.keys()
# Out:
# dict_keys(['16Ts', 'bw', 's=w', 's=p', 'shw', 'shp', 's=w_q0', 's=w_q1'])

# %%
len(loaded["16Ts"]["freqs"])
# Out:
# 100

# %%
loaded["16Ts"]["rho"][0][16000].shape
# Out:
# (51, 51, 3892)
