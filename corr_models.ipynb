# %% [markdown]
# # Correlation models

# %% [markdown]
# In this notebook we will be testing the corr_models.

# %% [markdown]
# # Code

# %%
# %pylab inline
from importlib import reload
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /camp/home/tootoos/working/tootoos/conda-envs/py38/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['cm']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
import corr_models as corrm

# %% [markdown]
# # Exponential model

# %%
reload(corrm)
y, labs = corrm.Exponential.gen_data(1001, corrm.Exponential.Params(2,1))
corrm.plot_data(y, labs)

# %%
reload(corrm)
mdl = corrm.Exponential(corrm.Exponential.Params(1,1))
mdl.fit(y)
corrm.plot_cdfs(y, [mdl])
# Out:
#              corr_models 2023/09/05 13:08:49     INFO: Iter    0: n+= 658, n-= 343 λ=2, μ=1
#              corr_models 2023/09/05 13:08:49     INFO: Iter    1: n+= 658, n-= 343 λ=2, μ=1
#              corr_models 2023/09/05 13:08:49     INFO: Converged.

# %% [markdown]
# # Intermittent Exponential model

# %%
reload(corrm)
true_params = corrm.IntermittentExponential.Params(2,1,0.1,0.2)
y, labs = corrm.IntermittentExponential.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentExponential(true_params)
mdl = corrm.IntermittentExponential(corrm.IntermittentExponential.Params(λ=2,μ=1,σ=0.001,γ=0.2),
                                    σ_penalty = 0, γ_pr_mean = 0.2, γ_pr_strength = 1)
mdl.fit(y)
corrm.plot_cdfs(y, [true_mdl, mdl])
print(mdl)
# Out:
#              corr_models 2023/09/05 13:18:06     INFO: Iter    0: n+= 274, n-= 226 n0= 501 λ=0.92, μ=0.54, σ=0.052, γ=0.5
#              corr_models 2023/09/05 13:18:06     INFO: Iter    1: n+= 221, n-= 150 n0= 630 λ=1.2, μ=0.68, σ=0.066, γ=0.37
#              corr_models 2023/09/05 13:18:06     INFO: Iter    2: n+= 172, n-=  88 n0= 741 λ=1.6, μ=0.9, σ=0.082, γ=0.26
#              corr_models 2023/09/05 13:18:06     INFO: Iter    3: n+= 143, n-=  60 n0= 798 λ=2, μ=1.1, σ=0.094, γ=0.2
#              corr_models 2023/09/05 13:18:06     INFO: Iter    4: n+= 136, n-=  55 n0= 810 λ=2.2, μ=1.2, σ=0.098, γ=0.19
#              corr_models 2023/09/05 13:18:06     INFO: Iter    5: n+= 134, n-=  54 n0= 813 λ=2.2, μ=1.2, σ=0.099, γ=0.19
#              corr_models 2023/09/05 13:18:06     INFO: Iter    6: n+= 134, n-=  54 n0= 813 λ=2.2, μ=1.2, σ=0.099, γ=0.19
#              corr_models 2023/09/05 13:18:06     INFO: Converged.
# IntermittentExponential(λ=2.2, μ=1.2, σ=0.099, γ=0.19)

# %% [markdown]
# # Intermittent Gamma model

# %%
reload(corrm)
true_params = corrm.IntermittentGamma.Params(2,1,0.01,0.8, 0.2,0.1)
y, labs = corrm.IntermittentGamma.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
mdl.hyper_params
# Out:
# HyperParams(σ_penalty=0, γ_pr_mean=0.1, γ_pr_strength=1000)

# %%
reload(corrm)
true_mdl = corrm.IntermittentGamma(true_params)
mdl = corrm.IntermittentGamma(corrm.IntermittentGamma.Params(λ=2,μ=1,σ=0.001,γ=0.2,k=1,m=1),
                                    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
mdl.fit(y)
figure(figsize=(12,4))
corrm.plot_cdfs(y, [true_mdl, mdl])
# Out:
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.1037386  0.40793098 0.7499076  0.37624726] in   94 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter    0: n+= 264, n-= 272 n0= 465 λ=1.1, μ=0.75, σ=0.0013, γ=0.67, k=0.41, m=0.38
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [2.16972251 0.20435485 1.39266417 0.1043353 ] in   83 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter    1: n+= 305, n-= 480 n0= 216 λ=2.2, μ=1.4, σ=0.0013, γ=0.79, k=0.2, m=0.1
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.94088557 0.20295374 1.23344778 0.10502891] in   68 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter    2: n+= 327, n-= 555 n0= 119 λ=1.9, μ=1.2, σ=0.0013, γ=0.84, k=0.2, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.87242615 0.20209278 1.18625375 0.1058642 ] in   61 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter    3: n+= 337, n-= 576 n0=  88 λ=1.9, μ=1.2, σ=0.0014, γ=0.86, k=0.2, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.83532325 0.20367545 1.16151855 0.10632589] in   58 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter    4: n+= 339, n-= 588 n0=  74 λ=1.8, μ=1.2, σ=0.0013, γ=0.86, k=0.2, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.81264391 0.20513241 1.14662236 0.10660562] in   55 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter    5: n+= 339, n-= 596 n0=  66 λ=1.8, μ=1.1, σ=0.0013, γ=0.87, k=0.21, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.80385452 0.20519417 1.14067084 0.10672796] in   49 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter    6: n+= 340, n-= 599 n0=  62 λ=1.8, μ=1.1, σ=0.0013, γ=0.87, k=0.21, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.79286838 0.20591516 1.1334417  0.10686202] in   51 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter    7: n+= 340, n-= 603 n0=  58 λ=1.8, μ=1.1, σ=0.0013, γ=0.87, k=0.21, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.78055605 0.20635438 1.12520475 0.10705368] in   52 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter    8: n+= 341, n-= 607 n0=  53 λ=1.8, μ=1.1, σ=0.0013, γ=0.87, k=0.21, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.75254595 0.20786559 1.10662787 0.10744377] in   57 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter    9: n+= 342, n-= 617 n0=  42 λ=1.8, μ=1.1, σ=0.0013, γ=0.88, k=0.21, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.74927749 0.20682878 1.10409145 0.1075811 ] in   42 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter   10: n+= 345, n-= 617 n0=  39 λ=1.7, μ=1.1, σ=0.0012, γ=0.88, k=0.21, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.74981441 0.20729211 1.10458418 0.10755441] in   24 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter   11: n+= 344, n-= 617 n0=  40 λ=1.7, μ=1.1, σ=0.0012, γ=0.88, k=0.21, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged to fixed point [1.74981516 0.20729205 1.10458466 0.10755438] in    0 iterations.
#              corr_models 2023/09/05 14:15:31     INFO: Iter   12: n+= 344, n-= 617 n0=  40 λ=1.7, μ=1.1, σ=0.0012, γ=0.88, k=0.21, m=0.11
#              corr_models 2023/09/05 14:15:31     INFO: Converged.
