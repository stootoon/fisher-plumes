# %% [markdown]
# # Correlation models

# %% [markdown]
# In this notebook we will be testing the corr_models.

# %% [markdown]
# # Code

# %%
# %pylab inline
from importlib import reload
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import corr_models as corrm

# %% [markdown]
# # Exponential model

# %%
reload(corrm)
y, labs = corrm.Exponential.gen_data(1001, corrm.Exponential.Params(2,1))
corrm.plot_data(y, labs)

# %%
reload(corrm)
mdl = corrm.Exponential()
mdl.fit(y)
corrm.plot_cdfs(y, [mdl])
# Out:
#              corr_models 2023/09/07 11:50:39     INFO: Initializing from fit.
#              corr_models 2023/09/07 11:50:39     INFO: Found 685 positive, 316 negative values.
#              corr_models 2023/09/07 11:50:39     INFO: Fit exponential distribution to positive values, λ=1.96.
#              corr_models 2023/09/07 11:50:39     INFO: Fit exponential distribution to negative values, μ=1.02.
#              corr_models 2023/09/07 11:50:39     INFO: Parameters initialized to λ=2, μ=1.
#              corr_models 2023/09/07 11:50:39     INFO: Iter    0: n+= 685, n-= 316 λ=2, μ=0.98
#              corr_models 2023/09/07 11:50:39     INFO: Iter    1: n+= 685, n-= 316 λ=2, μ=0.98
#              corr_models 2023/09/07 11:50:39     INFO: Converged.

# %% [markdown]
# # Intermittent Exponential model

# %%
reload(corrm)
true_params = corrm.IntermittentExponential.Params(2,1,0.1,0.2)
y, labs = corrm.IntermittentExponential.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentExponential(true_params)
mdl = corrm.IntermittentExponential(#corrm.IntermittentExponential.Params(λ=2,μ=1,σ=0.001,γ=0.2),
                                    σ_penalty = 0, γ_pr_mean = 0.2, γ_pr_strength = 1)
mdl.fit(y)
corrm.plot_cdfs(y, [true_mdl, mdl])
print(mdl)
# Out:
#              corr_models 2023/09/07 11:58:27     INFO: Initializing from fit using γ=0.2.
#              corr_models 2023/09/07 11:58:27     INFO: Found 801 intermittent points, 131 positive, 69 negative values.
#              corr_models 2023/09/07 11:58:27     INFO: Fit exponential distribution to positive values, λ=2.21.
#              corr_models 2023/09/07 11:58:27     INFO: Fit exponential distribution to negative values, μ=1.08.
#              corr_models 2023/09/07 11:58:27     INFO: Parameters initialized to λ=2.2, μ=1.1, σ=0.092, γ=0.2.
#              corr_models 2023/09/07 11:58:27     INFO: Iter    0: n+= 131, n-=  69 n0= 801 λ=2.2, μ=1.1, σ=0.092, γ=0.2
#              corr_models 2023/09/07 11:58:27     INFO: Iter    1: n+= 117, n-=  56 n0= 828 λ=2.5, μ=1.2, σ=0.1, γ=0.19
#              corr_models 2023/09/07 11:58:27     INFO: Iter    2: n+= 114, n-=  55 n0= 832 λ=2.5, μ=1.3, σ=0.1, γ=0.18
#              corr_models 2023/09/07 11:58:27     INFO: Iter    3: n+= 114, n-=  55 n0= 832 λ=2.5, μ=1.3, σ=0.1, γ=0.18
#              corr_models 2023/09/07 11:58:27     INFO: Converged.
# IntermittentExponential
# (λ=2.5, μ=1.3, σ=0.1, γ=0.18)

# %% [markdown]
# # Intermittent Gamma model

# %%
reload(corrm)
true_params = corrm.IntermittentGamma.Params(2,1,0.01,0.8, 0.2,0.1)
y, labs = corrm.IntermittentGamma.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentGamma(true_params)
mdl = corrm.IntermittentGamma(#corrm.IntermittentGamma.Params(λ=2,μ=1,σ=0.001,γ=0.2,k=1,m=1),
                                    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
mdl.fit(y)
figure(figsize=(8,4))
corrm.plot_cdfs(y, [true_mdl, mdl])
# Out:
#              corr_models 2023/09/07 12:04:29     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/07 12:04:29     INFO: Found 201 intermittent points, 364 positive, 436 negative values.
#              corr_models 2023/09/07 12:04:29     INFO: Fit gamma distribution to positive values, k=0.244, λ=1.41.
#              corr_models 2023/09/07 12:04:29     INFO: Fit gamma distribution to negative values, m=0.248, μ=0.547.
#              corr_models 2023/09/07 12:04:29     INFO: Parameters initialized to λ=1.4, μ=0.55, σ=2.8e-06, γ=0.8, k=0.24, m=0.25.
#              corr_models 2023/09/07 12:04:29     INFO: Iter    0: n+= 380, n-= 555 n0=  66 λ=1.7, μ=0.88, σ=3e-06, γ=0.87, k=0.2, m=0.12
#              corr_models 2023/09/07 12:04:29     INFO: Iter    1: n+= 380, n-= 586 n0=  35 λ=1.7, μ=0.87, σ=3.2e-06, γ=0.88, k=0.2, m=0.11
#              corr_models 2023/09/07 12:04:29     INFO: Iter    2: n+= 380, n-= 588 n0=  33 λ=1.7, μ=0.87, σ=3.3e-06, γ=0.88, k=0.2, m=0.11
#              corr_models 2023/09/07 12:04:29     INFO: Iter    3: n+= 380, n-= 588 n0=  33 λ=1.7, μ=0.87, σ=3.3e-06, γ=0.88, k=0.2, m=0.11
#              corr_models 2023/09/07 12:04:29     INFO: Iter    4: n+= 380, n-= 588 n0=  33 λ=1.7, μ=0.87, σ=3.3e-06, γ=0.88, k=0.2, m=0.11
#              corr_models 2023/09/07 12:04:29     INFO: Converged.

# %% [markdown]
# # Intermittent Generalized Inverse Gausssian model

# %%
reload(corrm)
Model = corrm.IntermittentGeneralizedInverseGaussian

# %%
true_params = Model.Params(λ=2,μ=1,σ=0.01,γ=0.8, k=0.2,m=0.1,α=0.1, β=0.1)
y, labs = Model.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
Model    = corrm.IntermittentGeneralizedInverseGaussian
true_mdl = Model(true_params)
mdl      = Model(#Model.Params(λ=1,μ=0.1, k=1,m=1,α=0.5, β=0.5, γ = 0.8, σ = 0.01),
            σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
mdl.fit(y, method="Nelder-Mead", damping=0.0)
figure(figsize=(8,4))
corrm.plot_cdfs(y, [true_mdl, mdl])
# Out:
#              corr_models 2023/09/07 12:10:53     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/07 12:10:53     INFO: Found 201 intermittent points, 539 positive, 261 negative values.
#              corr_models 2023/09/07 12:10:53     INFO: Fit geninvgauss distribution to positive values, λ=1.63, k=0.252, α=0.095.
#              corr_models 2023/09/07 12:10:53     INFO: Fit geninvgauss distribution to negative values, m=0.144, μ=0.886, β=0.108.
#              corr_models 2023/09/07 12:10:53     INFO: Parameters initialized to λ=1.6, μ=0.89, σ=0.01, γ=0.8, k=0.25, m=0.14, α=0.095, β=0.11.
#              corr_models 2023/09/07 12:10:53    DEBUG: Optimization terminated successfully. after 149 iterations.
#              corr_models 2023/09/07 12:10:53     INFO: Iter    0: n+= 537, n-= 258 n0= 206 λ=2, μ=1.1, σ=0.011, γ=0.8, k=0.22, m=0.11, α=0.11, β=0.12
#              corr_models 2023/09/07 12:10:53    DEBUG: Optimization terminated successfully. after 128 iterations.
#              corr_models 2023/09/07 12:10:53     INFO: Iter    1: n+= 537, n-= 257 n0= 207 λ=2, μ=1.1, σ=0.011, γ=0.8, k=0.21, m=0.11, α=0.11, β=0.13
#              corr_models 2023/09/07 12:10:54    DEBUG: Optimization terminated successfully. after 90 iterations.
#              corr_models 2023/09/07 12:10:54     INFO: Iter    2: n+= 537, n-= 257 n0= 207 λ=2, μ=1.1, σ=0.011, γ=0.8, k=0.21, m=0.11, α=0.11, β=0.13
#              corr_models 2023/09/07 12:10:54     INFO: Converged.

# %% [markdown]
# # CorrModel - Testing the wrapper class.

# %%
reload(corrm)
Params     = corrm.IntermittentGeneralizedInverseGaussian.Params
TrueModel  = corrm.IntermittentGamma
true_model = TrueModel(init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.4, m = 0.1, α = 0.1, β = 0.1),
                       σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
data, labs = true_model.gen_data(1001, params = true_model.params)
corrm.plot_data(data, labs)

# %%
reload(corrm)
Exp = corrm.CorrModel(model = "exp", intermittent = True,
    init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.2, m = 0.1, α = 0.1, β = 0.1),
                    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gam = corrm.CorrModel(model = "gamma", intermittent = True,
    init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 1., α = 0.1, β = 0.1),
                    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gig = corrm.CorrModel(model = "gig", intermittent = True,
    init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 0.2, α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.7, γ_pr_strength = 2, gammaness_thresh = 1e25)

# %%
#Exp.fit(data);
#Gam.fit(data, method = "Nelder-Mead");
Gig.fit(data, method = "Nelder-Mead");
# Out:
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 516 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter    0: n+= 155, n-= 128 n0= 718 λ=1.1, μ=0.35, σ=0.0076, γ=0.56, k=0.4, m=0.1, α=0.18, β=0.25
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 394 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter    1: n+= 160, n-= 133 n0= 708 λ=0.66, μ=0.27, σ=0.0069, γ=0.56, k=0.36, m=0.05, α=0.21, β=0.32
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 358 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter    2: n+= 162, n-= 138 n0= 701 λ=0.42, μ=0.23, σ=0.0065, γ=0.57, k=0.33, m=0.025, α=0.21, β=0.33
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 428 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter    3: n+= 165, n-= 150 n0= 686 λ=0.29, μ=0.19, σ=0.0059, γ=0.57, k=0.33, m=0.013, α=0.2, β=0.31
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 543 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter    4: n+= 174, n-= 160 n0= 667 λ=0.2, μ=0.17, σ=0.0052, γ=0.58, k=0.32, m=0.0063, α=0.17, β=0.29
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 498 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter    5: n+= 187, n-= 173 n0= 641 λ=0.15, μ=0.15, σ=0.0043, γ=0.59, k=0.3, m=0.0031, α=0.14, β=0.27
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 411 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter    6: n+= 199, n-= 187 n0= 615 λ=0.12, μ=0.13, σ=0.0036, γ=0.6, k=0.27, m=0.0016, α=0.12, β=0.24
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 468 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter    7: n+= 209, n-= 203 n0= 589 λ=0.099, μ=0.11, σ=0.003, γ=0.6, k=0.24, m=0.00078, α=0.099, β=0.22
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 385 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter    8: n+= 220, n-= 218 n0= 563 λ=0.084, μ=0.099, σ=0.0025, γ=0.61, k=0.21, m=0.00039, α=0.085, β=0.2
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 135 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter    9: n+= 233, n-= 239 n0= 529 λ=0.072, μ=0.087, σ=0.0019, γ=0.62, k=0.19, m=0.00051, α=0.074, β=0.18
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 407 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   10: n+= 238, n-= 260 n0= 503 λ=0.06, μ=0.076, σ=0.0015, γ=0.63, k=0.19, m=0.00026, α=0.063, β=0.16
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 146 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   11: n+= 246, n-= 277 n0= 478 λ=0.051, μ=0.067, σ=0.0012, γ=0.64, k=0.18, m=0.00033, α=0.054, β=0.14
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 172 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   12: n+= 254, n-= 299 n0= 448 λ=0.041, μ=0.058, σ=0.00087, γ=0.65, k=0.19, m=0.00039, α=0.044, β=0.13
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 169 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   13: n+= 258, n-= 324 n0= 419 λ=0.03, μ=0.049, σ=0.00058, γ=0.66, k=0.2, m=0.00048, α=0.032, β=0.12
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 162 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   14: n+= 266, n-= 343 n0= 392 λ=0.023, μ=0.042, σ=0.00037, γ=0.67, k=0.21, m=0.0006, α=0.024, β=0.11
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 422 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   15: n+= 277, n-= 355 n0= 369 λ=0.019, μ=0.037, σ=0.00025, γ=0.68, k=0.2, m=0.0003, α=0.02, β=0.097
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 199 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   16: n+= 280, n-= 368 n0= 353 λ=0.016, μ=0.032, σ=0.00017, γ=0.68, k=0.2, m=0.00033, α=0.017, β=0.087
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 159 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   17: n+= 284, n-= 380 n0= 337 λ=0.013, μ=0.028, σ=0.00011, γ=0.69, k=0.2, m=0.00038, α=0.014, β=0.078
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 193 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   18: n+= 285, n-= 392 n0= 324 λ=0.011, μ=0.024, σ=8e-05, γ=0.69, k=0.2, m=0.00051, α=0.011, β=0.069
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 170 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   19: n+= 289, n-= 399 n0= 313 λ=0.0094, μ=0.022, σ=6.1e-05, γ=0.7, k=0.2, m=0.00056, α=0.0097, β=0.061
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 180 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   20: n+= 290, n-= 411 n0= 300 λ=0.0077, μ=0.019, σ=4e-05, γ=0.7, k=0.21, m=0.0007, α=0.008, β=0.053
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 402 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   21: n+= 293, n-= 419 n0= 289 λ=0.0065, μ=0.016, σ=2.7e-05, γ=0.7, k=0.21, m=0.00035, α=0.0067, β=0.047
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 359 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   22: n+= 294, n-= 426 n0= 281 λ=0.0056, μ=0.014, σ=2e-05, γ=0.71, k=0.21, m=0.00019, α=0.0056, β=0.041
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 169 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   23: n+= 295, n-= 435 n0= 271 λ=0.0046, μ=0.012, σ=1.3e-05, γ=0.71, k=0.21, m=0.00023, α=0.0047, β=0.035
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 161 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   24: n+= 296, n-= 441 n0= 264 λ=0.0039, μ=0.011, σ=1e-05, γ=0.71, k=0.22, m=0.00025, α=0.0039, β=0.031
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 164 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   25: n+= 297, n-= 448 n0= 256 λ=0.0033, μ=0.0095, σ=7e-06, γ=0.71, k=0.22, m=0.00028, α=0.0033, β=0.026
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 145 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   26: n+= 297, n-= 454 n0= 250 λ=0.0028, μ=0.0083, σ=5.2e-06, γ=0.72, k=0.22, m=0.00038, α=0.0028, β=0.023
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 133 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   27: n+= 298, n-= 461 n0= 242 λ=0.0023, μ=0.0072, σ=3.4e-06, γ=0.72, k=0.23, m=0.00041, α=0.0023, β=0.019
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 150 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   28: n+= 298, n-= 467 n0= 236 λ=0.0019, μ=0.0062, σ=2.5e-06, γ=0.72, k=0.23, m=0.00052, α=0.0019, β=0.017
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 125 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   29: n+= 298, n-= 470 n0= 233 λ=0.0016, μ=0.0055, σ=2.2e-06, γ=0.72, k=0.23, m=0.00062, α=0.0016, β=0.014
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 408 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   30: n+= 298, n-= 476 n0= 227 λ=0.0011, μ=0.0041, σ=1.6e-06, γ=0.72, k=0.24, m=0.038, α=0.0011, β=0.012
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 251 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   31: n+= 298, n-= 481 n0= 222 λ=0.00083, μ=0.0032, σ=1.3e-06, γ=0.73, k=0.25, m=0.062, α=0.00084, β=0.011
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 251 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   32: n+= 298, n-= 487 n0= 216 λ=0.00061, μ=0.0025, σ=1e-06, γ=0.73, k=0.25, m=0.078, α=0.00062, β=0.0091
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 163 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   33: n+= 298, n-= 491 n0= 212 λ=0.00047, μ=0.0021, σ=8.4e-07, γ=0.73, k=0.26, m=0.088, α=0.00048, β=0.0079
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 198 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   34: n+= 298, n-= 499 n0= 204 λ=0.00036, μ=0.0017, σ=5.8e-07, γ=0.73, k=0.26, m=0.095, α=0.00036, β=0.0066
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 229 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   35: n+= 299, n-= 504 n0= 198 λ=0.00028, μ=0.0014, σ=4.3e-07, γ=0.73, k=0.26, m=0.1, α=0.00029, β=0.0056
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 182 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   36: n+= 299, n-= 508 n0= 194 λ=0.00023, μ=0.0012, σ=3.5e-07, γ=0.74, k=0.26, m=0.1, α=0.00023, β=0.0048
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 223 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   37: n+= 299, n-= 512 n0= 190 λ=0.00019, μ=0.001, σ=3.1e-07, γ=0.74, k=0.26, m=0.11, α=0.00019, β=0.0042
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 171 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   38: n+= 299, n-= 516 n0= 186 λ=0.00016, μ=0.00087, σ=2.7e-07, γ=0.74, k=0.27, m=0.11, α=0.00016, β=0.0036
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 140 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   39: n+= 299, n-= 520 n0= 182 λ=0.00013, μ=0.00076, σ=2.3e-07, γ=0.74, k=0.27, m=0.11, α=0.00013, β=0.0032
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 169 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   40: n+= 299, n-= 526 n0= 176 λ=0.00011, μ=0.00065, σ=1.9e-07, γ=0.74, k=0.27, m=0.11, α=0.00011, β=0.0028
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 211 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   41: n+= 299, n-= 534 n0= 168 λ=8.8e-05, μ=0.00056, σ=1.4e-07, γ=0.74, k=0.27, m=0.11, α=9.1e-05, β=0.0024
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 183 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   42: n+= 299, n-= 541 n0= 161 λ=7.2e-05, μ=0.00048, σ=9.1e-08, γ=0.75, k=0.27, m=0.11, α=7.5e-05, β=0.002
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 174 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   43: n+= 299, n-= 547 n0= 155 λ=6e-05, μ=0.00041, σ=6.4e-08, γ=0.75, k=0.27, m=0.11, α=6.2e-05, β=0.0017
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 178 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   44: n+= 299, n-= 554 n0= 148 λ=4.8e-05, μ=0.00035, σ=3.9e-08, γ=0.75, k=0.27, m=0.11, α=5e-05, β=0.0015
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 146 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   45: n+= 299, n-= 558 n0= 144 λ=4e-05, μ=0.0003, σ=2.9e-08, γ=0.75, k=0.27, m=0.11, α=4.2e-05, β=0.0013
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 176 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   46: n+= 299, n-= 564 n0= 138 λ=3.2e-05, μ=0.00026, σ=2e-08, γ=0.75, k=0.27, m=0.11, α=3.4e-05, β=0.0011
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 165 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   47: n+= 299, n-= 568 n0= 134 λ=2.6e-05, μ=0.00022, σ=1.6e-08, γ=0.76, k=0.27, m=0.11, α=2.7e-05, β=0.00091
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 156 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   48: n+= 299, n-= 571 n0= 131 λ=2.2e-05, μ=0.00019, σ=1.3e-08, γ=0.76, k=0.27, m=0.11, α=2.3e-05, β=0.00079
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 170 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   49: n+= 299, n-= 578 n0= 124 λ=1.7e-05, μ=0.00016, σ=8.4e-09, γ=0.76, k=0.28, m=0.11, α=1.8e-05, β=0.00066
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 203 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   50: n+= 299, n-= 581 n0= 121 λ=1.4e-05, μ=0.00014, σ=6.4e-09, γ=0.76, k=0.28, m=0.11, α=1.5e-05, β=0.00057
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 161 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   51: n+= 299, n-= 585 n0= 117 λ=1.2e-05, μ=0.00012, σ=4.6e-09, γ=0.76, k=0.28, m=0.11, α=1.3e-05, β=0.00049
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 185 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   52: n+= 299, n-= 588 n0= 114 λ=1e-05, μ=0.0001, σ=3.6e-09, γ=0.76, k=0.28, m=0.11, α=1.1e-05, β=0.00043
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 192 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   53: n+= 299, n-= 592 n0= 110 λ=8.4e-06, μ=8.9e-05, σ=2.7e-09, γ=0.76, k=0.28, m=0.11, α=8.8e-06, β=0.00037
#              corr_models 2023/09/06 19:13:48    DEBUG: Optimization terminated successfully. after 191 iterations.
#              corr_models 2023/09/06 19:13:48     INFO: Iter   54: n+= 299, n-= 596 n0= 106 λ=6.9e-06, μ=7.6e-05, σ=1.7e-09, γ=0.76, k=0.28, m=0.11, α=7.3e-06, β=0.00032
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 213 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   55: n+= 299, n-= 599 n0= 103 λ=5.7e-06, μ=6.6e-05, σ=1.3e-09, γ=0.77, k=0.28, m=0.11, α=6.1e-06, β=0.00027
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 168 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   56: n+= 299, n-= 604 n0=  98 λ=4.6e-06, μ=5.5e-05, σ=7e-10, γ=0.77, k=0.28, m=0.11, α=4.8e-06, β=0.00023
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 129 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   57: n+= 299, n-= 607 n0=  95 λ=3.7e-06, μ=4.6e-05, σ=3.8e-10, γ=0.77, k=0.28, m=0.11, α=3.9e-06, β=0.00019
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 158 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   58: n+= 299, n-= 609 n0=  93 λ=3e-06, μ=3.9e-05, σ=2.7e-10, γ=0.77, k=0.28, m=0.11, α=3.2e-06, β=0.00016
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 175 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   59: n+= 299, n-= 612 n0=  90 λ=2.4e-06, μ=3.2e-05, σ=1.6e-10, γ=0.77, k=0.28, m=0.11, α=2.5e-06, β=0.00014
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 170 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   60: n+= 299, n-= 615 n0=  87 λ=1.8e-06, μ=2.6e-05, σ=9.9e-11, γ=0.77, k=0.28, m=0.11, α=1.9e-06, β=0.00011
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 187 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   61: n+= 299, n-= 616 n0=  86 λ=1.5e-06, μ=2.2e-05, σ=7.5e-11, γ=0.77, k=0.28, m=0.11, α=1.6e-06, β=9.2e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 233 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   62: n+= 299, n-= 618 n0=  84 λ=1.2e-06, μ=1.8e-05, σ=5.9e-11, γ=0.77, k=0.28, m=0.11, α=1.3e-06, β=7.8e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 156 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   63: n+= 299, n-= 620 n0=  82 λ=1.1e-06, μ=1.6e-05, σ=4.4e-11, γ=0.77, k=0.27, m=0.11, α=1.2e-06, β=6.6e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 302 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   64: n+= 299, n-= 623 n0=  79 λ=1.1e-06, μ=1.4e-05, σ=2.7e-11, γ=0.77, k=0.26, m=0.11, α=1.1e-06, β=5.6e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 161 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   65: n+= 299, n-= 624 n0=  78 λ=1e-06, μ=1.2e-05, σ=2.4e-11, γ=0.77, k=0.26, m=0.11, α=1.1e-06, β=4.9e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 216 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   66: n+= 299, n-= 626 n0=  76 λ=1e-06, μ=1.1e-05, σ=1.9e-11, γ=0.77, k=0.25, m=0.11, α=1e-06, β=4.4e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 218 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   67: n+= 299, n-= 627 n0=  75 λ=1e-06, μ=1e-05, σ=1.6e-11, γ=0.78, k=0.25, m=0.11, α=1e-06, β=4e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 128 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   68: n+= 299, n-= 628 n0=  74 λ=1e-06, μ=9.6e-06, σ=1.4e-11, γ=0.78, k=0.24, m=0.11, α=1e-06, β=3.7e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 111 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   69: n+= 299, n-= 631 n0=  71 λ=1e-06, μ=8.8e-06, σ=8.6e-12, γ=0.78, k=0.24, m=0.11, α=1e-06, β=3.2e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 384 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   70: n+= 299, n-= 632 n0=  70 λ=1e-06, μ=8.2e-06, σ=6.9e-12, γ=0.78, k=0.23, m=0.11, α=1e-06, β=2.9e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 310 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   71: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.7e-06, σ=5.9e-12, γ=0.78, k=0.23, m=0.11, α=1e-06, β=2.7e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 171 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   72: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.5e-06, σ=5.9e-12, γ=0.78, k=0.23, m=0.11, α=1e-06, β=2.6e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 150 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   73: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.4e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 123 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   74: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.3e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 74 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   75: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.3e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 77 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   76: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.3e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 71 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   77: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.2e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 65 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   78: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.2e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 65 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   79: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.2e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 68 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   80: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.2e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 72 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   81: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.2e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 62 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   82: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.2e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 65 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   83: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.2e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 67 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   84: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.2e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49    DEBUG: Optimization terminated successfully. after 62 iterations.
#              corr_models 2023/09/06 19:13:49     INFO: Iter   85: n+= 299, n-= 633 n0=  69 λ=1e-06, μ=7.2e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05
#              corr_models 2023/09/06 19:13:49     INFO: Converged.

# %%
from copy import deepcopy

# %%
Gam = corrm.IntermittentGamma(corrm.IntermittentGamma.Params(λ=1.7,μ=0.5,k=0.22,m=0.11,σ=1e-6,γ=0.78))

# %%
figure(figsize=(12,8))
Gig1 = deepcopy(Gig)
Gig1.model.gammaness_thresh = 1e4
corrm.plot_cdfs(data, [true_model, Gig, Gig1, Gam], labs=["true", "Gig", "Gig (γ)", "Gam (γ)"])
# Out:
#              corr_models 2023/09/06 19:24:01     INFO: Using Gamma distribution with scale = 1.7 for negative values, since gammaness 1.9e+10 > 1.0e+04.
#              corr_models 2023/09/06 19:24:01     INFO: Using Gamma distribution with scale = 0.5 for positive values, since gammaness 1.0e+12 > 1.0e+04.
#              corr_models 2023/09/06 19:24:01     INFO: Using Gamma distribution with scale = 1.7 for negative values, since gammaness 1.9e+10 > 1.0e+04.
#              corr_models 2023/09/06 19:24:01     INFO: Using Gamma distribution with scale = 0.5 for positive values, since gammaness 1.0e+12 > 1.0e+04.

# %%
Gig1.cdf(0.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-310-00b1a616b744> in <module>
# ----> 1 Gig1.cdf(0.2)
#
# /nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py in cdf(self, *args, **kwargs)
#     677
#     678     def cdf(self, *args, **kwargs):
# --> 679         return self.model.cdf(*args, **kwargs)
#     680
#     681     def __str__(self):
#
# /nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py in cdf(self, y, params)
#     517         if params is None: params = self.params
#     518         # Compute the CDF
# --> 519         R = IntermittentGeneralizedInverseGaussian.agig_cdf(y, params, self.gammaness_thresh)
#     520         H = norm_dist.cdf(y, scale = params.σ)
#     521         return params.γ*R + (1-params.γ)*H
#
# /nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py in agig_cdf(y, params, gammaness_thresh)
#     510         Z = Z0 + Z1
#     511         cdf = 0*y
# --> 512         cdf[y<0] = neg_cdf(y[y<0]) * Z0/Z
#     513         cdf[y>=0]= Z0/Z + pos_cdf(y[y>=0]) * Z1/Z
#     514         return cdf
#
# TypeError: 'float' object is not subscriptable

# %%
Gig1
# Out:
# IntermittentGeneralizedInverseGaussian
# (Params(λ=1e-06, μ=7.2e-06, σ=5.9e-12, γ=0.78, k=0.22, m=0.11, α=1e-06, β=2.5e-05))
