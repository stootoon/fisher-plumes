# %% [markdown]
# # Correlation models

# %% [markdown]
# In this notebook we will be testing the corr_models.

# %% [markdown]
# # Code

# %%
# %pylab inline
from importlib import reload
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from copy import deepcopy

# %%
import corr_models as corrm

# %% [markdown]
# # Exponential model

# %%
reload(corrm)
y, labs = corrm.Exponential.gen_data(1001, corrm.Exponential.Params(2,1))
corrm.plot_data(y, labs)

# %%
reload(corrm)
mdl = corrm.Exponential()
mdl.fit(y)
corrm.plot_cdfs(y, [mdl])
# Out:
#              corr_models 2023/09/12 09:58:31     INFO: Fitting exponential model Model.
#              corr_models 2023/09/12 09:58:31     INFO: Initializing from fit.
#              corr_models 2023/09/12 09:58:31     INFO: Found 658 positive, 343 negative values.
#              corr_models 2023/09/12 09:58:31     INFO: Fit exponential distribution to positive values, λ=1.97.
#              corr_models 2023/09/12 09:58:31     INFO: Fit exponential distribution to negative values, μ=1.02.
#              corr_models 2023/09/12 09:58:31     INFO: Parameters initialized to λ=2, μ=1.
#              corr_models 2023/09/12 09:58:31    DEBUG: Iter    0: n+= 658, n-= 343 λ=2, μ=1
#              corr_models 2023/09/12 09:58:31    DEBUG: Iter    1: n+= 658, n-= 343 λ=2, μ=1
#              corr_models 2023/09/12 09:58:31     INFO: Converged.
#              corr_models 2023/09/12 09:58:31     INFO: Plotting cdf for model: Model, Exponential(λ=2, μ=1)

# %% [markdown]
# # Intermittent Exponential model

# %%
reload(corrm)
true_params = corrm.IntermittentExponential.Params(2,1,0.1,0.2)
y, labs = corrm.IntermittentExponential.gen_data(2001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentExponential(init_params = true_params, name = "True Model")
mdl = corrm.IntermittentExponential(#corrm.IntermittentExponential.Params(λ=2,μ=1,σ=0.001,γ=0.2),
    name = "Fit",
                                    σ_penalty = 0, γ_pr_mean = 0.2, γ_pr_strength = 1)
mdl.fit(y)
corrm.plot_cdfs(y, [true_mdl, mdl])
print(mdl)
# Out:
#              corr_models 2023/09/12 10:17:11     INFO: __init__ IntermittentExponential True Model id(self)=139708978181696
#              corr_models 2023/09/12 10:17:11     INFO: Casting IntermittentExponential to IntermittentExponential.
#              corr_models 2023/09/12 10:17:11     INFO: Cast params: λ=2, μ=1, σ=0.1, γ=0.2 -> λ=2, μ=1, σ=0.1, γ=0.2
#              corr_models 2023/09/12 10:17:11     INFO: Initialized self.init_params = λ=2, μ=1, σ=0.1, γ=0.2
#              corr_models 2023/09/12 10:17:11     INFO: Initialized self.params      = λ=2, μ=1, σ=0.1, γ=0.2
#              corr_models 2023/09/12 10:17:11     INFO: __init__ IntermittentExponential Fit id(self)=139708980454880
#              corr_models 2023/09/12 10:17:11     INFO: Initialized self.init_params = None
#              corr_models 2023/09/12 10:17:11     INFO: Initialized self.params      = None
#              corr_models 2023/09/12 10:17:11     INFO: Fitting IntermittentExponential model Fit.
#              corr_models 2023/09/12 10:17:11     INFO: Initializing from fit using γ=0.2.
#              corr_models 2023/09/12 10:17:11     INFO: Found 1601 intermittent points, 257 positive, 143 negative values.
#              corr_models 2023/09/12 10:17:11     INFO: Fit exponential distribution to positive values, λ=1.72.
#              corr_models 2023/09/12 10:17:11     INFO: Fit exponential distribution to negative values, μ=0.984.
#              corr_models 2023/09/12 10:17:11     INFO: Parameters initialized to λ=1.7, μ=0.98, σ=0.087, γ=0.2.
#              corr_models 2023/09/12 10:17:11    DEBUG: Iter    0: n+= 257, n-= 143 n0=1601 λ=1.7, μ=0.98, σ=0.088, γ=0.2
#              corr_models 2023/09/12 10:17:11    DEBUG: Iter    1: n+= 228, n-= 114 n0=1659 λ=2, μ=1.1, σ=0.096, γ=0.19
#              corr_models 2023/09/12 10:17:11    DEBUG: Iter    2: n+= 218, n-= 107 n0=1676 λ=2.1, μ=1.1, σ=0.099, γ=0.18
#              corr_models 2023/09/12 10:17:11    DEBUG: Iter    3: n+= 210, n-= 106 n0=1685 λ=2.1, μ=1.2, σ=0.1, γ=0.18
#              corr_models 2023/09/12 10:17:11    DEBUG: Iter    4: n+= 209, n-= 104 n0=1688 λ=2.1, μ=1.2, σ=0.1, γ=0.18
#              corr_models 2023/09/12 10:17:11    DEBUG: Iter    5: n+= 209, n-= 104 n0=1688 λ=2.1, μ=1.2, σ=0.1, γ=0.18
#              corr_models 2023/09/12 10:17:11     INFO: Converged.
#              corr_models 2023/09/12 10:17:11     INFO: Plotting cdf for model: True Model, IntermittentExponential(λ=2, μ=1, σ=0.1, γ=0.2)
#              corr_models 2023/09/12 10:17:11     INFO: Plotting cdf for model: Fit, IntermittentExponential(λ=2.1, μ=1.2, σ=0.1, γ=0.18)
# Fit, IntermittentExponential(λ=2.1, μ=1.2, σ=0.1, γ=0.18)

# %% [markdown]
# # Intermittent Gamma model

# %%
reload(corrm)
true_params = corrm.IntermittentGamma.Params(2,1,0.01,0.8, 0.2,0.3)
y, labs = corrm.IntermittentGamma.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentGamma(init_params = true_params, name="True Model")
mdl = corrm.IntermittentGamma(#corrm.IntermittentGamma.Params(λ=2,μ=1,σ=0.001,γ=0.2,k=1,m=1),
    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1, name="Gamma")
mdl.fit(y, method="Nelder-Mead")
figure(figsize=(8,4))
corrm.plot_cdfs(y, [true_mdl, mdl], diffs=False)
# Out:
#              corr_models 2023/09/12 10:40:26     INFO: __init__ IntermittentGamma True Model id(self)=139708981805216
#              corr_models 2023/09/12 10:40:26     INFO: Casting IntermittentGamma to IntermittentGamma.
#              corr_models 2023/09/12 10:40:26     INFO: Cast params: λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3 -> λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3
#              corr_models 2023/09/12 10:40:26     INFO: Initialized self.init_params = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3
#              corr_models 2023/09/12 10:40:26     INFO: Initialized self.params      = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3
#              corr_models 2023/09/12 10:40:26     INFO: __init__ IntermittentGamma Gamma id(self)=139708976814928
#              corr_models 2023/09/12 10:40:26     INFO: Initialized self.init_params = None
#              corr_models 2023/09/12 10:40:26     INFO: Initialized self.params      = None
#              corr_models 2023/09/12 10:40:26     INFO: Fitting IntermittentGamma model Gamma.
#              corr_models 2023/09/12 10:40:26     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/12 10:40:26     INFO: Found 201 intermittent points, 472 positive, 328 negative values.
#              corr_models 2023/09/12 10:40:26     INFO: Fit gamma distribution to positive values, k=0.362, λ=1.24.
#              corr_models 2023/09/12 10:40:26     INFO: Fit gamma distribution to negative values, m=0.396, μ=0.627.
#              corr_models 2023/09/12 10:40:26     INFO: Parameters initialized to λ=1.2, μ=0.63, σ=0.00051, γ=0.8, k=0.36, m=0.4.
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter    0: n+= 534, n-= 346 n0= 121 λ=1.6, μ=0.76, σ=0.00046, γ=0.84, k=0.25, m=0.32
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter    1: n+= 567, n-= 349 n0=  85 λ=1.6, μ=0.76, σ=0.00044, γ=0.86, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter    2: n+= 578, n-= 351 n0=  72 λ=1.6, μ=0.76, σ=0.00041, γ=0.86, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter    3: n+= 580, n-= 352 n0=  69 λ=1.6, μ=0.76, σ=0.00039, γ=0.87, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter    4: n+= 579, n-= 352 n0=  70 λ=1.6, μ=0.76, σ=0.00036, γ=0.87, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter    5: n+= 580, n-= 353 n0=  68 λ=1.6, μ=0.76, σ=0.00034, γ=0.87, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter    6: n+= 582, n-= 355 n0=  64 λ=1.6, μ=0.76, σ=0.0003, γ=0.87, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter    7: n+= 585, n-= 354 n0=  62 λ=1.6, μ=0.75, σ=0.00026, γ=0.87, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter    8: n+= 584, n-= 355 n0=  62 λ=1.6, μ=0.75, σ=0.00023, γ=0.87, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter    9: n+= 586, n-= 355 n0=  60 λ=1.6, μ=0.75, σ=0.00022, γ=0.87, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter   10: n+= 587, n-= 356 n0=  58 λ=1.6, μ=0.75, σ=0.00021, γ=0.87, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter   11: n+= 588, n-= 356 n0=  57 λ=1.6, μ=0.75, σ=0.00021, γ=0.87, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26    DEBUG: Iter   12: n+= 588, n-= 356 n0=  57 λ=1.6, μ=0.75, σ=0.00021, γ=0.87, k=0.23, m=0.31
#              corr_models 2023/09/12 10:40:26     INFO: Converged.
#              corr_models 2023/09/12 10:40:26     INFO: Plotting cdf for model: True Model, IntermittentGamma(λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3)
#              corr_models 2023/09/12 10:40:26     INFO: Plotting cdf for model: Gamma, IntermittentGamma(λ=1.6, μ=0.75, σ=0.00021, γ=0.87, k=0.23, m=0.31)

# %% [markdown]
# # Intermittent Generalized Inverse Gausssian model

# %%
reload(corrm)
Model = corrm.IntermittentGeneralizedInverseGaussian

# %%
true_params = Model.Params(λ=2,μ=1,σ=0.01,γ=0.8, k=0.2,m=0.1,α=0.1, β=0.1)
y, labs = Model.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
corrm.logger.setLevel(logging.INFO)
Model    = corrm.IntermittentGeneralizedInverseGaussian
true_mdl = Model(init_params=true_params, name="True Model")
mdl      = Model(#Model.Params(λ=1,μ=0.1, k=1,m=1,α=0.5, β=0.5, γ = 0.8, σ = 0.01),
    name = "Fit",
            σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1e-3)
mdl.fit(y, method="Nelder-Mead", damping=0.0)
figure(figsize=(10,5))
corrm.plot_cdfs(y, [true_mdl, mdl])
# Out:
#              corr_models 2023/09/12 10:40:36     INFO: __init__ IntermittentGeneralizedInverseGaussian True Model id(self)=139708982768496
#              corr_models 2023/09/12 10:40:36     INFO: Casting IntermittentGeneralizedInversGaussian to IntermittentGeneralizedInversGaussian.
#              corr_models 2023/09/12 10:40:36     INFO: Cast params: λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1 -> λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1
#              corr_models 2023/09/12 10:40:36     INFO: Initialized self.init_params = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1
#              corr_models 2023/09/12 10:40:36     INFO: Initialized self.params      = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1
#              corr_models 2023/09/12 10:40:36     INFO: __init__ IntermittentGeneralizedInverseGaussian Fit id(self)=139708982031168
#              corr_models 2023/09/12 10:40:36     INFO: Initialized self.init_params = None
#              corr_models 2023/09/12 10:40:36     INFO: Initialized self.params      = None
#              corr_models 2023/09/12 10:40:36     INFO: Fitting IntermittentGeneralizedInverseGaussian model Fit.
#              corr_models 2023/09/12 10:40:36     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/12 10:40:36     INFO: Found 201 intermittent points, 540 positive, 260 negative values.
#              corr_models 2023/09/12 10:40:37     INFO: Fit geninvgauss distribution to positive values, λ=2.29, k=0.147, α=0.0978.
#              corr_models 2023/09/12 10:40:37     INFO: Fit geninvgauss distribution to negative values, m=-0.00486, μ=1.6, β=0.124.
#              corr_models 2023/09/12 10:40:37     INFO: Parameters initialized to λ=2.3, μ=1.6, σ=0.012, γ=0.8, k=0.15, m=-0.0049, α=0.098, β=0.12.
#              corr_models 2023/09/12 10:40:37     INFO: Converged.
#              corr_models 2023/09/12 10:40:37     INFO: Plotting cdf for model: True Model, IntermittentGeneralizedInverseGaussian(λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1)
#              corr_models 2023/09/12 10:40:37     INFO: Plotting cdf for model: Fit, IntermittentGeneralizedInverseGaussian(λ=2.2, μ=1.2, σ=0.011, γ=0.81, k=0.15, m=0.065, α=0.095, β=0.11)

# %% [markdown]
# # CorrModel - Testing the wrapper class.

# %%
reload(corrm)
Params     = corrm.IntermittentGeneralizedInverseGaussian.Params
TrueModel  = corrm.IntermittentGamma
true_model = TrueModel(name="True Model", init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.4, m = 0.1, α = 0.1, β = 0.1),
                       σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
data, labs = true_model.gen_data(1001, params = true_model.params)
corrm.plot_data(data, labs)
# Out:
#              corr_models 2023/09/12 10:42:19     INFO: __init__ IntermittentGamma True Model id(self)=139708984390464
#              corr_models 2023/09/12 10:42:19     INFO: Casting IntermittentGenInvGauss to IntermittentGamma.
#              corr_models 2023/09/12 10:42:19     INFO: Cast params: λ=2, μ=0.5, σ=0.01, γ=0.8, k=0.4, m=0.1, α=0.1, β=0.1 -> λ=40, μ=10, σ=0.01, γ=0.8, k=0.4, m=0.1
#              corr_models 2023/09/12 10:42:19     INFO: Initialized self.init_params = λ=40, μ=10, σ=0.01, γ=0.8, k=0.4, m=0.1
#              corr_models 2023/09/12 10:42:19     INFO: Initialized self.params      = λ=40, μ=10, σ=0.01, γ=0.8, k=0.4, m=0.1

# %%
reload(corrm)
Exp = corrm.CorrModel(model = "exp", name = "Exp", intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.2, m = 0.1, α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gam = corrm.CorrModel(model = "gamma", name = "Gam", intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 1., α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gig = corrm.CorrModel(model = "gig", name="Gig",intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 0.2, α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1, gammaness_thresh = 1e5)
# Out:
#              corr_models 2023/09/12 10:42:45     INFO: __init__ IntermittentExponential Exp id(self)=139708975735184
#              corr_models 2023/09/12 10:42:45     INFO: Initialized self.init_params = None
#              corr_models 2023/09/12 10:42:45     INFO: Initialized self.params      = None
#              corr_models 2023/09/12 10:42:45     INFO: __init__ IntermittentGamma Gam id(self)=139708976674752
#              corr_models 2023/09/12 10:42:45     INFO: Initialized self.init_params = None
#              corr_models 2023/09/12 10:42:45     INFO: Initialized self.params      = None
#              corr_models 2023/09/12 10:42:45     INFO: __init__ IntermittentGeneralizedInverseGaussian Gig id(self)=139708976676672
#              corr_models 2023/09/12 10:42:45     INFO: Initialized self.init_params = None
#              corr_models 2023/09/12 10:42:45     INFO: Initialized self.params      = None

# %%
corrm.logger.setLevel(logging.INFO)
Exp.fit(data);
Gam.fit(data, method = "Nelder-Mead");
Gig.fit(data, method = "Nelder-Mead");
Gam2 = corrm.IntermittentGamma(init_params = corrm.IntermittentGamma.params_from_gig(Gig.params), name="GamFromGig")
figure(figsize=(12,8))
corrm.plot_cdfs(data, [true_model, Gam, Gig, Gam2])#, Gig1])#, labs=["true", "Gam", "Gig", "Gig (γ)"])
# Out:
#              corr_models 2023/09/12 10:42:47     INFO: Fitting IntermittentExponential model Exp.
#              corr_models 2023/09/12 10:42:47     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/12 10:42:47     INFO: Found 201 intermittent points, 428 positive, 372 negative values.
#              corr_models 2023/09/12 10:42:47     INFO: Fit exponential distribution to positive values, λ=12.3.
#              corr_models 2023/09/12 10:42:47     INFO: Fit exponential distribution to negative values, μ=1.48.
#              corr_models 2023/09/12 10:42:47     INFO: Parameters initialized to λ=12, μ=1.5, σ=9.1e-05, γ=0.8.
#              corr_models 2023/09/12 10:42:47     INFO: Converged.
#              corr_models 2023/09/12 10:42:47     INFO: Fitting IntermittentGamma model Gam.
#              corr_models 2023/09/12 10:42:47     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/12 10:42:47     INFO: Found 201 intermittent points, 428 positive, 372 negative values.
#              corr_models 2023/09/12 10:42:47     INFO: Fit gamma distribution to positive values, k=0.261, λ=46.9.
#              corr_models 2023/09/12 10:42:47     INFO: Fit gamma distribution to negative values, m=0.225, μ=6.58.
#              corr_models 2023/09/12 10:42:47     INFO: Parameters initialized to λ=47, μ=6.6, σ=9.1e-05, γ=0.8, k=0.26, m=0.22.
#              corr_models 2023/09/12 10:42:47     INFO: Converged.
#              corr_models 2023/09/12 10:42:47     INFO: Fitting IntermittentGeneralizedInverseGaussian model Gig.
#              corr_models 2023/09/12 10:42:47     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/12 10:42:47     INFO: Found 201 intermittent points, 428 positive, 372 negative values.
#              corr_models 2023/09/12 10:42:47     INFO: Fit geninvgauss distribution to positive values, λ=0.202, k=0.136, α=0.0059.
#              corr_models 2023/09/12 10:42:47     INFO: Fit geninvgauss distribution to negative values, m=-0.097, μ=0.131, β=0.0123.
#              corr_models 2023/09/12 10:42:47     INFO: Parameters initialized to λ=0.2, μ=0.13, σ=9.1e-05, γ=0.8, k=0.14, m=-0.097, α=0.0059, β=0.012.
#              corr_models 2023/09/12 10:42:48     INFO: Converged.
#              corr_models 2023/09/12 10:42:48     INFO: __init__ IntermittentGamma GamFromGig id(self)=139708976601504
#              corr_models 2023/09/12 10:42:48     INFO: Initialized self.init_params = λ=41, μ=17, σ=4.7e-12, γ=0.88, k=0.22, m=0.088
#              corr_models 2023/09/12 10:42:48     INFO: Initialized self.params      = λ=41, μ=17, σ=4.7e-12, γ=0.88, k=0.22, m=0.088
#              corr_models 2023/09/12 10:42:48     INFO: Plotting cdf for model: True Model, IntermittentGamma(λ=40, μ=10, σ=0.01, γ=0.8, k=0.4, m=0.1)
#              corr_models 2023/09/12 10:42:48     INFO: Plotting cdf for model: Gam, IntermittentGamma(λ=10, μ=7.6, σ=0.0001, γ=0.89, k=0.4, m=0.11)
#              corr_models 2023/09/12 10:42:48     INFO: Plotting cdf for model: Gig, IntermittentGeneralizedInverseGaussian(λ=2e-05, μ=7.1e-05, σ=4.7e-12, γ=0.88, k=0.22, m=0.088, α=1e-06, β=8.3e-06)
#              corr_models 2023/09/12 10:42:48     INFO: Using Gamma distribution with scale = 17 for negative values, since gammaness 2.0e+08 > 1.0e+05.
#              corr_models 2023/09/12 10:42:48     INFO: Using Gamma distribution with scale = 41 for positive values, since gammaness 2.4e+09 > 1.0e+05.
#              corr_models 2023/09/12 10:42:48     INFO: Using Gamma distribution with scale = 17 for negative values, since gammaness 2.0e+08 > 1.0e+05.
#              corr_models 2023/09/12 10:42:48     INFO: Using Gamma distribution with scale = 41 for positive values, since gammaness 2.4e+09 > 1.0e+05.
#              corr_models 2023/09/12 10:42:48     INFO: Plotting cdf for model: GamFromGig, IntermittentGamma(λ=41, μ=17, σ=4.7e-12, γ=0.88, k=0.22, m=0.088)

# %% [markdown]
# # Real data

# %%
import os, sys
os.environ["FISHER_PLUMES"] = os.path.join(os.environ["GIT"],"fisher-plumes")
os.chdir(os.environ["FISHER_PLUMES"])
import units; reload(units); UNITS = units.UNITS;

# %%
import boulder;   reload(boulder)
import crick;     reload(crick)
import surrogate; reload(surrogate)
import fisher_plumes_tools as fpt;      reload(fpt)
import fisher_plumes_figs  as fpf;      reload(fpf);
import fisher_plumes_fig_tools as fpft; reload(fpft)
import fisher_plumes as fp;             reload(fp)
import utils; reload(utils); from utils import dict_update, dict_update_from_field
import proc; reload(proc);
FisherPlumes = fp.FisherPlumes
crick.logger.setLevel(logging.DEBUG)
fp.logger.setLevel(logging.INFO)
# Out:
# INFO:boulder:Boulder simulation data available for:
# INFO:boulder:Re100_0_5mm_50Hz_16source_manuscript.h5         : ['Odor Data/c1a', 'Odor Data/c1b', 'Odor Data/c2a', 'Odor Data/c2b', 'Odor Data/c3a', 'Odor Data/c3b', 'Odor Data/c4a', 'Odor Data/c4b', 'Odor Data/c5a', 'Odor Data/c5b', 'Odor Data/c6a', 'Odor Data/c6b', 'Odor Data/c7a', 'Odor Data/c7b', 'Odor Data/c8a', 'Odor Data/c8b'] (16 datasets)
# INFO:boulder:Boulder simulation data available for:
# INFO:boulder:Re100_0_5mm_50Hz_16source_manuscript.h5         : ['Odor Data/c1a', 'Odor Data/c1b', 'Odor Data/c2a', 'Odor Data/c2b', 'Odor Data/c3a', 'Odor Data/c3b', 'Odor Data/c4a', 'Odor Data/c4b', 'Odor Data/c5a', 'Odor Data/c5b', 'Odor Data/c6a', 'Odor Data/c6b', 'Odor Data/c7a', 'Odor Data/c7b', 'Odor Data/c8a', 'Odor Data/c8b'] (16 datasets)
# INFO:crick:Simulation data available for:
# INFO:crick:crimgrid_w1                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w2                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w3                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w4                                     : y0 - y9 (16 datasets)
# INFO:crick:n12T                                            : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n12Tslow                                        : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n12dishT                                        : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n16T                                            : Y0.440 - Y0.560 (16 datasets)
# INFO:crick:n16Tslow                                        : Y0.440 - Y0.560 (16 datasets)
# INFO:crick:Simulation data available for:
# INFO:crick:crimgrid_w1                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w2                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w3                                     : y0 - y9 (16 datasets)
# INFO:crick:crimgrid_w4                                     : y0 - y9 (16 datasets)
# INFO:crick:n12T                                            : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n12Tslow                                        : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n12dishT                                        : Y0.450 - Y0.550 (11 datasets)
# INFO:crick:n16T                                            : Y0.440 - Y0.560 (16 datasets)
# INFO:crick:n16Tslow                                        : Y0.440 - Y0.560 (16 datasets)
# INFO:surrogate:Surrogate simulation data available for: ['no_info', 'one_info', 'two_info', 'high', 'spike_and_slab', 'blue', 'red', 'all_equal']
# INFO:surrogate:Surrogate simulation data available for: ['no_info', 'one_info', 'two_info', 'high', 'spike_and_slab', 'blue', 'red', 'all_equal']

# %%
window_length = 1 * UNITS.second
windows       = ['boxcar', 'hann', ('kaiser',9), ('kaiser', 16)]
window_shape  = windows[1]
fit_k         = False
fit_b         = True

# %%
to_use = {"16Ts":{"sim_name":"n16Tslow"},
          "bw":  {"sim_name":"boulder16"},
          "s=w": {"sim_name":"surr_all_equal", "surrogate_k": 0},
          "s=p": {"sim_name":"surr_all_equal", "surrogate_k": 4},
          "shw": {"sim_name":"surr_high",      "surrogate_k": 0},          
          "shp": {"sim_name":"surr_high",      "surrogate_k": 4},
          "s=w_q0":{"sim_name":"surr_quad",      "surrogate_k": 0, "phi":0},
          "s=w_q1":{"sim_name":"surr_quad",      "surrogate_k": 0, "phi":pi/3},
}

# %%
safe_load = lambda d: d[0] if d is not None else d
[f.logger.setLevel(logging.WARN) for f in [crick, boulder,fp]];
loaded = {k:safe_load(proc.load_data(init_filter = v,
                                       compute_filter = {
                                           "window_shape":window_shape,
                                           "window_length":window_length,
                                           "fit_k":fit_k,
                                           "fit_b":fit_b,
                                       }))
          for k,v in to_use.items()}

data =  {k:FisherPlumes(d) for k,d in loaded.items() if d is not None}

for k, l in loaded.items():
    if l is None:
        print(f"WARNING: No data for {k=}")

[f.logger.setLevel(logging.INFO) for f in [crick, boulder,fp]];
# Out:
#                     proc 2023/09/12 10:43:19     INFO: Loading init_filter={'sim_name': 'n16Tslow'} compute_filter={'window_shape': 'hann', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/n16Ts.1/78281891d4d0a86d.p
#                     proc 2023/09/12 10:43:23     INFO: Returning 1 results.
#                     proc 2023/09/12 10:43:23     INFO: Loading init_filter={'sim_name': 'boulder16'} compute_filter={'window_shape': 'hann', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/bw.1/a870f77347a4942f.p
#                     proc 2023/09/12 10:43:25     INFO: Returning 1 results.
#                     proc 2023/09/12 10:43:25     INFO: Loading init_filter={'sim_name': 'surr_all_equal', 'surrogate_k': 0} compute_filter={'window_shape': 'hann', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/s=w.1/d939203ae60ec26a.p
#                     proc 2023/09/12 10:43:25     INFO: Returning 1 results.
#                     proc 2023/09/12 10:43:25     INFO: Loading init_filter={'sim_name': 'surr_all_equal', 'surrogate_k': 4} compute_filter={'window_shape': 'hann', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/s=p.1/ea1b3a6e626f84a2.p
#                     proc 2023/09/12 10:43:26     INFO: Returning 1 results.
#                     proc 2023/09/12 10:43:26     INFO: Loading init_filter={'sim_name': 'surr_high', 'surrogate_k': 0} compute_filter={'window_shape': 'hann', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/shw.1/c608e21b188eccdc.p
#                     proc 2023/09/12 10:43:27     INFO: Returning 1 results.
#                     proc 2023/09/12 10:43:27     INFO: Loading init_filter={'sim_name': 'surr_high', 'surrogate_k': 4} compute_filter={'window_shape': 'hann', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/shp.1/9aa0c12903638012.p
#                     proc 2023/09/12 10:43:28     INFO: Returning 1 results.
#                     proc 2023/09/12 10:43:28     INFO: Loading init_filter={'sim_name': 'surr_quad', 'surrogate_k': 0, 'phi': 0} compute_filter={'window_shape': 'hann', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/s=w_q.1/590d29b026eb2834.p
#                     proc 2023/09/12 10:43:29     INFO: Returning 1 results.
#                     proc 2023/09/12 10:43:29     INFO: Loading init_filter={'sim_name': 'surr_quad', 'surrogate_k': 0, 'phi': 1.0471975511965976} compute_filter={'window_shape': 'hann', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/s=w_q.2/7213b58bc65c326d.p
#                     proc 2023/09/12 10:43:33     INFO: Returning 1 results.
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -56250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S0'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-59.10548154],
#        [ 35.2562945 ],
#        [-38.69660792],
#        ...,
#        [ 34.57781868],
#        [ -3.27081684],
#        [-59.10548154]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -56250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S0'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-59.10548154],
#        [ 35.2562945 ],
#        [-38.69660792],
#        ...,
#        [ 34.57781868],
#        [ -3.27081684],
#        [-59.10548154]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -48750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S1'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-34.8066426 ],
#        [ 43.82380139],
#        [-18.10450163],
#        ...,
#        [ 40.19624256],
#        [-15.65682817],
#        [-34.8066426 ]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -41250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S2'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-28.97564641],
#        [ 37.15857913],
#        [-41.8924706 ],
#        ...,
#        [ 29.51571216],
#        [-33.07679923],
#        [-28.97564641]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -33750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S3'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[  0.09667675],
#        [ 17.15605786],
#        [-22.76591961],
#        ...,
#        [ 14.80597364],
#        [-32.5007697 ],
#        [  0.09667675]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -26250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S4'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-54.5278579 ],
#        [ 31.51239671],
#        [-47.64004882],
#        ...,
#        [  8.26059954],
#        [-20.55958392],
#        [-54.5278579 ]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -18750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S5'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-48.35916503],
#        [ 45.96442053],
#        [-25.01993076],
#        ...,
#        [ -7.29143947],
#        [-23.64727656],
#        [-48.35916503]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([     0. -11250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S6'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-50.55704307],
#        [ 41.24139666],
#        [ -7.55622495],
#        ...,
#        [ -4.75087879],
#        [ -2.98271267],
#        [-50.55704307]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([    0. -3750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S7'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-14.44633995],
#        [ 56.33865616],
#        [ -6.5564151 ],
#        ...,
#        [ 21.55376075],
#        [ 20.56034844],
#        [-14.44633995]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
#        [0.        , 0.        , 0.        , ..., 0.69296345, 0.84008883,
#         1.        ]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'all_equal', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_all_equal_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_all_equal_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_all_equal_pitch')>, 'y': <Quantity([[0]], 'surr_all_equal_pitch')>}, 'x': <Quantity([10], 'surr_all_equal_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_all_equal_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_all_equal_pitch')>, <Quantity(10, 'surr_all_equal_pitch')>], 'y_lim': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'source': <Quantity([   0. 3750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_all_equal_pitch')>, <Quantity(0, 'surr_all_equal_pitch')>], 'fields': ['S8'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'all_equal', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-19.18887802],
#        [ 68.03417363],
#        [ -5.47800054],
#        ...,
#        [-45.58270935],
#        [ 22.17898333],
#        [-19.18887802]]), 'nt': 3001, 'c': array([[ 1.76405235,  1.69902549,  1.94311502, ...,  0.80566324,
#          0.58113609,  0.29204176],
#        [-0.88778575, -1.82029966, -1.74563104, ..., -0.47587193,
#         -0.90899596, -0.17073016],
#        [ 0.17742614, -0.06889189, -0.95156365, ..., -0.93672604,
#         -0.92073924, -0.69545511],
#        ...,
#        [-0.14331315, -0.0831055 ,  0.25482588, ..., -0.31222106,
#         -0.6177298 , -0.52176727],
#        [ 0.925733  ,  1.95669151,  2.00002813, ..., -0.06624656,
#          0.13730201,  0.94923068],
#        [-0.62405388, -0.68059769, -0.63729263, ..., -0.23137086,
#         -0.20782164,  0.00569635]]), 's': array([[ 1.49407907,  1.14387127,  1.10745091, ...,  0.85247859,
#          0.65688659,  0.58569601],
#        [-1.61389785, -1.47121827, -1.70481764, ..., -0.31389971,
#         -0.46448335, -1.03802476],
#        [-1.16514984, -0.49017707, -0.12669789, ...,  1.7505344 ,
#          1.6824682 ,  1.78420909],
#        ...,
#        [ 0.10421642,  0.14971047, -0.67278909, ..., -0.13813087,
#          1.32639984,  1.55281388],
#        [-0.97688115, -0.31313621, -0.88525627, ..., -0.84065459,
#         -0.70067784, -0.26565423],
#        [-0.94979414, -1.45641374, -0.57876988, ..., -1.3590029 ,
#         -1.62577583, -1.09388824]]), 'X': array([[-59.10548154,  35.2562945 , -38.69660792, ...,  34.57781868,
#          -3.27081684, -59.10548154],
#        [-34.8066426 ,  43.82380139, -18.10450163, ...,  40.19624256,
#         -15.65682817, -34.8066426 ],
#        [-28.97564641,  37.15857913, -41.8924706 , ...,  29.51571216,
#         -33.07679923, -28.97564641],
#        ...,
#        [-25.34901839,  27.27060323,   7.41299534, ...,   9.92476671,
#           5.05409929, -25.34901839],
#        [-19.29425733,  -1.61579449,  -2.3881297 , ...,  44.92659181,
#          33.07525974, -19.29425733],
#        [  9.00042795, -28.52920832, -17.9607944 , ...,  51.10491744,
#           0.912626  ,   9.00042795]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[1.        , 0.84008883, 0.69296345, ..., 0.        , 0.        ,
#         0.        ],
#        [0.84008883, 1.        , 0.84008883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.69296345, 0.84008883, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.84008883,
#         0.69296345],
#        [0.        , 0.        , 0.        , ..., 0.84008883, 1.        ,
#         0.84008883],
# ...
#         -71.37121462,  23.62859485]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[ 1.00000000e+00,  2.50000000e-01,  1.25000000e-01, ...,
#         -1.05715992e-04, -5.28579958e-05, -2.64289979e-05],
#        [ 2.50000000e-01,  1.00000000e+00,  2.50000000e-01, ...,
#         -2.11431983e-04, -1.05715992e-04, -5.28579958e-05],
#        [ 1.25000000e-01,  2.50000000e-01,  1.00000000e+00, ...,
#         -4.22863967e-04, -2.11431983e-04, -1.05715992e-04],
#        ...,
#        [-1.05715992e-04, -2.11431983e-04, -4.22863967e-04, ...,
#          1.00000000e+00,  2.50000000e-01,  1.25000000e-01],
#        [-5.28579958e-05, -1.05715992e-04, -2.11431983e-04, ...,
#          2.50000000e-01,  1.00000000e+00,  2.50000000e-01],
#        [-2.64289979e-05, -5.28579958e-05, -1.05715992e-04, ...,
#          1.25000000e-01,  2.50000000e-01,  1.00000000e+00]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'quad', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_quad_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_quad_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_quad_pitch')>, 'y': <Quantity([[0]], 'surr_quad_pitch')>}, 'x': <Quantity([10], 'surr_quad_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_quad_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_quad_pitch')>, <Quantity(10, 'surr_quad_pitch')>], 'y_lim': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'source': <Quantity([    0. 41250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'fields': ['S13'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'quad', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'phi': 1.0471975511965976, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[ -6.92404524],
#        [-40.39761547],
#        [  2.50464286],
#        ...,
#        [ 50.39836973],
#        [-12.13207052],
#        [ -6.92404524]]), 'nt': 3001, 'c': array([[ 1.76405235,  0.82846364,  1.2564624 , ...,  0.47276232,
#          0.63362831,  0.52423855],
#        [-0.88778575, -2.13984437, -0.8945978 , ..., -0.46941495,
#         -1.3314329 ,  0.40952886],
#        [ 0.17742614, -0.34466618, -1.64351493, ..., -0.82458199,
#         -0.56341031, -0.14681787],
#        ...,
#        [-0.14331315,  0.03073311,  0.57065177, ..., -0.773345  ,
#         -0.80698412, -0.22809732],
#        [ 0.925733  ,  2.33588161,  1.18617844, ...,  0.87031558,
#          0.76618868,  2.06066851],
#        [-0.62405388, -0.4350677 , -0.2639882 , ..., -0.69299892,
#         -0.30490032,  0.09155918]]), 's': array([[ 1.70545815,  0.17742492,  1.52406063, ...,  0.22239455,
#          0.26449227,  0.89487101],
#        [-2.33901382, -0.3385047 ,  0.10022246, ..., -0.84969923,
#         -0.39612789, -1.00917376],
#        [-1.3989365 , -0.39719692,  0.03087951, ...,  1.19497523,
#          0.9667504 ,  1.4963462 ],
#        ...,
#        [ 0.21547655,  0.53908094, -0.54803681, ..., -0.74585253,
#          1.57666895,  1.04639066],
#        [ 0.17462559,  0.64189124, -2.09751742, ...,  0.89710145,
#          0.39956768, -0.74096399],
#        [-0.97838942, -0.82640367,  0.8039547 , ..., -1.46635496,
#         -0.19610938, -0.78272994]]), 'X': array([[-59.10548154,  39.85129852, -38.88205781, ...,  34.76326856,
#          -7.86582086, -59.10548154],
#        [ 11.72520906,  49.40969037,  12.8582053 , ...,  31.7210257 ,
#         -39.09943121,  11.72520906],
#        [ -3.04537335,  13.40222049, -51.98474926, ...,   5.2071827 ,
#         -43.12579257,  -3.04537335],
#        ...,
#        [ -6.92404524, -40.39761547,   2.50464286, ...,  50.39836973,
#         -12.13207052,  -6.92404524],
#        [-17.90394882,  32.83156048, -22.00845732, ...,  81.28075257,
#         -19.18707923, -17.90394882],
#        [ 23.62859485, -10.37340181, -45.43897195, ...,  55.05468827,
#         -71.37121462,  23.62859485]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[ 1.00000000e+00,  2.50000000e-01,  1.25000000e-01, ...,
#         -1.05715992e-04, -5.28579958e-05, -2.64289979e-05],
#        [ 2.50000000e-01,  1.00000000e+00,  2.50000000e-01, ...,
#         -2.11431983e-04, -1.05715992e-04, -5.28579958e-05],
#        [ 1.25000000e-01,  2.50000000e-01,  1.00000000e+00, ...,
#         -4.22863967e-04, -2.11431983e-04, -1.05715992e-04],
#        ...,
#        [-1.05715992e-04, -2.11431983e-04, -4.22863967e-04, ...,
#          1.00000000e+00,  2.50000000e-01,  1.25000000e-01],
#        [-5.28579958e-05, -1.05715992e-04, -2.11431983e-04, ...,
#          2.50000000e-01,  1.00000000e+00,  2.50000000e-01],
#        [-2.64289979e-05, -5.28579958e-05, -1.05715992e-04, ...,
#          1.25000000e-01,  2.50000000e-01,  1.00000000e+00]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'quad', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_quad_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_quad_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_quad_pitch')>, 'y': <Quantity([[0]], 'surr_quad_pitch')>}, 'x': <Quantity([10], 'surr_quad_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_quad_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_quad_pitch')>, <Quantity(10, 'surr_quad_pitch')>], 'y_lim': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'source': <Quantity([    0. 48750.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'fields': ['S14'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'quad', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'phi': 1.0471975511965976, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[-17.90394882],
#        [ 32.83156048],
#        [-22.00845732],
#        ...,
#        [ 81.28075257],
#        [-19.18707923],
#        [-17.90394882]]), 'nt': 3001, 'c': array([[ 1.76405235,  0.82846364,  1.2564624 , ...,  0.47276232,
#          0.63362831,  0.52423855],
#        [-0.88778575, -2.13984437, -0.8945978 , ..., -0.46941495,
#         -1.3314329 ,  0.40952886],
#        [ 0.17742614, -0.34466618, -1.64351493, ..., -0.82458199,
#         -0.56341031, -0.14681787],
#        ...,
#        [-0.14331315,  0.03073311,  0.57065177, ..., -0.773345  ,
#         -0.80698412, -0.22809732],
#        [ 0.925733  ,  2.33588161,  1.18617844, ...,  0.87031558,
#          0.76618868,  2.06066851],
#        [-0.62405388, -0.4350677 , -0.2639882 , ..., -0.69299892,
#         -0.30490032,  0.09155918]]), 's': array([[ 1.70545815,  0.17742492,  1.52406063, ...,  0.22239455,
#          0.26449227,  0.89487101],
#        [-2.33901382, -0.3385047 ,  0.10022246, ..., -0.84969923,
#         -0.39612789, -1.00917376],
#        [-1.3989365 , -0.39719692,  0.03087951, ...,  1.19497523,
#          0.9667504 ,  1.4963462 ],
#        ...,
#        [ 0.21547655,  0.53908094, -0.54803681, ..., -0.74585253,
#          1.57666895,  1.04639066],
#        [ 0.17462559,  0.64189124, -2.09751742, ...,  0.89710145,
#          0.39956768, -0.74096399],
#        [-0.97838942, -0.82640367,  0.8039547 , ..., -1.46635496,
#         -0.19610938, -0.78272994]]), 'X': array([[-59.10548154,  39.85129852, -38.88205781, ...,  34.76326856,
#          -7.86582086, -59.10548154],
#        [ 11.72520906,  49.40969037,  12.8582053 , ...,  31.7210257 ,
#         -39.09943121,  11.72520906],
#        [ -3.04537335,  13.40222049, -51.98474926, ...,   5.2071827 ,
#         -43.12579257,  -3.04537335],
#        ...,
#        [ -6.92404524, -40.39761547,   2.50464286, ...,  50.39836973,
#         -12.13207052,  -6.92404524],
#        [-17.90394882,  32.83156048, -22.00845732, ...,  81.28075257,
#         -19.18707923, -17.90394882],
#        [ 23.62859485, -10.37340181, -45.43897195, ...,  55.05468827,
#         -71.37121462,  23.62859485]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[ 1.00000000e+00,  2.50000000e-01,  1.25000000e-01, ...,
#         -1.05715992e-04, -5.28579958e-05, -2.64289979e-05],
#        [ 2.50000000e-01,  1.00000000e+00,  2.50000000e-01, ...,
#         -2.11431983e-04, -1.05715992e-04, -5.28579958e-05],
#        [ 1.25000000e-01,  2.50000000e-01,  1.00000000e+00, ...,
#         -4.22863967e-04, -2.11431983e-04, -1.05715992e-04],
#        ...,
#        [-1.05715992e-04, -2.11431983e-04, -4.22863967e-04, ...,
#          1.00000000e+00,  2.50000000e-01,  1.25000000e-01],
#        [-5.28579958e-05, -1.05715992e-04, -2.11431983e-04, ...,
#          2.50000000e-01,  1.00000000e+00,  2.50000000e-01],
#        [-2.64289979e-05, -5.28579958e-05, -1.05715992e-04, ...,
#          1.25000000e-01,  2.50000000e-01,  1.00000000e+00]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)
# INFO:surrogate:
# {'tol': 0, 'name': 'quad', 'class_name': 'SurrogateSimulationData', 'units': <Unit('meter')>, 'pitch_units': <Quantity(1, 'surr_quad_pitch')>, 'pitch_sym': 'ϕ', 'pitch': <Quantity(1, 'surr_quad_pitch')>, 'probe_grid': {'x': <Quantity([[10]], 'surr_quad_pitch')>, 'y': <Quantity([[0]], 'surr_quad_pitch')>}, 'x': <Quantity([10], 'surr_quad_pitch')>, 'nx': 1, 'y': <Quantity([0], 'surr_quad_pitch')>, 'ny': 1, 'nz': 1, 'x_lim': [<Quantity(10, 'surr_quad_pitch')>, <Quantity(10, 'surr_quad_pitch')>], 'y_lim': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'source': <Quantity([    0. 56250.], 'micrometer')>, 'dimensions': [<Quantity(0, 'surr_quad_pitch')>, <Quantity(0, 'surr_quad_pitch')>], 'fields': ['S15'], 'fs': <Quantity(50, 'hertz')>, 'surr_data_args': {'type': 'quad', 'n_samples': 3001, 'n_sources': 16, 'fs': <Quantity(50, 'hertz')>, 'phi': 1.0471975511965976, 'surrogate_k': 0}, 'coord_strs': ['@origin'], 'coord_inds': {'@origin': (0, 0)}, 'data': array([[ 23.62859485],
#        [-10.37340181],
#        [-45.43897195],
#        ...,
#        [ 55.05468827],
#        [-71.37121462],
#        [ 23.62859485]]), 'nt': 3001, 'c': array([[ 1.76405235,  0.82846364,  1.2564624 , ...,  0.47276232,
#          0.63362831,  0.52423855],
#        [-0.88778575, -2.13984437, -0.8945978 , ..., -0.46941495,
#         -1.3314329 ,  0.40952886],
#        [ 0.17742614, -0.34466618, -1.64351493, ..., -0.82458199,
#         -0.56341031, -0.14681787],
#        ...,
#        [-0.14331315,  0.03073311,  0.57065177, ..., -0.773345  ,
#         -0.80698412, -0.22809732],
#        [ 0.925733  ,  2.33588161,  1.18617844, ...,  0.87031558,
#          0.76618868,  2.06066851],
#        [-0.62405388, -0.4350677 , -0.2639882 , ..., -0.69299892,
#         -0.30490032,  0.09155918]]), 's': array([[ 1.70545815,  0.17742492,  1.52406063, ...,  0.22239455,
#          0.26449227,  0.89487101],
#        [-2.33901382, -0.3385047 ,  0.10022246, ..., -0.84969923,
#         -0.39612789, -1.00917376],
#        [-1.3989365 , -0.39719692,  0.03087951, ...,  1.19497523,
#          0.9667504 ,  1.4963462 ],
#        ...,
#        [ 0.21547655,  0.53908094, -0.54803681, ..., -0.74585253,
#          1.57666895,  1.04639066],
#        [ 0.17462559,  0.64189124, -2.09751742, ...,  0.89710145,
#          0.39956768, -0.74096399],
#        [-0.97838942, -0.82640367,  0.8039547 , ..., -1.46635496,
#         -0.19610938, -0.78272994]]), 'X': array([[-59.10548154,  39.85129852, -38.88205781, ...,  34.76326856,
#          -7.86582086, -59.10548154],
#        [ 11.72520906,  49.40969037,  12.8582053 , ...,  31.7210257 ,
#         -39.09943121,  11.72520906],
#        [ -3.04537335,  13.40222049, -51.98474926, ...,   5.2071827 ,
#         -43.12579257,  -3.04537335],
#        ...,
#        [ -6.92404524, -40.39761547,   2.50464286, ...,  50.39836973,
#         -12.13207052,  -6.92404524],
#        [-17.90394882,  32.83156048, -22.00845732, ...,  81.28075257,
#         -19.18707923, -17.90394882],
#        [ 23.62859485, -10.37340181, -45.43897195, ...,  55.05468827,
#         -71.37121462,  23.62859485]]), 't': <Quantity([0.000e+00 2.000e-02 4.000e-02 ... 5.996e+01 5.998e+01 6.000e+01], 'second')>, 'K': array([[ 1.00000000e+00,  2.50000000e-01,  1.25000000e-01, ...,
#         -1.05715992e-04, -5.28579958e-05, -2.64289979e-05],
#        [ 2.50000000e-01,  1.00000000e+00,  2.50000000e-01, ...,
#         -2.11431983e-04, -1.05715992e-04, -5.28579958e-05],
#        [ 1.25000000e-01,  2.50000000e-01,  1.00000000e+00, ...,
#         -4.22863967e-04, -2.11431983e-04, -1.05715992e-04],
#        ...,
#        [-1.05715992e-04, -2.11431983e-04, -4.22863967e-04, ...,
#          1.00000000e+00,  2.50000000e-01,  1.25000000e-01],
#        [-5.28579958e-05, -1.05715992e-04, -2.11431983e-04, ...,
#          2.50000000e-01,  1.00000000e+00,  2.50000000e-01],
#        [-2.64289979e-05, -5.28579958e-05, -1.05715992e-04, ...,
#          1.25000000e-01,  2.50000000e-01,  1.00000000e+00]]), 'colors': {'@origin': (0.0, 0.4588235294117647, 0.7705882352941177, 1.0)}} <class 'surrogate.SurrogateSimulationData'>
# 1 m = 1 m
# x_lim: 10 meter to 10 meter
# y_lim: 0 meter to 0 meter
# x-y Dimensions: [<Quantity(0, 'meter')>, <Quantity(0, 'meter')>]
# x-range: 10.000 meter, ... 10.000 meter (1 points)
# y-range: 0.000 meter, ... 0.000 meter (1 points)
# fs: 50 hertz
# Sources:
#   0: =     S0 @ (x = +0 micrometer, y = -26250 micrometer)
#   1: =     S1 @ (x = +0 micrometer, y = -18750 micrometer)
#   2: =     S2 @ (x = +0 micrometer, y = -11250 micrometer)
#   3: =     S3 @ (x = +0 micrometer, y = -3750 micrometer)
#   4: =     S4 @ (x = +0 micrometer, y = +3750 micrometer)
#   5: =     S5 @ (x = +0 micrometer, y = +11250 micrometer)
#   6: =     S6 @ (x = +0 micrometer, y = +18750 micrometer)
#   7: =     S7 @ (x = +0 micrometer, y = +26250 micrometer)

# %%
iprb = 0

# %%
F = data["16Ts"]
dd= array(list(F.pairs_um.keys()))
dd[dd>=0]
# Out:
# array([     0,   8000,  16000,  24000,  32000,  40000,  48000,  56000,
#         64000,  72000,  80000,  88000,  96000, 104000, 112000, 120000])

# %%
d = 16000
f = 3
y  = F.rho[iprb][d][0][f]
la = F.la[iprb][d][0,f,0]
mu = F.mu[iprb][d][0,f,0]
print(la, mu, std(y))
la_ = la/std(y)
mu_ = mu/std(y)
y_  =  y/std(y)
print(la_, mu_)
# Out:
# 0.11574082514785504 0.01367020942480231 0.07043113703961949
# 1.6433189923193712 0.1940932661233686

# %%
plot(y_)

# %%
reload(fpt)
reload(corrm)
data = y_
Exp0 = corrm.CorrModel(model = "exp", name = "Exp0", intermittent = False, σ_penalty = 0, γ_pr_mean = 0.95, γ_pr_strength = 1)
Exp0.fit(y_)
Exp = corrm.CorrModel(model = "exp", name = "Exp", intermittent = True, σ_penalty = 0, γ_pr_mean = 0.95, γ_pr_strength = 1)
Exp.fit(y_)
Gam = corrm.CorrModel(model = "gamma", name = "Gam", intermittent = True, init_params = Exp.model.params)
Gam.fit(y_, method = "TNC")
Gig = corrm.CorrModel(model = "gig", name="Gig",intermittent = True, init_params = Gam.model.params)
Gig.fit(y_, method = "TNC")
Gig0 = corrm.CorrModel(model = "gig", name="Gig0",intermittent = False, init_params = Gig.model.params)
Gig0.fit(y_, method = "TNC")
Gam0 = corrm.CorrModel(model = "gamma", name="Gam0",intermittent = False, init_params = Gam.model.params)
Gam0.fit(y_, method = "TNC")

#Gam2 = corrm.IntermittentGamma(init_params = Gig0.model.params, name="GamFromGig")
figure(figsize=(12,5))
#corrm.plot_cdfs(data, [Exp0, Exp, Gam0, Gam, Gig0,Gig])#, Gig1])#, labs=["true", "Gam", "Gig", "Gig (γ)"])
corrm.plot_cdfs(data, [Exp0, Exp, Gam, Gig], legend_args={"labelspacing":0, "fontsize":6})
# Out:
#              corr_models 2023/09/12 19:35:51     INFO:
#              corr_models 2023/09/12 19:35:51     INFO: ********************************************************************************
#              corr_models 2023/09/12 19:35:51     INFO: Initializing model IntermittentExponential named 'Exp0' id(self)=139704023941072.
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.init_params = None
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.params      = None
#              corr_models 2023/09/12 19:35:51     INFO: Fitting IntermittentExponential model Exp0.
#              corr_models 2023/09/12 19:35:51     INFO: Initializing from fit using γ=1.
#              corr_models 2023/09/12 19:35:51     INFO: Found 0 intermittent points, 3445 positive, 447 negative values.
#              corr_models 2023/09/12 19:35:51     INFO: Fit exponential distribution to positive values, λ=0.846.
#              corr_models 2023/09/12 19:35:51     INFO: Fit exponential distribution to negative values, μ=0.187.
#              corr_models 2023/09/12 19:35:51     INFO: Parameters initialized to λ=0.85, μ=0.19, σ=nan, γ=1.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    0: n+=3445, n-= 447 n0=   0 λ=0.88, μ=0.15, σ=0, γ=1
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    1: n+=3445, n-= 447 n0=   0 λ=0.88, μ=0.15, σ=0, γ=1
#              corr_models 2023/09/12 19:35:51     INFO: Converged.
#              corr_models 2023/09/12 19:35:51     INFO:
#              corr_models 2023/09/12 19:35:51     INFO: ********************************************************************************
#              corr_models 2023/09/12 19:35:51     INFO: Initializing model IntermittentExponential named 'Exp' id(self)=139704027544448.
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.init_params = None
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.params      = None
#              corr_models 2023/09/12 19:35:51     INFO: Fitting IntermittentExponential model Exp.
#              corr_models 2023/09/12 19:35:51     INFO: Initializing from fit using γ=0.95.
#              corr_models 2023/09/12 19:35:51     INFO: Found 195 intermittent points, 3309 positive, 388 negative values.
#              corr_models 2023/09/12 19:35:51     INFO: Fit exponential distribution to positive values, λ=0.881.
#              corr_models 2023/09/12 19:35:51     INFO: Fit exponential distribution to negative values, μ=0.215.
#              corr_models 2023/09/12 19:35:51     INFO: Parameters initialized to λ=0.88, μ=0.21, σ=0.00075, γ=0.95.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    0: n+=3309, n-= 388 n0= 195 λ=0.92, μ=0.16, σ=0.00079, γ=0.95
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    1: n+=3297, n-= 387 n0= 208 λ=0.93, μ=0.16, σ=0.0009, γ=0.95
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    2: n+=3286, n-= 383 n0= 223 λ=0.93, μ=0.16, σ=0.001, γ=0.95
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    3: n+=3282, n-= 380 n0= 230 λ=0.93, μ=0.16, σ=0.0011, γ=0.95
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    4: n+=3277, n-= 379 n0= 236 λ=0.93, μ=0.16, σ=0.0012, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    5: n+=3273, n-= 378 n0= 241 λ=0.93, μ=0.16, σ=0.0012, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    6: n+=3268, n-= 377 n0= 247 λ=0.93, μ=0.16, σ=0.0013, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    7: n+=3261, n-= 374 n0= 257 λ=0.94, μ=0.16, σ=0.0014, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    8: n+=3255, n-= 366 n0= 271 λ=0.94, μ=0.16, σ=0.0016, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    9: n+=3245, n-= 364 n0= 283 λ=0.94, μ=0.16, σ=0.0017, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   10: n+=3235, n-= 362 n0= 295 λ=0.95, μ=0.16, σ=0.0018, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   11: n+=3232, n-= 361 n0= 299 λ=0.95, μ=0.16, σ=0.0019, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   12: n+=3229, n-= 360 n0= 303 λ=0.95, μ=0.16, σ=0.0019, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   13: n+=3227, n-= 359 n0= 306 λ=0.95, μ=0.16, σ=0.002, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   14: n+=3225, n-= 359 n0= 308 λ=0.95, μ=0.16, σ=0.002, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   15: n+=3223, n-= 359 n0= 310 λ=0.95, μ=0.16, σ=0.002, γ=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   16: n+=3223, n-= 359 n0= 310 λ=0.95, μ=0.16, σ=0.002, γ=0.94
#              corr_models 2023/09/12 19:35:51     INFO: Converged.
#              corr_models 2023/09/12 19:35:51     INFO:
#              corr_models 2023/09/12 19:35:51     INFO: ********************************************************************************
#              corr_models 2023/09/12 19:35:51     INFO: Initializing model IntermittentGamma named 'Gam' id(self)=139704023900272.
#              corr_models 2023/09/12 19:35:51     INFO: Casting IntermittentExponential to IntermittentGamma.
#              corr_models 2023/09/12 19:35:51     INFO: Cast params: λ=0.95, μ=0.16, σ=0.002, γ=0.94 -> λ=0.95, μ=0.16, σ=0.002, γ=0.94, k=1, m=1
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.init_params = λ=0.95, μ=0.16, σ=0.002, γ=0.94, k=1, m=1
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.params      = λ=0.95, μ=0.16, σ=0.002, γ=0.94, k=1, m=1
#              corr_models 2023/09/12 19:35:51     INFO: Fitting IntermittentGamma model Gam.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    0: n+=3223, n-= 359 n0= 310 λ=1.4, μ=0.21, σ=0.002, γ=0.92, k=0.66, m=1
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    1: n+=3267, n-= 358 n0= 267 λ=1.5, μ=0.22, σ=0.0018, γ=0.93, k=0.61, m=0.98
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    2: n+=3312, n-= 359 n0= 221 λ=1.5, μ=0.22, σ=0.0016, γ=0.94, k=0.58, m=0.97
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    3: n+=3348, n-= 361 n0= 183 λ=1.6, μ=0.22, σ=0.0016, γ=0.95, k=0.56, m=0.96
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    4: n+=3393, n-= 363 n0= 136 λ=1.6, μ=0.23, σ=0.0015, γ=0.97, k=0.53, m=0.94
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    5: n+=3445, n-= 365 n0=  82 λ=1.7, μ=0.23, σ=0.0017, γ=0.98, k=0.5, m=0.92
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    6: n+=3445, n-= 366 n0=  81 λ=1.7, μ=0.23, σ=0.0016, γ=0.98, k=0.5, m=0.92
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    7: n+=3445, n-= 367 n0=  80 λ=1.7, μ=0.23, σ=0.0016, γ=0.98, k=0.5, m=0.92
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    8: n+=3445, n-= 368 n0=  79 λ=1.7, μ=0.23, σ=0.0016, γ=0.98, k=0.5, m=0.91
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    9: n+=3445, n-= 372 n0=  75 λ=1.7, μ=0.23, σ=0.0014, γ=0.98, k=0.5, m=0.9
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   10: n+=3445, n-= 378 n0=  69 λ=1.7, μ=0.22, σ=0.0012, γ=0.98, k=0.5, m=0.89
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   11: n+=3445, n-= 381 n0=  66 λ=1.7, μ=0.22, σ=0.001, γ=0.98, k=0.5, m=0.88
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   12: n+=3445, n-= 385 n0=  62 λ=1.7, μ=0.22, σ=0.0009, γ=0.98, k=0.5, m=0.87
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   13: n+=3445, n-= 388 n0=  59 λ=1.7, μ=0.22, σ=0.0008, γ=0.98, k=0.5, m=0.87
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   14: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   15: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   16: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   17: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   18: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   19: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   20: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   21: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   22: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   23: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   24: n+=3445, n-= 389 n0=  58 λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51     INFO: Converged.
#              corr_models 2023/09/12 19:35:51     INFO:
#              corr_models 2023/09/12 19:35:51     INFO: ********************************************************************************
#              corr_models 2023/09/12 19:35:51     INFO: Initializing model IntermittentGeneralizedInverseGaussian named 'Gig' id(self)=139704023901712.
#              corr_models 2023/09/12 19:35:51     INFO: Casting IntermittentGamma to IntermittentGeneralizedInversGaussian.
#              corr_models 2023/09/12 19:35:51     INFO: Cast params: λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86 -> λ=0.00066, μ=0.00024, σ=0.00078, γ=0.99, k=0.5, m=0.86, α=0.00076, β=0.0021
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.init_params = λ=0.00066, μ=0.00024, σ=0.00078, γ=0.99, k=0.5, m=0.86, α=0.00076, β=0.0021
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.params      = λ=0.00066, μ=0.00024, σ=0.00078, γ=0.99, k=0.5, m=0.86, α=0.00076, β=0.0021
#              corr_models 2023/09/12 19:35:51     INFO: Fitting IntermittentGeneralizedInverseGaussian model Gig.
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|x_n-x_(n-1)| ~= 0) after 9 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    0: n+=3445, n-= 419 n0=  28 λ=0.0028, μ=0.00012, σ=0.00036, γ=0.99, k=0.5, m=0.86, α=0.0031, β=0.0011
#              corr_models 2023/09/12 19:35:51    DEBUG: Max. number of function evaluations reached after 11 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    1: n+=3444, n-= 421 n0=  27 λ=0.0029, μ=6.1e-05, σ=0.00019, γ=0.99, k=0.53, m=0.81, α=0.0036, β=0.00055
#              corr_models 2023/09/12 19:35:51    DEBUG: Max. number of function evaluations reached after 19 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    2: n+=3444, n-= 423 n0=  25 λ=0.0036, μ=4e-05, σ=0.00013, γ=0.99, k=0.51, m=0.75, α=0.0044, β=0.00034
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 17 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    3: n+=3443, n-= 426 n0=  23 λ=0.0033, μ=2.7e-05, σ=9.7e-05, γ=0.99, k=0.5, m=0.71, α=0.0039, β=0.00022
#              corr_models 2023/09/12 19:35:51    DEBUG: Max. number of function evaluations reached after 18 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    4: n+=3444, n-= 427 n0=  21 λ=0.0026, μ=1.7e-05, σ=8.9e-05, γ=0.99, k=0.49, m=0.68, α=0.003, β=0.00013
#              corr_models 2023/09/12 19:35:51    DEBUG: Max. number of function evaluations reached after 18 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    5: n+=3444, n-= 428 n0=  20 λ=0.0022, μ=2.8e-05, σ=8.1e-05, γ=0.99, k=0.5, m=0.64, α=0.0026, β=0.00019
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 16 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    6: n+=3444, n-= 429 n0=  19 λ=0.0019, μ=5.8e-05, σ=7.4e-05, γ=1, k=0.5, m=0.58, α=0.0022, β=0.00033
#              corr_models 2023/09/12 19:35:51    DEBUG: Max. number of function evaluations reached after 21 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    7: n+=3444, n-= 435 n0=  13 λ=0.0016, μ=0.00012, σ=6.3e-05, γ=1, k=0.5, m=0.5, α=0.0019, β=0.00057
#              corr_models 2023/09/12 19:35:51    DEBUG: Max. number of function evaluations reached after 20 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    8: n+=3445, n-= 443 n0=   4 λ=0.0014, μ=0.00015, σ=4.1e-05, γ=1, k=0.5, m=0.47, α=0.0017, β=0.00067
#              corr_models 2023/09/12 19:35:51    DEBUG: Max. number of function evaluations reached after 19 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    9: n+=3445, n-= 447 n0=   0 λ=0.0012, μ=0.00018, σ=0.032, γ=1, k=0.5, m=0.42, α=0.0014, β=0.00077
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 16 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   10: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00021, σ=0.032, γ=1, k=0.5, m=0.4, α=0.0014, β=0.00086
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 20 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   11: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00022, σ=0.032, γ=1, k=0.5, m=0.4, α=0.0013, β=0.00091
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 17 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   12: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00022, σ=0.032, γ=1, k=0.5, m=0.39, α=0.0013, β=0.00094
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 13 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   13: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00023, σ=0.032, γ=1, k=0.5, m=0.39, α=0.0013, β=0.00097
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 9 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   14: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00098
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 14 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   15: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00099
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 6 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   16: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00099
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 2 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   17: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00099
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 5 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   18: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.001
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 4 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   19: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.001
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 4 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   20: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.001
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 4 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   21: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.001
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 1 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   22: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.001
#              corr_models 2023/09/12 19:35:51     INFO: Converged.
#              corr_models 2023/09/12 19:35:51     INFO:
#              corr_models 2023/09/12 19:35:51     INFO: ********************************************************************************
#              corr_models 2023/09/12 19:35:51     INFO: Initializing model IntermittentGeneralizedInverseGaussian named 'Gig0' id(self)=139704021151072.
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.init_params = λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.001
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.params      = λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.001
#              corr_models 2023/09/12 19:35:51     INFO: Fitting IntermittentGeneralizedInverseGaussian model Gig0.
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 1 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    0: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.001
#              corr_models 2023/09/12 19:35:51    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 1 iterations.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    1: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.001
#              corr_models 2023/09/12 19:35:51     INFO: Converged.
#              corr_models 2023/09/12 19:35:51     INFO:
#              corr_models 2023/09/12 19:35:51     INFO: ********************************************************************************
#              corr_models 2023/09/12 19:35:51     INFO: Initializing model IntermittentGamma named 'Gam0' id(self)=139704020790768.
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.init_params = λ=1.7, μ=0.22, σ=0.00078, γ=1, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51     INFO: Initialized self.params      = λ=1.7, μ=0.22, σ=0.00078, γ=1, k=0.5, m=0.86
#              corr_models 2023/09/12 19:35:51     INFO: Fitting IntermittentGamma model Gam0.
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    0: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    1: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    2: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    3: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    4: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    5: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    6: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    7: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    8: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter    9: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   10: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   11: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   12: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   13: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   14: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   15: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   16: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   17: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   18: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   19: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   20: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51    DEBUG: Iter   21: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 19:35:51     INFO: Converged.
#              corr_models 2023/09/12 19:35:51     INFO: Plotting cdf for model: Exp0, IntermittentExponential(λ=0.88, μ=0.15, σ=0, γ=1)
#              corr_models 2023/09/12 19:35:51     INFO: Plotting cdf for model: Exp, IntermittentExponential(λ=0.95, μ=0.16, σ=0.002, γ=0.94)
#              corr_models 2023/09/12 19:35:52     INFO: Plotting cdf for model: Gam, IntermittentGamma(λ=1.7, μ=0.22, σ=0.00078, γ=0.99, k=0.5, m=0.86)
#              corr_models 2023/09/12 19:35:52    DEBUG: agamma_cdf: Z0 = 0.29883474773927293, Z1 = 2.3362188035763647
#              corr_models 2023/09/12 19:35:52    DEBUG: agamma_cdf: Z0 = 0.29883474773927293, Z1 = 2.3362188035763647
#              corr_models 2023/09/12 19:35:52     INFO: Plotting cdf for model: Gig, IntermittentGeneralizedInverseGaussian(λ=0.0011, μ=0.00024, σ=0.032, γ=1, k=0.5, m=0.38, α=0.0013, β=0.001)

# %%
reload(fpt)
reload(corrm)
data = y_
Gig = corrm.CorrModel(model = "gig", name="Gig", intermittent = False, init_mode="ancestral", γ_pr_mean = 0.8, γ_pr_strength=2)

# %%
Gig.fit(data, method = "TNC")
# Out:
#              corr_models 2023/09/12 22:01:26     INFO: Using ancestral initialization.
#              corr_models 2023/09/12 22:01:26     INFO:
#              corr_models 2023/09/12 22:01:26     INFO: ********************************************************************************
#              corr_models 2023/09/12 22:01:26     INFO: Initializing model IntermittentExponential named 'Gig_0' id(self)=139704022973696.
#              corr_models 2023/09/12 22:01:26     INFO: Initialized self.init_params = None
#              corr_models 2023/09/12 22:01:26     INFO: Initialized self.params      = None
#              corr_models 2023/09/12 22:01:26     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=1, γ_pr_strength=inf
#              corr_models 2023/09/12 22:01:26     INFO: Fitting IntermittentExponential model Gig_0.
#              corr_models 2023/09/12 22:01:26     INFO: Initializing from fit using γ=1.
#              corr_models 2023/09/12 22:01:26     INFO: Found 0 intermittent points, 3445 positive, 447 negative values.
#              corr_models 2023/09/12 22:01:26     INFO: Fit exponential distribution to positive values, λ=0.846.
#              corr_models 2023/09/12 22:01:26     INFO: Fit exponential distribution to negative values, μ=0.187.
#              corr_models 2023/09/12 22:01:26     INFO: Parameters initialized to λ=0.85, μ=0.19, σ=nan, γ=1.
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    0: n+=3445, n-= 447 n0=   0 λ=0.88, μ=0.15, σ=0, γ=1
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    1: n+=3445, n-= 447 n0=   0 λ=0.88, μ=0.15, σ=0, γ=1
#              corr_models 2023/09/12 22:01:26     INFO: Converged.
#              corr_models 2023/09/12 22:01:26     INFO:
#              corr_models 2023/09/12 22:01:26     INFO: ********************************************************************************
#              corr_models 2023/09/12 22:01:26     INFO: Initializing model IntermittentGamma named 'Gig_1' id(self)=139704023822592.
#              corr_models 2023/09/12 22:01:26     INFO: Casting IntermittentExponential to IntermittentGamma.
#              corr_models 2023/09/12 22:01:26     INFO: Cast params: λ=0.88, μ=0.15, σ=0, γ=1 -> λ=0.88, μ=0.15, σ=0, γ=1, k=1, m=1
#              corr_models 2023/09/12 22:01:26     INFO: Initialized self.init_params = λ=0.88, μ=0.15, σ=0, γ=1, k=1, m=1
#              corr_models 2023/09/12 22:01:26     INFO: Initialized self.params      = λ=0.88, μ=0.15, σ=0, γ=1, k=1, m=1
#              corr_models 2023/09/12 22:01:26     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=1, γ_pr_strength=inf
#              corr_models 2023/09/12 22:01:26     INFO: Fitting IntermittentGamma model Gig_1.
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    0: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    1: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    2: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    3: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    4: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    5: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    6: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    7: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    8: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    9: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter   10: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter   11: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter   12: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter   13: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter   14: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter   15: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter   16: n+=3445, n-= 447 n0=   0 λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73
#              corr_models 2023/09/12 22:01:26     INFO: Converged.
#              corr_models 2023/09/12 22:01:26     INFO:
#              corr_models 2023/09/12 22:01:26     INFO: ********************************************************************************
#              corr_models 2023/09/12 22:01:26     INFO: Initializing model IntermittentGeneralizedInverseGaussian named 'Gig' id(self)=139704022970960.
#              corr_models 2023/09/12 22:01:26     INFO: Casting IntermittentGamma to IntermittentGeneralizedInversGaussian.
#              corr_models 2023/09/12 22:01:26     INFO: Cast params: λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73 -> λ=0.00067, μ=0.00023, σ=0, γ=1, k=0.48, m=0.73, α=0.00074, β=0.0022
#              corr_models 2023/09/12 22:01:26     INFO: Initialized self.init_params = λ=0.00067, μ=0.00023, σ=0, γ=1, k=0.48, m=0.73, α=0.00074, β=0.0022
#              corr_models 2023/09/12 22:01:26     INFO: Initialized self.params      = λ=0.00067, μ=0.00023, σ=0, γ=1, k=0.48, m=0.73, α=0.00074, β=0.0022
#              corr_models 2023/09/12 22:01:26     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=1, γ_pr_strength=inf
#              corr_models 2023/09/12 22:01:26     INFO: Fitting IntermittentGeneralizedInverseGaussian model Gig.
#              corr_models 2023/09/12 22:01:26    DEBUG: Max. number of function evaluations reached after 19 iterations.
#              corr_models 2023/09/12 22:01:26    DEBUG: Iter    0: n+=3445, n-= 447 n0=   0 λ=0.00086, μ=0.00015, σ=0, γ=1, k=0.49, m=0.61, α=0.00099, β=0.0012
#              corr_models 2023/09/12 22:01:27    DEBUG: Max. number of function evaluations reached after 17 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter    1: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.0002, σ=0, γ=1, k=0.49, m=0.5, α=0.0013, β=0.0012
#              corr_models 2023/09/12 22:01:27    DEBUG: Max. number of function evaluations reached after 14 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter    2: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00021, σ=0, γ=1, k=0.5, m=0.44, α=0.0013, β=0.001
#              corr_models 2023/09/12 22:01:27    DEBUG: Max. number of function evaluations reached after 22 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter    3: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00021, σ=0, γ=1, k=0.5, m=0.42, α=0.0013, β=0.00099
#              corr_models 2023/09/12 22:01:27    DEBUG: Max. number of function evaluations reached after 20 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter    4: n+=3445, n-= 447 n0=   0 λ=0.001, μ=0.00022, σ=0, γ=1, k=0.5, m=0.4, α=0.0012, β=0.00097
#              corr_models 2023/09/12 22:01:27    DEBUG: Max. number of function evaluations reached after 18 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter    5: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00022, σ=0, γ=1, k=0.5, m=0.39, α=0.0013, β=0.00095
#              corr_models 2023/09/12 22:01:27    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 17 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter    6: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00023, σ=0, γ=1, k=0.5, m=0.39, α=0.0013, β=0.00095
#              corr_models 2023/09/12 22:01:27    DEBUG: Max. number of function evaluations reached after 14 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter    7: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00023, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00096
#              corr_models 2023/09/12 22:01:27    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 12 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter    8: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00023, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00097
#              corr_models 2023/09/12 22:01:27    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 12 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter    9: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00023, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00097
#              corr_models 2023/09/12 22:01:27    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 4 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter   10: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00023, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00097
#              corr_models 2023/09/12 22:01:27    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 4 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter   11: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00097
#              corr_models 2023/09/12 22:01:27    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 8 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter   12: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00099
#              corr_models 2023/09/12 22:01:27    DEBUG: Converged (|f_n-f_(n-1)| ~= 0) after 1 iterations.
#              corr_models 2023/09/12 22:01:27    DEBUG: Iter   13: n+=3445, n-= 447 n0=   0 λ=0.0011, μ=0.00024, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00099
#              corr_models 2023/09/12 22:01:27     INFO: Converged.
# Gig, IntermittentGeneralizedInverseGaussian(Params(λ=0.0011, μ=0.00024, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00099))

# %%
figure(figsize=(12,5))
#corrm.plot_cdfs(data, [Exp0, Exp, Gam0, Gam, Gig0,Gig])#, Gig1])#, labs=["true", "Gam", "Gig", "Gig (γ)"])
corrm.plot_cdfs(data, Gig.models, legend_args={"labelspacing":0, "fontsize":6})
# Out:
#              corr_models 2023/09/12 21:59:52     INFO: Plotting cdf for model: Gig_0, IntermittentExponential(λ=0.88, μ=0.15, σ=0, γ=1)
#              corr_models 2023/09/12 21:59:52     INFO: Plotting cdf for model: Gig_1, IntermittentGamma(λ=1.8, μ=0.21, σ=0, γ=1, k=0.48, m=0.73)
#              corr_models 2023/09/12 21:59:52    DEBUG: agamma_cdf: Z0 = 0.40220190976857717, Z1 = 2.4373214539339725
#              corr_models 2023/09/12 21:59:52    DEBUG: agamma_cdf: Z0 = 0.40220190976857717, Z1 = 2.4373214539339725
#              corr_models 2023/09/12 21:59:52     INFO: Plotting cdf for model: Gig, IntermittentGeneralizedInverseGaussian(λ=0.0011, μ=0.00024, σ=0, γ=1, k=0.5, m=0.38, α=0.0013, β=0.00099)
