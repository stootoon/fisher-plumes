# %% [markdown]
# # Correlation models

# %% [markdown]
# In this notebook we will be testing the corr_models.

# %% [markdown]
# # Code

# %%
# %pylab inline
from importlib import reload
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from copy import deepcopy

# %%
import corr_models as corrm

# %% [markdown]
# # Exponential model

# %%
reload(corrm)
y, labs = corrm.Exponential.gen_data(1001, corrm.Exponential.Params(2,1))
corrm.plot_data(y, labs)

# %%
reload(corrm)
mdl = corrm.Exponential()
mdl.fit(y)
corrm.plot_cdfs(y, [mdl])
# Out:
#              corr_models 2023/09/07 14:25:27     INFO: Fitting exponential model Model.
#              corr_models 2023/09/07 14:25:27     INFO: Initializing from fit.
#              corr_models 2023/09/07 14:25:27     INFO: Found 664 positive, 337 negative values.
#              corr_models 2023/09/07 14:25:27     INFO: Fit exponential distribution to positive values, λ=1.95.
#              corr_models 2023/09/07 14:25:27     INFO: Fit exponential distribution to negative values, μ=0.993.
#              corr_models 2023/09/07 14:25:27     INFO: Parameters initialized to λ=1.9, μ=0.99.
#              corr_models 2023/09/07 14:25:27    DEBUG: Iter    0: n+= 664, n-= 337 λ=1.9, μ=0.99
#              corr_models 2023/09/07 14:25:27    DEBUG: Iter    1: n+= 664, n-= 337 λ=1.9, μ=0.99
#              corr_models 2023/09/07 14:25:27     INFO: Converged.
#              corr_models 2023/09/07 14:25:27     INFO: Plotting cdf for model: Model, Exponential(λ=1.9, μ=0.99)

# %% [markdown]
# # Intermittent Exponential model

# %%
reload(corrm)
true_params = corrm.IntermittentExponential.Params(2,1,0.1,0.2)
y, labs = corrm.IntermittentExponential.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentExponential(init_params = true_params, name = "True Model")
mdl = corrm.IntermittentExponential(#corrm.IntermittentExponential.Params(λ=2,μ=1,σ=0.001,γ=0.2),
    name = "Fit",
                                    σ_penalty = 0, γ_pr_mean = 0.2, γ_pr_strength = 1)
mdl.fit(y)
corrm.plot_cdfs(y, [true_mdl, mdl])
print(mdl)
# Out:
#              corr_models 2023/09/07 14:29:41     INFO: Fitting IntermittentExponential model Fit.
#              corr_models 2023/09/07 14:29:41     INFO: Initializing from fit using γ=0.2.
#              corr_models 2023/09/07 14:29:41     INFO: Found 801 intermittent points, 133 positive, 67 negative values.
#              corr_models 2023/09/07 14:29:41     INFO: Fit exponential distribution to positive values, λ=1.88.
#              corr_models 2023/09/07 14:29:41     INFO: Fit exponential distribution to negative values, μ=1.14.
#              corr_models 2023/09/07 14:29:41     INFO: Parameters initialized to λ=1.9, μ=1.1, σ=0.089, γ=0.2.
#              corr_models 2023/09/07 14:29:41    DEBUG: Iter    0: n+= 133, n-=  67 n0= 801 λ=1.9, μ=1.1, σ=0.089, γ=0.2
#              corr_models 2023/09/07 14:29:41    DEBUG: Iter    1: n+= 112, n-=  46 n0= 843 λ=2.4, μ=1.3, σ=0.099, γ=0.18
#              corr_models 2023/09/07 14:29:41    DEBUG: Iter    2: n+= 108, n-=  43 n0= 850 λ=2.5, μ=1.3, σ=0.1, γ=0.18
#              corr_models 2023/09/07 14:29:41    DEBUG: Iter    3: n+= 108, n-=  39 n0= 854 λ=2.6, μ=1.4, σ=0.1, γ=0.17
#              corr_models 2023/09/07 14:29:41    DEBUG: Iter    4: n+= 108, n-=  38 n0= 855 λ=2.6, μ=1.4, σ=0.1, γ=0.17
#              corr_models 2023/09/07 14:29:41    DEBUG: Iter    5: n+= 108, n-=  38 n0= 855 λ=2.6, μ=1.4, σ=0.1, γ=0.17
#              corr_models 2023/09/07 14:29:41     INFO: Converged.
#              corr_models 2023/09/07 14:29:41     INFO: Plotting cdf for model: True Model, IntermittentExponential(λ=2, μ=1, σ=0.1, γ=0.2)
#              corr_models 2023/09/07 14:29:41     INFO: Plotting cdf for model: Fit, IntermittentExponential(λ=2.6, μ=1.4, σ=0.1, γ=0.17)
# Fit, IntermittentExponential(λ=2.6, μ=1.4, σ=0.1, γ=0.17)

# %% [markdown]
# # Intermittent Gamma model

# %%
reload(corrm)
true_params = corrm.IntermittentGamma.Params(2,1,0.01,0.8, 0.2,0.1)
y, labs = corrm.IntermittentGamma.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentGamma(init_params = true_params)
mdl = corrm.IntermittentGamma(#corrm.IntermittentGamma.Params(λ=2,μ=1,σ=0.001,γ=0.2,k=1,m=1),
                                    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
mdl.fit(y)
figure(figsize=(8,4))
corrm.plot_cdfs(y, [true_mdl, mdl])
# Out:
#              corr_models 2023/09/07 14:30:01     INFO: Fitting IntermittentGamma model Model.
#              corr_models 2023/09/07 14:30:01     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/07 14:30:01     INFO: Found 201 intermittent points, 387 positive, 413 negative values.
#              corr_models 2023/09/07 14:30:01     INFO: Fit gamma distribution to positive values, k=0.257, λ=1.21.
#              corr_models 2023/09/07 14:30:01     INFO: Fit gamma distribution to negative values, m=0.258, μ=0.415.
#              corr_models 2023/09/07 14:30:01     INFO: Parameters initialized to λ=1.2, μ=0.42, σ=2.2e-06, γ=0.8, k=0.26, m=0.26.
#              corr_models 2023/09/07 14:30:01    DEBUG: Iter    0: n+= 398, n-= 515 n0=  88 λ=1.6, μ=0.65, σ=2.2e-06, γ=0.86, k=0.21, m=0.13
#              corr_models 2023/09/07 14:30:01    DEBUG: Iter    1: n+= 402, n-= 547 n0=  52 λ=1.6, μ=0.65, σ=2.1e-06, γ=0.87, k=0.2, m=0.12
#              corr_models 2023/09/07 14:30:01    DEBUG: Iter    2: n+= 403, n-= 551 n0=  47 λ=1.6, μ=0.64, σ=2e-06, γ=0.88, k=0.2, m=0.12
#              corr_models 2023/09/07 14:30:01    DEBUG: Iter    3: n+= 403, n-= 552 n0=  46 λ=1.6, μ=0.64, σ=1.9e-06, γ=0.88, k=0.2, m=0.12
#              corr_models 2023/09/07 14:30:01    DEBUG: Iter    4: n+= 404, n-= 551 n0=  46 λ=1.6, μ=0.64, σ=1.6e-06, γ=0.88, k=0.2, m=0.12
#              corr_models 2023/09/07 14:30:01    DEBUG: Iter    5: n+= 404, n-= 552 n0=  45 λ=1.6, μ=0.64, σ=1.6e-06, γ=0.88, k=0.2, m=0.12
#              corr_models 2023/09/07 14:30:01    DEBUG: Iter    6: n+= 404, n-= 551 n0=  46 λ=1.6, μ=0.64, σ=1.6e-06, γ=0.88, k=0.2, m=0.12
#              corr_models 2023/09/07 14:30:01    DEBUG: Iter    7: n+= 404, n-= 551 n0=  46 λ=1.6, μ=0.64, σ=1.6e-06, γ=0.88, k=0.2, m=0.12
#              corr_models 2023/09/07 14:30:01    DEBUG: Iter    8: n+= 404, n-= 551 n0=  46 λ=1.6, μ=0.64, σ=1.6e-06, γ=0.88, k=0.2, m=0.12
#              corr_models 2023/09/07 14:30:01     INFO: Converged.
#              corr_models 2023/09/07 14:30:01     INFO: Plotting cdf for model: Model, IntermittentGamma(λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1)
#              corr_models 2023/09/07 14:30:01     INFO: Plotting cdf for model: Model, IntermittentGamma(λ=1.6, μ=0.64, σ=1.6e-06, γ=0.88, k=0.2, m=0.12)

# %% [markdown]
# # Intermittent Generalized Inverse Gausssian model

# %%
reload(corrm)
Model = corrm.IntermittentGeneralizedInverseGaussian

# %%
true_params = Model.Params(λ=2,μ=1,σ=0.01,γ=0.8, k=0.2,m=0.1,α=0.1, β=0.1)
y, labs = Model.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
corrm.logger.setLevel(logging.INFO)
Model    = corrm.IntermittentGeneralizedInverseGaussian
true_mdl = Model(init_params=true_params, name="True Model")
mdl      = Model(#Model.Params(λ=1,μ=0.1, k=1,m=1,α=0.5, β=0.5, γ = 0.8, σ = 0.01),
    name = "Fit",
            σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1e-3)
mdl.fit(y, method="Nelder-Mead", damping=0.0)
figure(figsize=(8,4))
corrm.plot_cdfs(y, [true_mdl, mdl])
# Out:
#              corr_models 2023/09/07 14:31:27     INFO: Fitting IntermittentGeneralizedInverseGaussian model Fit.
#              corr_models 2023/09/07 14:31:27     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/07 14:31:27     INFO: Found 201 intermittent points, 536 positive, 264 negative values.
#              corr_models 2023/09/07 14:31:27     INFO: Fit geninvgauss distribution to positive values, λ=1.36, k=0.357, α=0.0988.
#              corr_models 2023/09/07 14:31:27     INFO: Fit geninvgauss distribution to negative values, m=0.0975, μ=0.866, β=0.101.
#              corr_models 2023/09/07 14:31:27     INFO: Parameters initialized to λ=1.4, μ=0.87, σ=0.0091, γ=0.8, k=0.36, m=0.098, α=0.099, β=0.1.
#              corr_models 2023/09/07 14:31:27     INFO: Converged.
#              corr_models 2023/09/07 14:31:27     INFO: Plotting cdf for model: True Model, IntermittentGeneralizedInverseGaussian(λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1)
#              corr_models 2023/09/07 14:31:28     INFO: Plotting cdf for model: Fit, IntermittentGeneralizedInverseGaussian(λ=2, μ=0.96, σ=0.0095, γ=0.8, k=0.28, m=0.071, α=0.13, β=0.1)

# %% [markdown]
# # CorrModel - Testing the wrapper class.

# %%
reload(corrm)
Params     = corrm.IntermittentGeneralizedInverseGaussian.Params
TrueModel  = corrm.IntermittentGamma
true_model = TrueModel(name="True Model", init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.4, m = 0.1, α = 0.1, β = 0.1),
                       σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
data, labs = true_model.gen_data(1001, params = true_model.params)
corrm.plot_data(data, labs)

# %%
reload(corrm)
Exp = corrm.CorrModel(model = "exp", name = "Exp", intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.2, m = 0.1, α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gam = corrm.CorrModel(model = "gamma", name = "Gam", intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 1., α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gig = corrm.CorrModel(model = "gig", name="Gig",intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 0.2, α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1, gammaness_thresh = 1e5)

# %%
corrm.logger.setLevel(logging.INFO)
Exp.fit(data);
Gam.fit(data, method = "Nelder-Mead");
Gig.fit(data, method = "Nelder-Mead");
Gam2 = corrm.IntermittentGamma(init_params = corrm.IntermittentGamma.params_from_gig(Gig.params), name="GamFromGig")
figure(figsize=(12,8))
corrm.plot_cdfs(data, [true_model, Gam, Gig, Gam2])#, Gig1])#, labs=["true", "Gam", "Gig", "Gig (γ)"])
# Out:
#              corr_models 2023/09/07 15:17:14     INFO: Fitting IntermittentExponential model Exp.
#              corr_models 2023/09/07 15:17:14     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/07 15:17:14     INFO: Found 201 intermittent points, 307 positive, 493 negative values.
#              corr_models 2023/09/07 15:17:14     INFO: Fit exponential distribution to positive values, λ=0.579.
#              corr_models 2023/09/07 15:17:14     INFO: Fit exponential distribution to negative values, μ=0.0623.
#              corr_models 2023/09/07 15:17:14     INFO: Parameters initialized to λ=0.58, μ=0.062, σ=1e-06, γ=0.8.
#              corr_models 2023/09/07 15:17:14     INFO: Converged.
#              corr_models 2023/09/07 15:17:14     INFO: Fitting IntermittentGamma model Gam.
#              corr_models 2023/09/07 15:17:14     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/07 15:17:14     INFO: Found 201 intermittent points, 307 positive, 493 negative values.
#              corr_models 2023/09/07 15:17:14     INFO: Fit gamma distribution to positive values, k=0.314, λ=1.85.
#              corr_models 2023/09/07 15:17:14     INFO: Fit gamma distribution to negative values, m=0.261, μ=0.239.
#              corr_models 2023/09/07 15:17:14     INFO: Parameters initialized to λ=1.8, μ=0.24, σ=1e-06, γ=0.8, k=0.31, m=0.26.
#              corr_models 2023/09/07 15:17:14     INFO: Converged.
#              corr_models 2023/09/07 15:17:14     INFO: Fitting IntermittentGeneralizedInverseGaussian model Gig.
#              corr_models 2023/09/07 15:17:14     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/07 15:17:14     INFO: Found 201 intermittent points, 307 positive, 493 negative values.
#              corr_models 2023/09/07 15:17:14     INFO: Fit geninvgauss distribution to positive values, λ=0.00997, k=0.211, α=0.00832.
#              corr_models 2023/09/07 15:17:14     INFO: Fit geninvgauss distribution to negative values, m=0.111, μ=0.00144, β=0.00766.
#              corr_models 2023/09/07 15:17:14     INFO: Parameters initialized to λ=0.01, μ=0.0014, σ=1e-06, γ=0.8, k=0.21, m=0.11, α=0.0083, β=0.0077.
#              corr_models 2023/09/07 15:17:15     INFO: Converged.
#              corr_models 2023/09/07 15:17:15     INFO: Plotting cdf for model: True Model, IntermittentGamma(λ=2, μ=0.5, σ=0.01, γ=0.8, k=0.4, m=0.1)
#              corr_models 2023/09/07 15:17:15     INFO: Plotting cdf for model: Gam, IntermittentGamma(λ=1.9, μ=0.42, σ=4.5e-07, γ=0.88, k=0.31, m=0.11)
#              corr_models 2023/09/07 15:17:15     INFO: Plotting cdf for model: Gig, IntermittentGeneralizedInverseGaussian(λ=1e-06, μ=5.2e-06, σ=1.7e-12, γ=0.87, k=0.21, m=0.11, α=1e-06, β=1.7e-05)
#              corr_models 2023/09/07 15:17:15     INFO: Using Gamma distribution with scale = 0.62 for negative values, since gammaness 3.7e+10 > 1.0e+05.
#              corr_models 2023/09/07 15:17:15     INFO: Using Gamma distribution with scale = 2 for positive values, since gammaness 1.0e+12 > 1.0e+05.
#              corr_models 2023/09/07 15:17:15     INFO: Using Gamma distribution with scale = 0.62 for negative values, since gammaness 3.7e+10 > 1.0e+05.
#              corr_models 2023/09/07 15:17:15     INFO: Using Gamma distribution with scale = 2 for positive values, since gammaness 1.0e+12 > 1.0e+05.
#              corr_models 2023/09/07 15:17:15     INFO: Plotting cdf for model: GamFromGig, IntermittentGamma(λ=2, μ=0.62, σ=1.7e-12, γ=0.87, k=0.21, m=0.11)
# agam_cdf: Z0 = 8.9, Z1 = 2.9
# agam_cdf: Z0 = 8.9, Z1 = 2.9
# agam_cdf: Z0 = 7.8, Z1 = 3.6
# agam_cdf: Z0 = 7.8, Z1 = 3.6
# agam_cdf: Z0 = 8.2, Z1 = 5.1
# agam_cdf: Z0 = 8.2, Z1 = 5.1
