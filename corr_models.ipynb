# %% [markdown]
# # Correlation models

# %% [markdown]
# In this notebook we will be testing the corr_models.

# %% [markdown]
# # Code

# %%
# %pylab inline
from importlib import reload
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import corr_models as corrm

# %% [markdown]
# # Exponential model

# %%
reload(corrm)
y, labs = corrm.Exponential.gen_data(1001, corrm.Exponential.Params(2,1))
corrm.plot_data(y, labs)

# %%
reload(corrm)
mdl = corrm.Exponential(corrm.Exponential.Params(1,1))
mdl.fit(y)
corrm.plot_cdfs(y, [mdl])
# Out:
#              corr_models 2023/09/06 09:53:17     INFO: Iter    0: n+= 677, n-= 324 λ=1.9, μ=0.98
#              corr_models 2023/09/06 09:53:17     INFO: Iter    1: n+= 677, n-= 324 λ=1.9, μ=0.98
#              corr_models 2023/09/06 09:53:17     INFO: Converged.

# %% [markdown]
# # Intermittent Exponential model

# %%
reload(corrm)
true_params = corrm.IntermittentExponential.Params(2,1,0.1,0.2)
y, labs = corrm.IntermittentExponential.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentExponential(true_params)
mdl = corrm.IntermittentExponential(corrm.IntermittentExponential.Params(λ=2,μ=1,σ=0.001,γ=0.2),
                                    σ_penalty = 0, γ_pr_mean = 0.2, γ_pr_strength = 1)
mdl.fit(y)
corrm.plot_cdfs(y, [true_mdl, mdl])
print(mdl)
# Out:
#              corr_models 2023/09/06 09:53:22     INFO: Iter    0: n+= 132, n-=  68 n0= 801 λ=2.3, μ=1.2, σ=0.095, γ=0.2
#              corr_models 2023/09/06 09:53:22     INFO: Iter    1: n+= 126, n-=  65 n0= 810 λ=2.4, μ=1.3, σ=0.098, γ=0.2
#              corr_models 2023/09/06 09:53:22     INFO: Iter    2: n+= 126, n-=  64 n0= 811 λ=2.4, μ=1.3, σ=0.099, γ=0.19
#              corr_models 2023/09/06 09:53:22     INFO: Iter    3: n+= 125, n-=  64 n0= 812 λ=2.5, μ=1.3, σ=0.099, γ=0.19
#              corr_models 2023/09/06 09:53:22     INFO: Iter    4: n+= 125, n-=  64 n0= 812 λ=2.5, μ=1.3, σ=0.099, γ=0.19
#              corr_models 2023/09/06 09:53:22     INFO: Converged.
# IntermittentExponential(λ=2.5, μ=1.3, σ=0.099, γ=0.19)

# %% [markdown]
# # Intermittent Gamma model

# %%
reload(corrm)
true_params = corrm.IntermittentGamma.Params(2,1,0.01,0.8, 0.2,0.1)
y, labs = corrm.IntermittentGamma.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
mdl.hyper_params
# Out:
# HyperParams(σ_penalty=0, γ_pr_mean=0.2, γ_pr_strength=1)

# %%
reload(corrm)
true_mdl = corrm.IntermittentGamma(true_params)
mdl = corrm.IntermittentGamma(corrm.IntermittentGamma.Params(λ=2,μ=1,σ=0.001,γ=0.2,k=1,m=1),
                                    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
mdl.fit(y)
figure(figsize=(8,4))
corrm.plot_cdfs(y, [true_mdl, mdl])
# Out:
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [0.91681671 0.42016042 0.57170061 0.38367858] in  110 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter    0: n+= 259, n-= 271 n0= 471 λ=0.92, μ=0.57, σ=0.0013, γ=0.66, k=0.42, m=0.38
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.72337669 0.21674772 0.97989595 0.10691839] in   84 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter    1: n+= 306, n-= 511 n0= 184 λ=1.7, μ=0.98, σ=0.0013, γ=0.81, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.56057075 0.21660116 0.87948401 0.10786339] in   68 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter    2: n+= 325, n-= 578 n0=  98 λ=1.6, μ=0.88, σ=0.0014, γ=0.85, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.49125263 0.21796518 0.83756905 0.10897451] in   64 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter    3: n+= 333, n-= 606 n0=  62 λ=1.5, μ=0.84, σ=0.0014, γ=0.87, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.45731643 0.22033051 0.81735813 0.10956087] in   60 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter    4: n+= 334, n-= 621 n0=  46 λ=1.5, μ=0.82, σ=0.0015, γ=0.88, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.45759848 0.21959418 0.81748018 0.10955167] in   37 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter    5: n+= 335, n-= 621 n0=  45 λ=1.5, μ=0.82, σ=0.0016, γ=0.88, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.45711401 0.21908319 0.81714796 0.10957678] in   21 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter    6: n+= 336, n-= 621 n0=  44 λ=1.5, μ=0.82, σ=0.0016, γ=0.88, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.45660577 0.2185805  0.81680275 0.10960292] in   23 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter    7: n+= 337, n-= 621 n0=  43 λ=1.5, μ=0.82, σ=0.0016, γ=0.88, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.45727542 0.2183876  0.81720227 0.10957271] in   36 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter    8: n+= 337, n-= 621 n0=  43 λ=1.5, μ=0.82, σ=0.0017, γ=0.88, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.45915857 0.21849537 0.81836769 0.10948459] in   41 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter    9: n+= 336, n-= 621 n0=  44 λ=1.5, μ=0.82, σ=0.0018, γ=0.88, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.46037448 0.21879561 0.81913612 0.1094266 ] in   37 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter   10: n+= 335, n-= 621 n0=  45 λ=1.5, μ=0.82, σ=0.0018, γ=0.88, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.46282474 0.21939545 0.82068725 0.10930982] in   42 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter   11: n+= 333, n-= 621 n0=  47 λ=1.5, μ=0.82, σ=0.0019, γ=0.88, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.46405353 0.21969664 0.82146648 0.10925129] in   37 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter   12: n+= 332, n-= 621 n0=  48 λ=1.5, μ=0.82, σ=0.0019, γ=0.88, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.46653758 0.22029599 0.82304441 0.10913306] in   42 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter   13: n+= 330, n-= 621 n0=  50 λ=1.5, μ=0.82, σ=0.002, γ=0.88, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.47095866 0.22100451 0.82583576 0.10892482] in   46 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter   14: n+= 327, n-= 621 n0=  53 λ=1.5, μ=0.83, σ=0.0021, γ=0.87, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.4798129  0.22313894 0.83150929 0.10850514] in   50 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter   15: n+= 320, n-= 621 n0=  60 λ=1.5, μ=0.83, σ=0.0023, γ=0.87, k=0.22, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.48749398 0.22500635 0.83647056 0.10814201] in   49 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter   16: n+= 314, n-= 621 n0=  66 λ=1.5, μ=0.84, σ=0.0025, γ=0.87, k=0.23, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.49142751 0.22593361 0.83902578 0.10795638] in   45 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter   17: n+= 311, n-= 621 n0=  69 λ=1.5, μ=0.84, σ=0.0026, γ=0.87, k=0.23, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.49218683 0.2257047  0.83948661 0.107923  ] in   37 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter   18: n+= 311, n-= 621 n0=  69 λ=1.5, μ=0.84, σ=0.0027, γ=0.87, k=0.23, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged to fixed point [1.49218762 0.22570462 0.83948707 0.10792297] in    0 iterations.
#              corr_models 2023/09/06 09:53:33     INFO: Iter   19: n+= 311, n-= 621 n0=  69 λ=1.5, μ=0.84, σ=0.0027, γ=0.87, k=0.23, m=0.11
#              corr_models 2023/09/06 09:53:33     INFO: Converged.

# %% [markdown]
# # Intermittent Generalized Inverse Gausssian model

# %%
reload(corrm)
Model = corrm.IntermittentGeneralizedInverseGaussian

# %%
true_params = Model.Params(λ=2,μ=1,σ=0.01,γ=0.8, k=0.2,m=0.1,α=0.1, β=0.1)
y, labs = Model.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
Model    = corrm.IntermittentGeneralizedInverseGaussian
true_mdl = Model(true_params)
mdl      = Model(Model.Params(λ=1,μ=0.1, k=1,m=1,α=0.5, β=0.5, γ = 0.8, σ = 0.01),
            σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
mdl.fit(y, method="Nelder-Mead", damping=0.0)
figure(figsize=(8,4))
corrm.plot_cdfs(y, [true_mdl, mdl])
# Out:
#              corr_models 2023/09/06 09:55:23    DEBUG: Optimization terminated successfully. after 654 iterations.
#              corr_models 2023/09/06 09:55:23     INFO: Iter    0: n+= 555, n-= 251 n0= 195 λ=2.1, μ=1.2, σ=0.011, γ=0.8, k=0.21, m=0.037, α=0.095, β=0.13
#              corr_models 2023/09/06 09:55:23    DEBUG: Optimization terminated successfully. after 97 iterations.
#              corr_models 2023/09/06 09:55:23     INFO: Iter    1: n+= 555, n-= 251 n0= 195 λ=2.1, μ=1.2, σ=0.011, γ=0.8, k=0.21, m=0.037, α=0.095, β=0.13
#              corr_models 2023/09/06 09:55:23    DEBUG: Optimization terminated successfully. after 91 iterations.
#              corr_models 2023/09/06 09:55:23     INFO: Iter    2: n+= 555, n-= 251 n0= 195 λ=2.1, μ=1.2, σ=0.011, γ=0.8, k=0.21, m=0.037, α=0.095, β=0.13
#              corr_models 2023/09/06 09:55:23     INFO: Converged.

# %%
corrm.plot_data(y, mdl.labs)

# %% [markdown]
# # CorrModel - Testing the wrapper class.

# %%
reload(corrm)
Params     = corrm.IntermittentGeneralizedInverseGaussian.Params
TrueModel  = corrm.IntermittentGamma
true_model = TrueModel(init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.4, m = 0.1, α = 0.1, β = 0.1),
                       σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
data, labs = true_model.gen_data(1001, params = true_model.params)
corrm.plot_data(data, labs)

# %%
reload(corrm)
Exp = corrm.CorrModel(model = "exp", intermittent = True,
    init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.2, m = 0.1, α = 0.1, β = 0.1),
                    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gam = corrm.CorrModel(model = "gamma", intermittent = True,
    init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 1., α = 0.1, β = 0.1),
                    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gig = corrm.CorrModel(model = "gig", intermittent = True,
    init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 0.2, α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1, gammaness_thresh = 1e5)

# %%
#Exp.fit(data);
#Gam.fit(data, method = "Nelder-Mead");
Gig.fit(data, method = "Nelder-Mead");
# Out:
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 497 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter    0: n+= 165, n-= 122 n0= 714 λ=1.1, μ=0.35, σ=0.008, γ=0.54, k=0.43, m=0.1, α=0.19, β=0.22
#              corr_models 2023/09/06 18:33:46    DEBUG: Maximum number of function evaluations has been exceeded. after 793 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter    1: n+= 167, n-= 127 n0= 707 λ=0.7, μ=0.27, σ=0.0075, γ=0.55, k=0.41, m=0.05, α=0.22, β=0.26
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 356 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter    2: n+= 170, n-= 132 n0= 699 λ=0.46, μ=0.23, σ=0.007, γ=0.55, k=0.4, m=0.025, α=0.22, β=0.28
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 687 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter    3: n+= 174, n-= 139 n0= 688 λ=0.31, μ=0.2, σ=0.0065, γ=0.56, k=0.41, m=0.013, α=0.19, β=0.27
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 433 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter    4: n+= 177, n-= 153 n0= 671 λ=0.16, μ=0.15, σ=0.0058, γ=0.56, k=0.52, m=0.021, α=0.099, β=0.32
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 498 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter    5: n+= 182, n-= 168 n0= 651 λ=0.083, μ=0.12, σ=0.0051, γ=0.57, k=0.56, m=0.01, α=0.052, β=0.32
#              corr_models 2023/09/06 18:33:46    DEBUG: Maximum number of function evaluations has been exceeded. after 774 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter    6: n+= 192, n-= 178 n0= 631 λ=0.047, μ=0.11, σ=0.0045, γ=0.58, k=0.53, m=0.0059, α=0.032, β=0.3
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 276 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter    7: n+= 200, n-= 191 n0= 610 λ=0.03, μ=0.094, σ=0.0039, γ=0.6, k=0.5, m=0.0097, α=0.022, β=0.28
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 564 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter    8: n+= 207, n-= 208 n0= 586 λ=0.022, μ=0.084, σ=0.0033, γ=0.61, k=0.47, m=0.0049, α=0.017, β=0.26
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 442 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter    9: n+= 218, n-= 224 n0= 559 λ=0.018, μ=0.076, σ=0.0027, γ=0.62, k=0.43, m=0.0024, α=0.015, β=0.24
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 382 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   10: n+= 225, n-= 248 n0= 528 λ=0.015, μ=0.067, σ=0.0021, γ=0.64, k=0.4, m=0.0012, α=0.012, β=0.22
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 381 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   11: n+= 242, n-= 263 n0= 496 λ=0.016, μ=0.061, σ=0.0016, γ=0.65, k=0.35, m=0.00061, α=0.013, β=0.2
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 419 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   12: n+= 260, n-= 277 n0= 464 λ=0.022, μ=0.058, σ=0.0011, γ=0.67, k=0.29, m=0.00031, α=0.018, β=0.17
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 390 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   13: n+= 275, n-= 292 n0= 434 λ=0.026, μ=0.054, σ=0.00074, γ=0.68, k=0.24, m=0.00015, α=0.021, β=0.15
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 209 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   14: n+= 282, n-= 312 n0= 407 λ=0.025, μ=0.049, σ=0.00049, γ=0.7, k=0.22, m=0.00018, α=0.02, β=0.13
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 170 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   15: n+= 287, n-= 326 n0= 388 λ=0.022, μ=0.043, σ=0.00035, γ=0.71, k=0.2, m=0.0002, α=0.018, β=0.11
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 182 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   16: n+= 291, n-= 342 n0= 368 λ=0.019, μ=0.037, σ=0.00024, γ=0.72, k=0.2, m=0.00024, α=0.015, β=0.1
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 184 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   17: n+= 292, n-= 357 n0= 352 λ=0.015, μ=0.032, σ=0.00016, γ=0.72, k=0.21, m=0.00021, α=0.012, β=0.089
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 180 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   18: n+= 301, n-= 368 n0= 332 λ=0.013, μ=0.028, σ=0.00011, γ=0.73, k=0.2, m=0.00027, α=0.0099, β=0.077
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 192 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   19: n+= 306, n-= 378 n0= 317 λ=0.011, μ=0.024, σ=7.9e-05, γ=0.74, k=0.2, m=0.00037, α=0.0085, β=0.067
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 166 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   20: n+= 307, n-= 389 n0= 305 λ=0.0092, μ=0.021, σ=5.6e-05, γ=0.75, k=0.2, m=0.00041, α=0.0071, β=0.058
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 159 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   21: n+= 308, n-= 398 n0= 295 λ=0.0077, μ=0.018, σ=4.2e-05, γ=0.75, k=0.2, m=0.00048, α=0.0059, β=0.051
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 488 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   22: n+= 308, n-= 405 n0= 288 λ=0.0065, μ=0.016, σ=3.4e-05, γ=0.76, k=0.21, m=0.00024, α=0.005, β=0.045
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 147 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   23: n+= 308, n-= 414 n0= 279 λ=0.0054, μ=0.014, σ=2.8e-05, γ=0.76, k=0.21, m=0.00026, α=0.0041, β=0.039
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 182 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   24: n+= 311, n-= 423 n0= 267 λ=0.0046, μ=0.012, σ=2.1e-05, γ=0.77, k=0.22, m=0.00039, α=0.0035, β=0.034
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 166 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   25: n+= 311, n-= 433 n0= 257 λ=0.0038, μ=0.011, σ=1.5e-05, γ=0.77, k=0.22, m=0.00049, α=0.0028, β=0.03
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 156 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   26: n+= 311, n-= 442 n0= 248 λ=0.0031, μ=0.0091, σ=1.1e-05, γ=0.78, k=0.23, m=0.00057, α=0.0023, β=0.025
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 176 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   27: n+= 311, n-= 451 n0= 239 λ=0.0025, μ=0.0079, σ=8.2e-06, γ=0.78, k=0.23, m=0.00063, α=0.0019, β=0.022
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 169 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   28: n+= 311, n-= 460 n0= 230 λ=0.0021, μ=0.0068, σ=5.8e-06, γ=0.79, k=0.23, m=0.00077, α=0.0016, β=0.019
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 147 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   29: n+= 311, n-= 468 n0= 222 λ=0.0017, μ=0.0059, σ=4.2e-06, γ=0.79, k=0.24, m=0.00086, α=0.0013, β=0.016
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 111 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   30: n+= 312, n-= 475 n0= 214 λ=0.0014, μ=0.0052, σ=2.9e-06, γ=0.79, k=0.24, m=0.0011, α=0.0011, β=0.014
#              corr_models 2023/09/06 18:33:46    DEBUG: Optimization terminated successfully. after 136 iterations.
#              corr_models 2023/09/06 18:33:46     INFO: Iter   31: n+= 312, n-= 482 n0= 207 λ=0.0012, μ=0.0045, σ=1.9e-06, γ=0.8, k=0.24, m=0.0016, α=0.00091, β=0.012
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 405 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   32: n+= 312, n-= 488 n0= 201 λ=0.00089, μ=0.0036, σ=1.4e-06, γ=0.8, k=0.25, m=0.023, α=0.00068, β=0.011
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 258 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   33: n+= 312, n-= 494 n0= 195 λ=0.00067, μ=0.0029, σ=9.8e-07, γ=0.8, k=0.25, m=0.039, α=0.00052, β=0.0093
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 190 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   34: n+= 312, n-= 499 n0= 190 λ=0.00051, μ=0.0024, σ=7.4e-07, γ=0.81, k=0.26, m=0.051, α=0.0004, β=0.008
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 219 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   35: n+= 312, n-= 503 n0= 186 λ=0.0004, μ=0.002, σ=6.2e-07, γ=0.81, k=0.26, m=0.061, α=0.00031, β=0.007
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 184 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   36: n+= 312, n-= 508 n0= 181 λ=0.00032, μ=0.0017, σ=4.9e-07, γ=0.81, k=0.26, m=0.069, α=0.00025, β=0.006
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 184 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   37: n+= 312, n-= 514 n0= 175 λ=0.00025, μ=0.0014, σ=3.9e-07, γ=0.81, k=0.26, m=0.076, α=0.00019, β=0.0051
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 148 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   38: n+= 312, n-= 518 n0= 171 λ=0.0002, μ=0.0012, σ=3.3e-07, γ=0.81, k=0.27, m=0.081, α=0.00016, β=0.0044
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 177 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   39: n+= 312, n-= 527 n0= 162 λ=0.00016, μ=0.00094, σ=2.1e-07, γ=0.82, k=0.27, m=0.085, α=0.00012, β=0.0037
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 173 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   40: n+= 312, n-= 533 n0= 156 λ=0.00012, μ=0.00078, σ=1.5e-07, γ=0.82, k=0.27, m=0.088, α=9.6e-05, β=0.0031
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 242 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   41: n+= 312, n-= 540 n0= 149 λ=9.6e-05, μ=0.00065, σ=8.2e-08, γ=0.83, k=0.27, m=0.09, α=7.6e-05, β=0.0026
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 215 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   42: n+= 312, n-= 544 n0= 145 λ=7.8e-05, μ=0.00055, σ=5.3e-08, γ=0.83, k=0.27, m=0.092, α=6.2e-05, β=0.0022
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 145 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   43: n+= 312, n-= 546 n0= 143 λ=6.5e-05, μ=0.00048, σ=4.6e-08, γ=0.83, k=0.27, m=0.094, α=5.2e-05, β=0.0019
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 200 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   44: n+= 312, n-= 552 n0= 137 λ=5.1e-05, μ=0.00039, σ=3.2e-08, γ=0.83, k=0.27, m=0.097, α=4.1e-05, β=0.0016
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 158 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   45: n+= 312, n-= 555 n0= 134 λ=4.1e-05, μ=0.00033, σ=2.8e-08, γ=0.83, k=0.27, m=0.1, α=3.3e-05, β=0.0014
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 196 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   46: n+= 312, n-= 560 n0= 129 λ=3.3e-05, μ=0.00027, σ=2e-08, γ=0.84, k=0.27, m=0.1, α=2.6e-05, β=0.0011
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 172 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   47: n+= 312, n-= 566 n0= 123 λ=2.6e-05, μ=0.00022, σ=1.1e-08, γ=0.84, k=0.28, m=0.1, α=2e-05, β=0.00094
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 231 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   48: n+= 312, n-= 569 n0= 120 λ=2.1e-05, μ=0.00019, σ=7.9e-09, γ=0.84, k=0.28, m=0.1, α=1.7e-05, β=0.0008
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 190 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   49: n+= 312, n-= 575 n0= 114 λ=1.6e-05, μ=0.00015, σ=3.5e-09, γ=0.84, k=0.28, m=0.11, α=1.3e-05, β=0.00065
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 188 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   50: n+= 312, n-= 579 n0= 110 λ=1.2e-05, μ=0.00012, σ=2e-09, γ=0.85, k=0.28, m=0.11, α=9.8e-06, β=0.00052
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 170 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   51: n+= 312, n-= 582 n0= 107 λ=9.3e-06, μ=9.7e-05, σ=1.2e-09, γ=0.85, k=0.28, m=0.11, α=7.4e-06, β=0.00042
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 172 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   52: n+= 312, n-= 584 n0= 105 λ=7.2e-06, μ=7.9e-05, σ=9.6e-10, γ=0.85, k=0.28, m=0.11, α=5.8e-06, β=0.00034
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 162 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   53: n+= 312, n-= 586 n0= 103 λ=5.7e-06, μ=6.5e-05, σ=7.4e-10, γ=0.85, k=0.28, m=0.11, α=4.6e-06, β=0.00029
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 171 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   54: n+= 312, n-= 590 n0=  99 λ=4.3e-06, μ=5.1e-05, σ=4.5e-10, γ=0.85, k=0.28, m=0.12, α=3.4e-06, β=0.00023
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 178 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   55: n+= 312, n-= 592 n0=  97 λ=3.3e-06, μ=4.1e-05, σ=3.8e-10, γ=0.85, k=0.28, m=0.12, α=2.7e-06, β=0.00018
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 192 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   56: n+= 312, n-= 594 n0=  95 λ=2.6e-06, μ=3.4e-05, σ=3.2e-10, γ=0.85, k=0.28, m=0.12, α=2.1e-06, β=0.00015
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 166 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   57: n+= 312, n-= 595 n0=  94 λ=2.1e-06, μ=2.9e-05, σ=3e-10, γ=0.85, k=0.28, m=0.12, α=1.7e-06, β=0.00013
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 203 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   58: n+= 312, n-= 595 n0=  94 λ=1.9e-06, μ=2.7e-05, σ=3e-10, γ=0.85, k=0.28, m=0.12, α=1.6e-06, β=0.00012
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 165 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   59: n+= 312, n-= 596 n0=  93 λ=1.7e-06, μ=2.4e-05, σ=2.8e-10, γ=0.85, k=0.28, m=0.12, α=1.4e-06, β=0.00011
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 162 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   60: n+= 312, n-= 601 n0=  88 λ=1.5e-06, μ=2.1e-05, σ=1.9e-10, γ=0.86, k=0.28, m=0.12, α=1.2e-06, β=9.4e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 150 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   61: n+= 312, n-= 603 n0=  86 λ=1.3e-06, μ=1.9e-05, σ=1.6e-10, γ=0.86, k=0.27, m=0.12, α=1.1e-06, β=8.3e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 175 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   62: n+= 312, n-= 605 n0=  84 λ=1.3e-06, μ=1.7e-05, σ=1.4e-10, γ=0.86, k=0.27, m=0.12, α=1e-06, β=7.5e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 141 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   63: n+= 312, n-= 607 n0=  82 λ=1.2e-06, μ=1.6e-05, σ=1.2e-10, γ=0.86, k=0.27, m=0.12, α=1e-06, β=6.9e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 123 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   64: n+= 312, n-= 610 n0=  79 λ=1.2e-06, μ=1.5e-05, σ=9.7e-11, γ=0.86, k=0.26, m=0.12, α=1e-06, β=6.2e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 167 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   65: n+= 312, n-= 613 n0=  76 λ=1.2e-06, μ=1.4e-05, σ=7.2e-11, γ=0.86, k=0.26, m=0.11, α=1e-06, β=5.7e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 105 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   66: n+= 312, n-= 616 n0=  73 λ=1.2e-06, μ=1.3e-05, σ=4.7e-11, γ=0.86, k=0.26, m=0.11, α=1e-06, β=5.2e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 138 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   67: n+= 312, n-= 618 n0=  71 λ=1.2e-06, μ=1.2e-05, σ=3.8e-11, γ=0.86, k=0.25, m=0.11, α=1e-06, β=4.8e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 198 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   68: n+= 312, n-= 622 n0=  67 λ=1.1e-06, μ=1.1e-05, σ=1.9e-11, γ=0.87, k=0.25, m=0.11, α=1e-06, β=4.2e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 127 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   69: n+= 312, n-= 624 n0=  65 λ=1.1e-06, μ=1e-05, σ=7.4e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3.8e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 175 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   70: n+= 312, n-= 625 n0=  64 λ=1.1e-06, μ=9.6e-06, σ=5.9e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3.4e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 109 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   71: n+= 312, n-= 625 n0=  64 λ=1.1e-06, μ=9.3e-06, σ=5.9e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3.2e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 97 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   72: n+= 312, n-= 625 n0=  64 λ=1.1e-06, μ=9.1e-06, σ=5.9e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3.1e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 88 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   73: n+= 312, n-= 625 n0=  64 λ=1.1e-06, μ=9e-06, σ=5.9e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3.1e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 59 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   74: n+= 312, n-= 625 n0=  64 λ=1.1e-06, μ=8.9e-06, σ=5.9e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3.1e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 55 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   75: n+= 312, n-= 625 n0=  64 λ=1.1e-06, μ=8.9e-06, σ=5.9e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 57 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   76: n+= 312, n-= 625 n0=  64 λ=1.1e-06, μ=8.9e-06, σ=5.9e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 78 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   77: n+= 312, n-= 625 n0=  64 λ=1.1e-06, μ=8.9e-06, σ=5.9e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 49 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   78: n+= 312, n-= 625 n0=  64 λ=1.1e-06, μ=8.9e-06, σ=5.9e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3e-05
#              corr_models 2023/09/06 18:33:47    DEBUG: Optimization terminated successfully. after 48 iterations.
#              corr_models 2023/09/06 18:33:47     INFO: Iter   79: n+= 312, n-= 625 n0=  64 λ=1.1e-06, μ=8.9e-06, σ=5.9e-12, γ=0.87, k=0.24, m=0.11, α=1e-06, β=3e-05
#              corr_models 2023/09/06 18:33:47     INFO: Converged.

# %%
figure(figsize=(12,4))
corrm.plot_cdfs(data, [Gig, Gam, true_model])
# Out:
#              corr_models 2023/09/06 18:33:48     INFO: Using Gamma distribution with scale = 1.7 for negative values, since gammaness 1.3e+10 > 1.0e+05.
#              corr_models 2023/09/06 18:33:48     INFO: Using Gamma distribution with scale = 0.46 for positive values, since gammaness 8.3e+11 > 1.0e+05.
#              corr_models 2023/09/06 18:33:48     INFO: Using Gamma distribution with scale = 1.7 for negative values, since gammaness 1.3e+10 > 1.0e+05.
#              corr_models 2023/09/06 18:33:48     INFO: Using Gamma distribution with scale = 0.46 for positive values, since gammaness 8.3e+11 > 1.0e+05.

# %%
x = linspace(-0.2,0.2,1001)
c = Gig.cdf(x)
# Out:
#              corr_models 2023/09/06 18:42:10     INFO: Using Gamma distribution with scale = 1.7 for negative values, since gammaness 1.3e+10 > 1.0e+05.
#              corr_models 2023/09/06 18:42:10     INFO: Using Gamma distribution with scale = 0.46 for positive values, since gammaness 8.3e+11 > 1.0e+05.

# %%
c = corrm.IntermittentGeneralizedInverseGaussian.agig_cdf(x, Gig.params, Gig.model.gammaness_thresh)
# Out:
#              corr_models 2023/09/06 18:42:12     INFO: Using Gamma distribution with scale = 1.7 for negative values, since gammaness 1.3e+10 > 1.0e+05.
#              corr_models 2023/09/06 18:42:12     INFO: Using Gamma distribution with scale = 0.46 for positive values, since gammaness 8.3e+11 > 1.0e+05.

# %%
from scipy.stats import gamma as gamma_dist

# %%
# ?gamma_dist

# %%
gamma_dist(0.25, scale=1.7).cdf(0.15)
# Out:
# 0.5909413762940937

# %%
plot(x,c, ".-")
xlim(-0.2,0.2)
# Out:
# (-0.2, 0.2)

# %%
plot(c)

# %%
Gig.params
# Out:
# Params(λ=1.0000023103827279e-06, μ=7.647703586993312e-06, σ=9.830199871906338e-12, γ=0.8665334665334666, k=0.23143928464437724, m=0.12138052601759955, α=1.0000360766179408e-06, β=3.3275622964247925e-05)

# %%
Gig.params.μ / Gig.params.β
# Out:
# 0.22982901312501874

# %%
plot(data, Gig.cdf(data, Gig.params), "o")

# %%
Z, Z0, Z1 =  Gig.model.agig_Z(Gig.params)

# %%
Z
# Out:
# 0.00035966594374461545

# %%
Z0
# Out:
# 0.00021582471831219104

# %%
Z1
# Out:
# 0.0001438412254324244

# %%
params = Gig.params
print(params)
λ = params.λ
μ = params.μ
k = params.k
m = params.m
α = params.α
β = params.β
# Out:
# Params(λ=1.7245075243880217e-06, μ=8.57098112872548e-06, σ=2.1772859647474324e-11, γ=0.8670329670329672, k=0.21610964363261825, m=0.12358597405872296, α=2.006376927005963e-06, β=6.0065943610866055e-05)

# %%
y = data
Z, Z0, Z1 = corrm.IntermittentGeneralizedInverseGaussian.agig_Z(params)
cdf = 0*y
cdf[y<0] = (1 -   geninvgauss.cdf(abs(y[y<0]), m, β, scale = μ)) * Z0/Z
cdf[y>=0]= Z0/Z + geninvgauss.cdf(y[y>=0],     k, α, scale = λ) * Z1/Z

# %%
geninvgauss.cdf(100,     k, α, scale = 1e-6)
# Out:
# 1.0033164207973246

# %%
from scipy.stats import geninvgauss
