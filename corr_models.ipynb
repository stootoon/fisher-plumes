# %% [markdown]
# # Correlation models

# %% [markdown]
# In this notebook we will be testing the corr_models.

# %% [markdown]
# # Code

# %%
# %pylab inline
from importlib import reload
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
-1 % 15
# Out:
# 14

# %%
import corr_models as corrm

# %% [markdown]
# # Exponential model

# %%
reload(corrm)
y, labs = corrm.Exponential.gen_data(1001, corrm.Exponential.Params(2,1))
corrm.plot_data(y, labs)

# %%
reload(corrm)
mdl = corrm.Exponential()
mdl.fit(y)
corrm.plot_cdfs(y, [mdl])
# Out:
#              corr_models 2023/09/22 10:41:55     INFO: Fitting exponential model Model.
#              corr_models 2023/09/22 10:41:55     INFO: Initializing from fit.
#              corr_models 2023/09/22 10:41:55     INFO: Found 691 positive, 310 negative values.
#              corr_models 2023/09/22 10:41:55     INFO: Fit exponential distribution to positive values, λ=2.06.
#              corr_models 2023/09/22 10:41:55     INFO: Fit exponential distribution to negative values, μ=0.951.
#              corr_models 2023/09/22 10:41:55     INFO: Parameters initialized to λ=2.1, μ=0.95.
#              corr_models 2023/09/22 10:41:55    DEBUG: Iter    0: n+= 691, n-= 310 λ=2.1, μ=0.94
#              corr_models 2023/09/22 10:41:55    DEBUG: Iter    1: n+= 691, n-= 310 λ=2.1, μ=0.94
#              corr_models 2023/09/22 10:41:55     INFO: Converged in    1 iterations to n+= 691, n-= 310 λ=2.1, μ=0.94
# ...

# %% [markdown]
# # Intermittent Exponential model

# %%
reload(corrm)
true_params = corrm.IntermittentExponential.Params(2,1,0.1,0.2)
y, labs = corrm.IntermittentExponential.gen_data(2001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentExponential(init_params = true_params, name = "True Model")
mdl = corrm.IntermittentExponential(#corrm.IntermittentExponential.Params(λ=2,μ=1,σ=0.001,γ=0.2),
    name = "Fit",
                                    σ_penalty = 0, γ_pr_mean = 0.2, γ_pr_strength = 1)
mdl.fit(y)
corrm.plot_cdfs(y, [true_mdl, mdl])
print(mdl)
# Out:
#              corr_models 2023/09/22 10:41:55     INFO: ********************************************************************************
#              corr_models 2023/09/22 10:41:55     INFO: Initializing model IntermittentExponential named 'True Model' id(self)=140497069766736.
#              corr_models 2023/09/22 10:41:55     INFO: Casting IntermittentExponential to IntermittentExponential.
#              corr_models 2023/09/22 10:41:55     INFO: Cast params: λ=2, μ=1, σ=0.1, γ=0.2 -> λ=2, μ=1, σ=0.1, γ=0.2
#              corr_models 2023/09/22 10:41:55     INFO: Initialized self.init_params = λ=2, μ=1, σ=0.1, γ=0.2
#              corr_models 2023/09/22 10:41:55     INFO: Initialized self.params      = λ=2, μ=1, σ=0.1, γ=0.2
#              corr_models 2023/09/22 10:41:55     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.5, γ_pr_strength=0
# ...

# %% [markdown]
# # Intermittent Gamma model

# %%
reload(corrm)
true_params = corrm.IntermittentGamma.Params(2,1,0.01,0.8, 0.2,0.3)
y, labs = corrm.IntermittentGamma.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
true_mdl = corrm.IntermittentGamma(init_params = true_params, name="True Model")
mdl = corrm.IntermittentGamma(#corrm.IntermittentGamma.Params(λ=2,μ=1,σ=0.001,γ=0.2,k=1,m=1),
    σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1, name="Gamma")
mdl.fit(y, method="Nelder-Mead")
figure(figsize=(8,4))
corrm.plot_cdfs(y, [true_mdl, mdl], diffs=False)
# Out:
#              corr_models 2023/09/22 10:41:56     INFO: ********************************************************************************
#              corr_models 2023/09/22 10:41:56     INFO: Initializing model IntermittentGamma named 'True Model' id(self)=140497068636096.
#              corr_models 2023/09/22 10:41:56     INFO: Casting IntermittentGamma to IntermittentGamma.
#              corr_models 2023/09/22 10:41:56     INFO: Cast params: λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3 -> λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3
#              corr_models 2023/09/22 10:41:56     INFO: Initialized self.init_params = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3
#              corr_models 2023/09/22 10:41:56     INFO: Initialized self.params      = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.3
#              corr_models 2023/09/22 10:41:56     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.5, γ_pr_strength=0
#              corr_models 2023/09/22 10:41:56     INFO: Set k_max=10, k_min=1e-06.
# ...

# %% [markdown]
# # Intermittent Generalized Inverse Gausssian model

# %%
reload(corrm)
Model = corrm.IntermittentGeneralizedInverseGaussian

# %%
true_params = Model.Params(λ=2,μ=1,σ=0.01,γ=0.8, k=0.2,m=0.1,α=0.1, β=0.1)
y, labs = Model.gen_data(1001, true_params)
corrm.plot_data(y, labs)

# %%
reload(corrm)
corrm.logger.setLevel(logging.INFO)
Model    = corrm.IntermittentGeneralizedInverseGaussian
true_mdl = Model(init_params=true_params, name="True Model")
mdl      = Model(#Model.Params(λ=1,μ=0.1, k=1,m=1,α=0.5, β=0.5, γ = 0.8, σ = 0.01),
    name = "Fit",
            σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1e-3)
mdl.fit(y, method="Nelder-Mead", damping=0.0)
figure(figsize=(10,5))
corrm.plot_cdfs(y, [true_mdl, mdl])
# Out:
#              corr_models 2023/09/22 10:41:56     INFO: ********************************************************************************
#              corr_models 2023/09/22 10:41:56     INFO: Initializing model IntermittentGeneralizedInverseGaussian named 'True Model' id(self)=140497067875824.
#              corr_models 2023/09/22 10:41:56     INFO: Casting IntermittentGeneralizedInversGaussian to IntermittentGeneralizedInversGaussian.
#              corr_models 2023/09/22 10:41:56     INFO: Cast params: λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1 -> λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1
#              corr_models 2023/09/22 10:41:56     INFO: Initialized self.init_params = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1
#              corr_models 2023/09/22 10:41:56     INFO: Initialized self.params      = λ=2, μ=1, σ=0.01, γ=0.8, k=0.2, m=0.1, α=0.1, β=0.1
# ...

# %% [markdown]
# # CorrModel - Testing the wrapper class.

# %%
reload(corrm)
Params     = corrm.IntermittentGeneralizedInverseGaussian.Params
TrueModel  = corrm.IntermittentGamma
true_model = TrueModel(name="True Model", init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.4, m = 0.1, α = 0.1, β = 0.1),
                       σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
data, labs = true_model.gen_data(1001, params = true_model.params)
corrm.plot_data(data, labs)
# Out:
#              corr_models 2023/09/22 10:41:58     INFO: ********************************************************************************
#              corr_models 2023/09/22 10:41:58     INFO: Initializing model IntermittentGamma named 'True Model' id(self)=140497070066752.
#              corr_models 2023/09/22 10:41:58     INFO: Casting IntermittentGenInvGauss to IntermittentGamma.
#              corr_models 2023/09/22 10:41:58     INFO: Finding nearest Gamma distribution to GIG(η=2, p=0.4, θ=0.1).
#              corr_models 2023/09/22 10:41:58    DEBUG: C0=18.693982264514133, C1=1.9252473405978052
#              corr_models 2023/09/22 10:41:58    DEBUG: Initializing at [40.   0.4].
#              corr_models 2023/09/22 10:41:58    DEBUG: Solving using scipy.optimize.minimize.
#              corr_models 2023/09/22 10:41:58    DEBUG: Initial value of neg_ElogQ = 3.894727560318895.
# ...

# %%
reload(corrm)
Exp = corrm.CorrModel(model = "exp", name = "Exp", intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.2, m = 0.1, α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gam = corrm.CorrModel(model = "gamma", name = "Gam", intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 1., α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)
Gig = corrm.CorrModel(model = "gig", name="Gig",intermittent = True,
                      #init_params = Params(λ=2, μ=0.5, σ = 0.01, γ = 0.8, k = 0.5, m = 0.2, α = 0.1, β = 0.1),
                      σ_penalty = 0, γ_pr_mean = 0.8, γ_pr_strength = 1)

# %%
corrm.logger.setLevel(logging.INFO)
Exp.fit(data);
Gam.fit(data, method = "Nelder-Mead");
Gig.fit(data, method = "Nelder-Mead");
Gam2 = corrm.IntermittentGamma(init_params = corrm.IntermittentGamma.params_from_gig(Gig.models[-1].params), name="GamFromGig")
figure(figsize=(12,8))
corrm.plot_cdfs(data, [true_model, Gam, Gig, Gam2])#, Gig1])#, labs=["true", "Gam", "Gig", "Gig (γ)"])
# Out:
#              corr_models 2023/09/22 10:41:58     INFO: ********************************************************************************
#              corr_models 2023/09/22 10:41:58     INFO: Initializing model IntermittentExponential named 'Model' id(self)=140498584461856.
#              corr_models 2023/09/22 10:41:58     INFO: Initialized self.init_params = None
#              corr_models 2023/09/22 10:41:58     INFO: Initialized self.params      = None
#              corr_models 2023/09/22 10:41:58     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=0.8, γ_pr_strength=1
#              corr_models 2023/09/22 10:41:58     INFO: Fitting IntermittentExponential model Model.
#              corr_models 2023/09/22 10:41:58     INFO: Initializing from fit using γ=0.8.
#              corr_models 2023/09/22 10:41:58     INFO: Found 201 intermittent points, 588 positive, 212 negative values.
# ...

# %% [markdown]
# # Real data

# %%
import os, sys
os.environ["FISHER_PLUMES"] = os.path.join(os.environ["GIT"],"fisher-plumes")
os.chdir(os.environ["FISHER_PLUMES"])
import units; reload(units); UNITS = units.UNITS;

# %%
import boulder;   reload(boulder)
import crick;     reload(crick)
import surrogate; reload(surrogate)
import fisher_plumes_tools as fpt;      reload(fpt)
import fisher_plumes_figs  as fpf;      reload(fpf);
import fisher_plumes_fig_tools as fpft; reload(fpft)
import fisher_plumes as fp;             reload(fp)
import utils; reload(utils); from utils import dict_update, dict_update_from_field
import proc; reload(proc);
FisherPlumes = fp.FisherPlumes
crick.logger.setLevel(logging.DEBUG)
fp.logger.setLevel(logging.INFO)
# Out:
# INFO:boulder:Boulder simulation data available for:
# INFO:boulder:Re100_0_5mm_50Hz_16source_manuscript.h5         : ['Odor Data/c1a', 'Odor Data/c1b', 'Odor Data/c2a', 'Odor Data/c2b', 'Odor Data/c3a', 'Odor Data/c3b', 'Odor Data/c4a', 'Odor Data/c4b', 'Odor Data/c5a', 'Odor Data/c5b', 'Odor Data/c6a', 'Odor Data/c6b', 'Odor Data/c7a', 'Odor Data/c7b', 'Odor Data/c8a', 'Odor Data/c8b'] (16 datasets)
# INFO:boulder:Boulder simulation data available for:
# INFO:boulder:Re100_0_5mm_50Hz_16source_manuscript.h5         : ['Odor Data/c1a', 'Odor Data/c1b', 'Odor Data/c2a', 'Odor Data/c2b', 'Odor Data/c3a', 'Odor Data/c3b', 'Odor Data/c4a', 'Odor Data/c4b', 'Odor Data/c5a', 'Odor Data/c5b', 'Odor Data/c6a', 'Odor Data/c6b', 'Odor Data/c7a', 'Odor Data/c7b', 'Odor Data/c8a', 'Odor Data/c8b'] (16 datasets)
# INFO:crick:Simulation data available for:
# INFO:crick:crimgrid_w1                                     : y0 - y9 (16 datasets)
# ...

# %%
window_length = 1 * UNITS.second
windows       = ['boxcar', 'hann', ('kaiser',9), ('kaiser', 16)]
window_shape  = windows[0]
fit_k         = False
fit_b         = True

# %%
to_use = {
    "16Ts":{"sim_name":"n16Tslow"},
    "bw":  {"sim_name":"boulder16"},
    "s=w": {"sim_name":"surr_all_equal", "surrogate_k": 0},
    "s=p": {"sim_name":"surr_all_equal", "surrogate_k": 4},
#    "shw": {"sim_name":"surr_high",      "surrogate_k": 0},          
#    "shp": {"sim_name":"surr_high",      "surrogate_k": 4},
#    "s=w_q0":{"sim_name":"surr_quad",      "surrogate_k": 0, "phi":0},
#    "s=w_q1":{"sim_name":"surr_quad",      "surrogate_k": 0, "phi":pi/3},
}

# %%
reload(proc)
safe_load = lambda d: d[0] if d is not None else d
[f.logger.setLevel(logging.WARN) for f in [crick, boulder,fp]];
loaded = {k:safe_load(proc.load_data(init_filter = v,
                                       compute_filter = {
                                           "window_shape":window_shape,
                                           "window_length":window_length,
                                           "fit_k":fit_k,
                                           "fit_b":fit_b,
                                       },
                                     fit_corrs = ["search.1"]
                                     ))
          for k,v in to_use.items()}

data =  {k:FisherPlumes(d) for k,d in loaded.items() if d is not None}

for k, l in loaded.items():
    if l is None:
        print(f"WARNING: No data for {k=}")

[f.logger.setLevel(logging.INFO) for f in [crick, boulder,fp]];
# Out:
#                     proc 2023/09/22 10:42:04     INFO: Loading init_filter={'sim_name': 'n16Tslow'} compute_filter={'window_shape': 'boxcar', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/n16Ts.1/8ce1f67f387e66d4.p
#                     proc 2023/09/22 10:42:09     INFO: Loading proc/n16Ts.1/fit_corrs/search.1/8ce1f67f387e66d4.p.
#                     proc 2023/09/22 10:42:15     INFO: Returning 1 results.
#                     proc 2023/09/22 10:42:15     INFO: Loading init_filter={'sim_name': 'boulder16'} compute_filter={'window_shape': 'boxcar', 'window_length': <Quantity(1, 'second')>, 'fit_k': False, 'fit_b': True} from proc/bw.1/68a5c7b1f718189b.p
#                     proc 2023/09/22 10:42:16     INFO: Loading proc/bw.1/fit_corrs/search.1/68a5c7b1f718189b.p.
#                     proc 2023/09/22 10:42:18     INFO: Returning 1 results.
# ...

# %%
def get_data(ds, idist, ifreq, iprb=0):
    F = data[ds]
    dd= array(list(F.pairs_um.keys()))
    dd= dd[dd>=0]
    d = dd[idist]
    f = ifreq
    print(f"Returning data for ds={ds}, d={d}, freq={F.freqs[f]:.1f}")
    y  = F.rho[iprb][d][0][f]
    la = F.la[iprb][d][0,f,0]
    mu = F.mu[iprb][d][0,f,0]
    print(f"la={la:.2g}, mu={mu:.2g}, {std(y)=:.2g}")
    la_ = la/std(y)
    mu_ = mu/std(y)
    y_  =  y/std(y)
    print(f"la_={la_:.2g}, mu_={mu_:.2g}, {std(y_)=:.2g}")
    return y_

# %%
data["16Ts"].rho[0][0].shape
# Out:
# (51, 51, 4448)

# %%
y_ = get_data("16Ts", 0, 0)
plot(y_)
# Out:
# Returning data for ds=16Ts, d=0, freq=0.0 hertz
# la=3.2e-31, mu=1.9e-64, std(y)=2.8e-30
# la_=0.12, mu_=6.8e-35, std(y_)=1

# %%
reload(fpt)
reload(corrm)
Exp0 = corrm.CorrModel(model = "exp", name = "Exp0", intermittent = False, σ_penalty = 0, γ_pr_mean = 0.95, γ_pr_strength = 1)
Exp0.fit(y_)
Exp = corrm.CorrModel(model = "exp", name = "Exp", intermittent = True, σ_penalty = 0, γ_pr_mean = 0.95, γ_pr_strength = 1)
Exp.fit(y_)
Gam = corrm.CorrModel(model = "gamma", name = "Gam", intermittent = True, init_params = Exp.models[-1].params)
Gam.fit(y_, method = "TNC")
Gig = corrm.CorrModel(model = "gig", name="Gig",intermittent = True, init_params = Gam.models[-1].params)
Gig.fit(y_, method = "TNC")
Gig0 = corrm.CorrModel(model = "gig", name="Gig0",intermittent = False, init_params = Gig.models[-1].params)
Gig0.fit(y_, method = "TNC")
Gam0 = corrm.CorrModel(model = "gamma", name="Gam0",intermittent = False, init_params = Gam.models[-1].params)
Gam0.fit(y_, method = "TNC")

#Gam2 = corrm.IntermittentGamma(init_params = Gig0.model.params, name="GamFromGig")
figure(figsize=(12,5))
corrm.plot_cdfs(y_, [Exp0, Exp, Gam, Gig], legend_args={"labelspacing":0, "fontsize":6, "loc":"lower right"})
# Out:
#              corr_models 2023/09/22 10:43:04     INFO: ********************************************************************************
#              corr_models 2023/09/22 10:43:04     INFO: Initializing model IntermittentExponential named 'Model' id(self)=140497070490576.
#              corr_models 2023/09/22 10:43:04     INFO: Initialized self.init_params = None
#              corr_models 2023/09/22 10:43:04     INFO: Initialized self.params      = None
#              corr_models 2023/09/22 10:43:04     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=1, γ_pr_strength=inf
#              corr_models 2023/09/22 10:43:04     INFO: Fitting IntermittentExponential model Model.
#              corr_models 2023/09/22 10:43:04     INFO: Initializing from fit using γ=1.
#              corr_models 2023/09/22 10:43:04     INFO: Found 0 intermittent points, 4423 positive, 0 negative values.
# ...

# %% [markdown]
# # Model selection

# %%
from sklearn.model_selection import GridSearchCV, ShuffleSplit
import pandas as pd

# %%
param_grid= [{"model":["exp", "gamma", "gig"], "intermittent":[False]},
#             {"model":["exp", "gamma", "gig"], "intermittent":[True], "γ_pr_mean":[0.2,0.4,0.6,0.8], "γ_pr_strength":[1]}
             ]

# %%
reload(fpt)
reload(corrm)
corrm.logger.setLevel(logging.WARN)

# %%
y_ = get_data("16Ts", 1, 5)
plot(y_)
# Out:
# Returning data for ds=16Ts, d=8000, freq=5.0 hertz
# la=0.044, mu=0.0024, std(y)=0.026
# la_=1.7, mu_=0.093, std(y_)=1

# %%
reload(corrm)
# Out:
# <module 'corr_models' from '/nemo/lab/schaefera/working/tootoos/git/fisher-plumes/corr_models.py'>

# %%
res = corrm.fit_corrs(y, "search.0.yaml")
# Out:
#              corr_models 2023/09/22 10:43:06     INFO: Loaded search_spec from search_spec={'gridsearch': {'verbose': 1, 'n_jobs': 1}, 'estimator': {'scoring': 'tv', 'init_mode': 'ancestral'}, 'cv': {'n_splits': 10, 'test_size': 0.5, 'random_state': 0}, 'param_grid': [{'model': ['exp', 'gamma', 'gig'], 'intermittent': [False], 'k_min': [1e-06], 'k_max': [10]}]}
#              corr_models 2023/09/22 10:43:06     INFO:
#              corr_models 2023/09/22 10:43:06     INFO: Using ancestral initialization for self.model='exp'.
#              corr_models 2023/09/22 10:43:06     INFO: ********************************************************************************
#              corr_models 2023/09/22 10:43:06     INFO: Initializing model IntermittentExponential named 'Model' id(self)=140495296196416.
#              corr_models 2023/09/22 10:43:06     INFO: Initialized self.init_params = None
#              corr_models 2023/09/22 10:43:06     INFO: Initialized self.params      = None
# ...

# %%
reload(corrm)
search = corrm.GridSearchCVKeepModels(GridSearchCV(estimator = corrm.CorrModel(name="Model", scoring = "tv", init_mode="ancestral"), param_grid=param_grid, cv=ShuffleSplit(n_splits=3, test_size=0.5, random_state=0),verbose=1, n_jobs=1))
corrm.logger.setLevel(logging.INFO)
search.fit(X=y_, y=None)
# Out:
#              corr_models 2023/09/22 10:43:13     INFO:
#              corr_models 2023/09/22 10:43:13     INFO: Using ancestral initialization for self.model='exp'.
#              corr_models 2023/09/22 10:43:13     INFO: ********************************************************************************
#              corr_models 2023/09/22 10:43:13     INFO: Initializing model IntermittentExponential named 'Model' id(self)=140495296196224.
#              corr_models 2023/09/22 10:43:13     INFO: Initialized self.init_params = None
#              corr_models 2023/09/22 10:43:13     INFO: Initialized self.params      = None
#              corr_models 2023/09/22 10:43:13     INFO: Initialized self.hyper_params= σ_penalty=0, γ_pr_mean=1, γ_pr_strength=inf
#              corr_models 2023/09/22 10:43:13     INFO: Fitting IntermittentExponential model Model.
#              corr_models 2023/09/22 10:43:13     INFO: Initializing from fit using γ=1.
# ...

# %%
search.fitted_models
# Out:
# {"{'init_mode': 'ancestral', 'init_params': None, 'intermittent': False, 'k_max': 10, 'k_min': 1e-06, 'model': 'exp', 'name': 'Model', 'scoring': 'tv', 'γ_pr_mean': 0.5, 'γ_pr_strength': 1, 'σ_penalty': 0}": [Model, IntermittentExponential(Params(λ=0.86, μ=0.082, σ=0, γ=1)),
#   Model, IntermittentExponential(Params(λ=0.87, μ=0.09, σ=0, γ=1)),
#   Model, IntermittentExponential(Params(λ=0.87, μ=0.082, σ=0, γ=1))],
#  "{'init_mode': 'ancestral', 'init_params': None, 'intermittent': False, 'k_max': 10, 'k_min': 1e-06, 'model': 'gamma', 'name': 'Model', 'scoring': 'tv', 'γ_pr_mean': 0.5, 'γ_pr_strength': 1, 'σ_penalty': 0}": [Model, IntermittentGamma(Params(λ=1.2, μ=0.11, σ=0, γ=1, k=0.72, m=1)),
#   Model, IntermittentGamma(Params(λ=1.1, μ=0.12, σ=0, γ=1, k=0.76, m=1.1)),
#   Model, IntermittentGamma(Params(λ=1.2, μ=0.1, σ=0, γ=1, k=0.74, m=1))],
# ...

# %%
reload(corrm); from corr_models import GridSearchCVKeepModelsWrapper as Wrapper
w = Wrapper(search)
w.split_test_score(intermittent=False)
# Out:
# ([[0.9708792782332428, 0.9741520301094528, 0.9859390578709888],
#   [0.9639331739100458, 0.9764966168046758, 0.9782822162433971],
#   [0.9527125787028699, 0.9400182032689515, 0.9414289168367755]],
#  [{'intermittent': False, 'model': 'gig'},
#   {'intermittent': False, 'model': 'gamma'},
#   {'intermittent': False, 'model': 'exp'}])

# %% [markdown]
# # Loading collected fits

# %%
# Unpack a dictionary into a list of keys and a list of values
unpack_dict = lambda d: (lambda uv: ([eval(ki) for ki in uv[0]], uv[1]))(list(zip(*d.items())))

# %%
def find_best_γ(obj):
    w = Wrapper(obj)
    v, k = w.mean_test_score(model="exp")    
    γvals = [1 if "γ_pr_mean" not in k[i] else k[i]["γ_pr_mean"] for i in range(len(k))]
    imax = argsort(-np.array(v))[0]
    γ = [m.models[-1].params.γ for m in w.models(**k[imax])[0][0]]
    return np.mean(γ)

# %%
def find_best_non_intermittent(obj):
    w = Wrapper(obj)
    m, k = w.models(intermittent=False)
    s = np.array([w.mean_test_score(**ki)[0] for ki in k])
    ibest = argmax(s)
    m = m[ibest]
    k = k[ibest]
    s = s[ibest]
    return m,k,s

# %%
def find_k(obj):
    w = Wrapper(obj)
    m,k,s = find_best_non_intermittent(obj)
    return 1 if k["model"]=="exp" else np.nanmean([mi.models[-1].params.k for mi in m])

def find_gig_a(obj):
    w = Wrapper(obj)
    m,k,s = find_best_non_intermittent(obj)
    if k["model"] in ["exp", "gamma"]:
        return np.array([1/np.nanmean([mi.models[-1].params.λ for mi in m]), 1/np.nanmean([mi.models[-1].params.μ for mi in m])])
    else:
        return np.array(
            [np.nanmean([mi.models[-1].params.α/mi.models[-1].params.λ for mi in m]),
             np.nanmean([mi.models[-1].params.β/mi.models[-1].params.μ for mi in m])])

def find_gig_b(obj):
    w = Wrapper(obj)
    m,k,s = find_best_non_intermittent(obj)
    if k["model"] in ["exp", "gamma"]:
        return np.array([0, 0])
    else:
        return np.array([np.nanmean([mi.models[-1].params.α * mi.models[-1].params.λ for mi in m]),
                np.nanmean([mi.models[-1].params.β * mi.models[-1].params.μ for mi in m])])

# %%
ds    = "bw"

# %%
reload(corrm)
srch = "search.1"
ds   = "bw"
F    = data[ds]
kk   = list(F.fit_corrs[srch]["results"].keys())
dd   = sorted(list(set(ki[1] for ki in kk)))
ff   = sorted(set(ki[2] for ki in kk))
nd   = len(dd)
nf   = len(ff)
score = np.zeros((11,nf,nd))
for i in range(nf):
    for j in range(nd):        
        res = F.fit_corrs[srch]["results"][(0,dd[j],ff[i])]
        obj = res["search"]
        sca = res["scale"]
        w   = Wrapper(obj)
        r,k = w.mean_test_score(0)
        assert len(r) == 1, "Expected only one result"
        s0 = max([Wrapper(obj).mean_test_score(model=mdl, intermittent=False)[0][0] for mdl in ["exp", "gamma", "gig"]])
        γ = find_best_γ(res["search"])
        m = {"exp":0, "gamma":1, "gig":2}[k[0]["model"]]
        s =  w.mean_test_score(0)[0][0]
        k = find_k(obj)
        s_exp0 = w.mean_test_score(0, model="exp", intermittent=False)[0][0]
        s_expi = w.mean_test_score(0, model="exp")[0][0]
        s_noi  = w.mean_test_score(0, intermittent=False)[0][0]
        apos, aneg = find_gig_a(obj) * sca
        bpos, bneg = find_gig_b(obj) / sca
        score[0,i,j]  = bpos # {"exp":0, "gamma":1, "gig":2}[find_best_model(obj)]
        score[1,i,j]  = s_exp0
        score[2,i,j]  = s_expi
        score[3,i,j]  = s
        score[4,i,j]  = s_noi
        score[5,i,j]  = np.mean([m.models[-1].params.γ for m in w.models(rank=0)[0][0]])
        score[6,i,j]  = np.mean([m.models[-1].params.γ for m in w.models(rank=0, model="exp")[0][0]])
        score[7,i,j]  = m
        score[8,i,j]  = w.mean_test_score(0, model="gamma", intermittent=True)[0][0]
        score[9,i,j]  = w.mean_test_score(0, model="gamma", intermittent=False)[0][0]
        score[10,i,j] = w.mean_test_score(0, model="gamma")[0][0]

# %%
reload(corrm);
from corr_models import GridSearchCVKeepModelsWrapper as Wrapper
w = Wrapper(obj)
pp, hh = w.params(model = ["exp", "gamma"])
corrm.summarize_params(pp, preproc_fun = corrm.IntermittentGamma._cast_params)
# Out:
#              corr_models 2023/09/22 14:29:09    DEBUG: Cast Params(λ=0.47, μ=0.71, σ=0.025, γ=0.82, k=1.8, m=1.2) -> IntermittentGammaParams(λ=0.47, μ=0.71, σ=0.025, γ=0.82, k=1.8, m=1.2)
#              corr_models 2023/09/22 14:29:09    DEBUG: Cast Params(λ=0.36, μ=0.65, σ=0.025, γ=0.83, k=1.3, m=1.3) -> IntermittentGammaParams(λ=0.36, μ=0.65, σ=0.025, γ=0.83, k=1.3, m=1.3)
#              corr_models 2023/09/22 14:29:09    DEBUG: Cast Params(λ=0.41, μ=0.72, σ=0.019, γ=0.84, k=1.4, m=1.4) -> IntermittentGammaParams(λ=0.41, μ=0.72, σ=0.019, γ=0.84, k=1.4, m=1.4)
#              corr_models 2023/09/22 14:29:09    DEBUG: Cast Params(λ=0.53, μ=0.84, σ=0, γ=1) -> IntermittentGammaParams(λ=0.53, μ=0.84, σ=0, γ=1, k=1, m=1)
#              corr_models 2023/09/22 14:29:09    DEBUG: Cast Params(λ=0.39, μ=0.75, σ=0, γ=1) -> IntermittentGammaParams(λ=0.39, μ=0.75, σ=0, γ=1, k=1, m=1)
# ...

# %%
pp[0].__class__
# Out:
# corr_models.IntermittentGamma.Params

# %%
dir(pp[0])
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_asdict',
#  '_field_defaults',
#  '_fields',
#  '_fields_defaults',
#  '_make',
#  '_replace',
#  'count',
#  'index',
#  'k',
#  'm',
#  'γ',
#  'λ',
#  'μ',
#  'σ']

# %%
pp[0].__class__
# Out:
# corr_models.IntermittentGamma.Params

# %%
str(pp[0])
# Out:
# 'Params(λ=0.47045057618901026, μ=0.7068163456483376, σ=0.024933205276445745, γ=0.823728813559322, k=1.7752181968303464, m=1.1942054491872574)'

# %%
figure(figsize=(12,4))
plot(dd, score[0,12])

# %%
ttl = "Best score - Best (γ = 1) score."
ttl = "bpos"
ttl = "Model"
#figure(figsize=(1,4))
matshow(score[0], cmap=cm.jet_r,fignum=False); axis("auto"); colorbar()
#matshow(score, fignum=False,cmap=cm.jet_r); axis("auto"); colorbar()
xticks(range(nd), dd, rotation=90)
yticks(range(nf), ff)
xlabel("Distance")
ylabel("Frequency")
title(ttl)
# Out:
# Text(0.5, 1.0, 'Model')

# %% [markdown]
# # Gamma models

# %%
figure(figsize=(12,4))
order = [2,0,1]
s = [score[8], # Intermitent = True
     score[9], # Intermitent = False
     score[8]-score[9],
     score[10]-score[1],
     ]
cmaps = [cm.jet,
         cm.jet,
         cm.bwr,
         cm.bwr,
         ]
for i in range(4):
    subplot(1,4,i+1)
    matshow(s[i],
            cmap = cmaps[i],
            #cmap=[cm.pink, cm.magma, cm.magma][i],        
            vmin= 0.8 if i < 2 else -0.02,
            vmax=1. if i < 2 else 0.02,
            fignum=False); axis("auto");
    colorbar()
    xticks(range(nd), dd, rotation=90)    
    if i == 0:
        yticks(range(nf), ff, fontsize=10)
    else:
        yticks([])
    xlabel("Distance")
    i == 0 and ylabel("Frequency")
    
    xlabel("Distance")
    i == 0 and ylabel("Frequency")
    title({0:"A: Gamma (γ <= 1)", 1:"B: Gamma (γ = 1)", 2:"A - B", 3:"Gamma_0 - Exp_0"}[i])
tight_layout(pad=0, w_pad=0, h_pad=0)

# %% [markdown]
# # Accuracy

# %%
figure(figsize=(12,4))
for i in range(4):
    if i == 0:
        ss = score[i+1]
    elif i == 3:
        ss = score[3]
    else:
        ss = score[i+1] if i == 0 else score[i+1] - score[i]
    subplot(1,4,i+1)
    matshow(ss, cmap=cm.jet_r if i in [0,3] else cm.pink,fignum=False,
            vmin = 0.8 if i in [0,3] else None,
            vmax = 1 if i in [0,3] else 0.10,
            ); axis("auto");
    if i <2:
        cbar = colorbar(fraction=0.05, shrink=1.0)
        cbar.ax.tick_params(labelsize=8)
    #matshow(score, fignum=False,cmap=cm.jet_r); axis("auto"); colorbar()
    xticks(range(nd), dd, rotation=90)    
    if i == 0:
        yticks(range(nf), ff, fontsize=10)
    else:
        yticks([])
    xlabel("Distance")
    i == 0 and ylabel("Frequency")
    title({0:"Original", 1:"Δ after intermittency", 2:"Δ after gamma/gig", 3:"Final"}[i])
tight_layout(pad=0, w_pad=0, h_pad=0)

# %%
figure(figsize=(12,4))
order = [2,0,1]
s = [score[7], # Model
     score[5], # γ (all)
     score[6], # γ (exp)
     score[3] - score[4], # Final - No intermittency
     ]
cmaps = [cm.viridis,
         cm.magma,
         cm.magma,
         cm.pink,
         ]
for i in range(4):
    subplot(1,4,i+1)
    matshow(s[i],
            cmap = cmaps[i],
            #cmap=[cm.pink, cm.magma, cm.magma][i],        
            vmax= 0.1 if i == 3 else None,
            fignum=False); axis("auto");
    colorbar()
    xticks(range(nd), dd, rotation=90)    
    if i == 0:
        yticks(range(nf), ff, fontsize=10)
    else:
        yticks([])
    xlabel("Distance")
    i == 0 and ylabel("Frequency")
    
    xlabel("Distance")
    i == 0 and ylabel("Frequency")
    title({0:"Model", 1:"Intermittency (all)", 2:"Intermittency (exp)", 3:"Accuracy gain w/ intermittency"}[i])
tight_layout(pad=0, w_pad=0, h_pad=0)

# %% [markdown]
# ## Why does the gig model, with more parameters, fit better than the exponential model?

# %%
y_ = get_data("bw", 2, 2, iprb=0)
plot(y_)
# Out:
# Returning data for ds=bw, d=15000, freq=2.0 hertz
# la=0.38, mu=0.081, std(y)=0.17
# la_=2.2, mu_=0.48, std(y_)=1

# %%
reload(corrm)
corrm.logger.setLevel(logging.WARN)
res = corrm.fit_corrs(y_, "search.1.yaml")
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /camp/home/tootoos/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
# ...

# %%
w = Wrapper(res["search"])
# Only show the columns named "params" and sort by the mean_test_score
pd.DataFrame(w.grid_search.cv_results_).sort_values(by="mean_test_score", ascending=False).loc[:, ["param_model", "param_γ_pr_mean", "mean_test_score", "std_test_score"]]
# Out:
#    param_model param_γ_pr_mean  mean_test_score  std_test_score
# 27         gig             0.7         0.942866        0.014129
# 28         gig             0.8         0.937563        0.014733
# 19       gamma             0.8         0.936143        0.017125
# 18       gamma             0.7         0.935254        0.019605
# 26         gig             0.6         0.932064        0.021530
# 17       gamma             0.6         0.928643        0.018449
# 1        gamma             NaN         0.927030        0.023094
# 2          gig             NaN         0.925327        0.019500
# 29         gig             0.9         0.922867        0.021832
# 20       gamma             0.9         0.921110        0.022838
# 16       gamma             0.5         0.901930        0.018963
# 0          exp             NaN         0.895412        0.012075
# 15       gamma             0.4         0.876009        0.010138
# 24         gig             0.4         0.874627        0.010811
# ...

# %%
corrm.plot_cdfs(y_, [w.models(rank=0, model=m)[0][0][0] for m in ["exp", "gamma", "gig"]], gof_fun=fpt.compute_tv_value, legend_args={"fontsize":6})

# %% [markdown]
# # Considering the PDFs

# %%
def get_length_scale(params):
    λ = params.λ if not hasattr(params, "α") else 2*params.λ/params.α
    μ = params.μ if not hasattr(params, "β") else 2*params.μ/params.β
    return [λ, μ]

# %%
def cleanup_cdf(c):
    # Replace any nan indices using linear interpolation
    c = np.array(c)
    nans = np.isnan(c)
    if nans.sum() == 0:
        return c
    else:
        print(f"Found {nans.sum()} nans.")
    x    = lambda z: z.nonzero()[0]
    c[nans] = np.interp(x(nans), x(~nans), c[~nans])
    return c

x = sin(2*pi*arange(100)/100)
x[50:80] = np.nan
plot(cleanup_cdf(x))
plot(x, linewidth=4)
# Out:
# Found 30 nans.

# %%
# Let's look at how the CDFs evolve with distance at a given frequency
srch  = "search.1"
ifreq = 12
f     =  F.freqs[ifreq]
res   = [F.fit_corrs[srch]["results"][(0,d,ifreq)]          for d in sorted(dd)]
sca   = [F.fit_corrs[srch]["results"][(0,d,ifreq)]["scale"] for d in sorted(dd)]
y     = [F.rho[0][d][0][ifreq] for d in sorted(dd)]
y_    = [yi/sca[i] for i,yi in enumerate(y)]
xv_   = [np.linspace(np.min(yi),np.max(yi),5001) for yi in y_]
w     = [Wrapper(r["search"]) for r in res]
#λμ    = np.array([np.array(get_length_scale(w_.grid_search.best_estimator_.models[-1].params))*sc for i,(w_,sc) in enumerate(zip(w,sca))])
#λμ    = np.array([np.mean(np.array([get_length_scale(wi.models[-1].params) for wi in w_.models(rank=0)[0][0]]), axis=0)*sc for i,(w_,sc) in enumerate(zip(w,sca))])
#cdfs  = [w_.grid_search.best_estimator_.cdf(xv_[i]) for i,w_ in enumerate(w)]
cdfs  = np.array([cleanup_cdf(w_.models(rank=0)[0][0][0].cdf(xv_[i])) for i,w_ in enumerate(w)])
pdfs  = [(c[2:]-c[0:-2])/2  for c in cdfs]
xx    = [xv_[i]*sca[i] for i in range(len(dd))]

# %%
figure(figsize=(12,4))
subplot(1,2,1)
for i in range(len(dd)):
    plot(xx[i], cdfs[i], label=f"{dd[i]}", color=cm.rainbow_r(i/len(dd)))
    xlabel("x")
    ylabel("P(r <= x)")
legend(fontsize=6, labelspacing=0)
subplot(1,2,2)
for i in range(len(dd))[:]:
    semilogy(xx[i][1:-1], pdfs[i], label=f"{dd[i]}", color=cm.rainbow_r(i/(0 + 1*len(dd))))
    xlabel("x")
    ylabel("p(r=x)")
suptitle(f"Fitted distributions of correlations at different distances at {f} for dataset {ds}")
# Out:
# Text(0.5, 0.98, 'Fitted distributions of correlations at different distances at 12.0 Hz for dataset bw')

# %%
rmax = np.max([np.max(abs(yi)) for yi in y])
figure(figsize=(14,6))
for i, sgn in enumerate([1,-1]):
    subplot(1,2,i+1)
    for r in sgn*arange(0, rmax, rmax/20):
        inds = [np.argmin(abs(xx[i]-r)) for i in range(len(dd))]
        try:
            d, p = zip(*[(dd[i], pdfs[i][inds[i]]) for i in range(len(dd)) if inds[i] < len(pdfs[i])])        
            semilogy(d[1:],p[1:] , "o-", color=cm.rainbow_r(abs(r/rmax)), label=f"{r:g}")
        except Exception as e:
            print(e)
            pass
    #ylim(1e-8,1e-2)
    legend(fontsize=6)
    #title(f"PDF at r={r}")

# %%
w[1].grid_search.best_estimator_
# Out:
# Model, IntermittentGamma(Params(λ=1, μ=0.21, σ=0.013, γ=0.9, k=0.88, m=1.3))

# %%
y_ = get_data("bw", 1, ifreq)
# Out:
# Returning data for ds=bw, d=7500, freq=12.0 hertz
# la=0.0037, mu=0.00037, std(y)=0.0023
# la_=1.6, mu_=0.16, std(y_)=1

# %%
from copy import deepcopy

# %%
q = deepcopy(w[1].grid_search.best_estimator_.models[-1])
#q.params = q.params._replace(k=2.4)

# %%
corrm.plot_cdfs(y_, [q], gof_fun=fpt.compute_tv_value)
